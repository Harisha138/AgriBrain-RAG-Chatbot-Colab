# %% [markdown]
# # Conversational Text Chatbot with Gemini and LangChain for Farmers
#
# In this notebook you will use Gemini and LangChain to build a conversational text-based chatbot

# %% [markdown]
# ## Install Gemini and LangChain dependencies
#
# Google Gemini API is free (till now). You can get a key [here](https://aistudio.google.com/app/apikey), just need to sign in with your google account. Gemini may not be available fully in EU.

# %%
# !pip install langchain==0.3.11
# !pip install langchain-google-genai==2.0.7
# !pip install langchain-community==0.3.11
# !pip install pyngrok==7.2.2
# !pip install PyMuPDF==1.24.0
# !pip install chromadb==0.6.3
# !pip install pydantic==2.10.1
# !pip install langchain-chroma==0.2.2
# !pip install numpy==1.24.3
# Out:
# Collecting langchain==0.3.11
#   Downloading langchain-0.3.11-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.11/dist-packages (from langchain==0.3.11) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.11/dist-packages (from langchain==0.3.11) (2.0.40)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.11/dist-packages (from langchain==0.3.11) (3.11.15)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.24 in /usr/local/lib/python3.11/dist-packages (from langchain==0.3.11) (0.3.51)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from langchain==0.3.11) (0.3.8)
# Collecting langsmith<0.3,>=0.1.17 (from langchain==0.3.11)
#   Downloading langsmith-0.2.11-py3-none-any.whl.metadata (14 kB)
# Collecting numpy<2,>=1.22.4 (from langchain==0.3.11)
#   Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 3.7 MB/s eta 0:00:00
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.11/dist-packages (from langchain==0.3.11) (2.11.2)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.11/dist-packages (from langchain==0.3.11) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /usr/local/lib/python3.11/dist-packages (from langchain==0.3.11) (9.1.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.11) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.11) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.11) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.11) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.11) (6.3.2)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.11) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.11) (1.18.3)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.11/dist-packages (from langchain-core<0.4.0,>=0.3.24->langchain==0.3.11) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.11/dist-packages (from langchain-core<0.4.0,>=0.3.24->langchain==0.3.11) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in /usr/local/lib/python3.11/dist-packages (from langchain-core<0.4.0,>=0.3.24->langchain==0.3.11) (4.13.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.3,>=0.1.17->langchain==0.3.11) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.3,>=0.1.17->langchain==0.3.11) (3.10.16)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.3,>=0.1.17->langchain==0.3.11) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain==0.3.11) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain==0.3.11) (2.33.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain==0.3.11) (0.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain==0.3.11) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain==0.3.11) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain==0.3.11) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain==0.3.11) (2025.1.31)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from SQLAlchemy<3,>=1.4->langchain==0.3.11) (3.1.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain==0.3.11) (4.9.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain==0.3.11) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain==0.3.11) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.11/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.24->langchain==0.3.11) (3.0.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain==0.3.11) (1.3.1)
# Downloading langchain-0.3.11-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 23.5 MB/s eta 0:00:00
# Downloading langsmith-0.2.11-py3-none-any.whl (326 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 326.9/326.9 kB 16.0 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 76.6 MB/s eta 0:00:00
# Installing collected packages: numpy, langsmith, langchain
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#   Attempting uninstall: langsmith
#     Found existing installation: langsmith 0.3.24
#     Uninstalling langsmith-0.3.24:
#       Successfully uninstalled langsmith-0.3.24
#   Attempting uninstall: langchain
#     Found existing installation: langchain 0.3.23
#     Uninstalling langchain-0.3.23:
#       Successfully uninstalled langchain-0.3.23
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# Successfully installed langchain-0.3.11 langsmith-0.2.11 numpy-1.26.4
# Collecting langchain-google-genai==2.0.7
#   Downloading langchain_google_genai-2.0.7-py3-none-any.whl.metadata (3.6 kB)
# Collecting filetype<2.0.0,>=1.2.0 (from langchain-google-genai==2.0.7)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: google-generativeai<0.9.0,>=0.8.0 in /usr/local/lib/python3.11/dist-packages (from langchain-google-genai==2.0.7) (0.8.4)
# Requirement already satisfied: langchain-core<0.4,>=0.3.15 in /usr/local/lib/python3.11/dist-packages (from langchain-google-genai==2.0.7) (0.3.51)
# Requirement already satisfied: pydantic<3,>=2 in /usr/local/lib/python3.11/dist-packages (from langchain-google-genai==2.0.7) (2.11.2)
# Requirement already satisfied: google-ai-generativelanguage==0.6.15 in /usr/local/lib/python3.11/dist-packages (from google-generativeai<0.9.0,>=0.8.0->langchain-google-genai==2.0.7) (0.6.15)
# Requirement already satisfied: google-api-core in /usr/local/lib/python3.11/dist-packages (from google-generativeai<0.9.0,>=0.8.0->langchain-google-genai==2.0.7) (2.24.2)
# Requirement already satisfied: google-api-python-client in /usr/local/lib/python3.11/dist-packages (from google-generativeai<0.9.0,>=0.8.0->langchain-google-genai==2.0.7) (2.164.0)
# Requirement already satisfied: google-auth>=2.15.0 in /usr/local/lib/python3.11/dist-packages (from google-generativeai<0.9.0,>=0.8.0->langchain-google-genai==2.0.7) (2.38.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.11/dist-packages (from google-generativeai<0.9.0,>=0.8.0->langchain-google-genai==2.0.7) (5.29.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from google-generativeai<0.9.0,>=0.8.0->langchain-google-genai==2.0.7) (4.67.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.11/dist-packages (from google-generativeai<0.9.0,>=0.8.0->langchain-google-genai==2.0.7) (4.13.1)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /usr/local/lib/python3.11/dist-packages (from google-ai-generativelanguage==0.6.15->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai==2.0.7) (1.26.1)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in /usr/local/lib/python3.11/dist-packages (from langchain-core<0.4,>=0.3.15->langchain-google-genai==2.0.7) (0.2.11)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.11/dist-packages (from langchain-core<0.4,>=0.3.15->langchain-google-genai==2.0.7) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.11/dist-packages (from langchain-core<0.4,>=0.3.15->langchain-google-genai==2.0.7) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.11/dist-packages (from langchain-core<0.4,>=0.3.15->langchain-google-genai==2.0.7) (6.0.2)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.11/dist-packages (from langchain-core<0.4,>=0.3.15->langchain-google-genai==2.0.7) (24.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=2->langchain-google-genai==2.0.7) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=2->langchain-google-genai==2.0.7) (2.33.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=2->langchain-google-genai==2.0.7) (0.4.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai==2.0.7) (1.69.2)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in /usr/local/lib/python3.11/dist-packages (from google-api-core->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai==2.0.7) (2.32.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth>=2.15.0->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai==2.0.7) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth>=2.15.0->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai==2.0.7) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth>=2.15.0->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai==2.0.7) (4.9)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.11/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4,>=0.3.15->langchain-google-genai==2.0.7) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4,>=0.3.15->langchain-google-genai==2.0.7) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4,>=0.3.15->langchain-google-genai==2.0.7) (3.10.16)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4,>=0.3.15->langchain-google-genai==2.0.7) (1.0.0)
# Requirement already satisfied: httplib2<1.dev0,>=0.19.0 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai==2.0.7) (0.22.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai==2.0.7) (0.2.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai==2.0.7) (4.1.1)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai==2.0.7) (1.71.0)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai==2.0.7) (1.71.0)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.11/dist-packages (from httplib2<1.dev0,>=0.19.0->google-api-python-client->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai==2.0.7) (3.2.3)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-core<0.4,>=0.3.15->langchain-google-genai==2.0.7) (4.9.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-core<0.4,>=0.3.15->langchain-google-genai==2.0.7) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-core<0.4,>=0.3.15->langchain-google-genai==2.0.7) (1.0.7)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-core<0.4,>=0.3.15->langchain-google-genai==2.0.7) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-core<0.4,>=0.3.15->langchain-google-genai==2.0.7) (0.14.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai==2.0.7) (0.6.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai==2.0.7) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai==2.0.7) (2.3.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-core<0.4,>=0.3.15->langchain-google-genai==2.0.7) (1.3.1)
# Downloading langchain_google_genai-2.0.7-py3-none-any.whl (41 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 2.0 MB/s eta 0:00:00
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Installing collected packages: filetype, langchain-google-genai
# Successfully installed filetype-1.2.0 langchain-google-genai-2.0.7
# Collecting langchain-community==0.3.11
#   Downloading langchain_community-0.3.11-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.11/dist-packages (from langchain-community==0.3.11) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.11/dist-packages (from langchain-community==0.3.11) (2.0.40)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.11/dist-packages (from langchain-community==0.3.11) (3.11.15)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain-community==0.3.11)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting httpx-sse<0.5.0,>=0.4.0 (from langchain-community==0.3.11)
#   Downloading httpx_sse-0.4.0-py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: langchain<0.4.0,>=0.3.11 in /usr/local/lib/python3.11/dist-packages (from langchain-community==0.3.11) (0.3.11)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.24 in /usr/local/lib/python3.11/dist-packages (from langchain-community==0.3.11) (0.3.51)
# Requirement already satisfied: langsmith<0.3,>=0.1.125 in /usr/local/lib/python3.11/dist-packages (from langchain-community==0.3.11) (0.2.11)
# Requirement already satisfied: numpy<2,>=1.22.4 in /usr/local/lib/python3.11/dist-packages (from langchain-community==0.3.11) (1.26.4)
# Collecting pydantic-settings<3.0.0,>=2.4.0 (from langchain-community==0.3.11)
#   Downloading pydantic_settings-2.8.1-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.11/dist-packages (from langchain-community==0.3.11) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /usr/local/lib/python3.11/dist-packages (from langchain-community==0.3.11) (9.1.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.11) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.11) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.11) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.11) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.11) (6.3.2)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.11) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.11) (1.18.3)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community==0.3.11)
#   Downloading marshmallow-3.26.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community==0.3.11)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from langchain<0.4.0,>=0.3.11->langchain-community==0.3.11) (0.3.8)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.11/dist-packages (from langchain<0.4.0,>=0.3.11->langchain-community==0.3.11) (2.11.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.11/dist-packages (from langchain-core<0.4.0,>=0.3.24->langchain-community==0.3.11) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.11/dist-packages (from langchain-core<0.4.0,>=0.3.24->langchain-community==0.3.11) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in /usr/local/lib/python3.11/dist-packages (from langchain-core<0.4.0,>=0.3.24->langchain-community==0.3.11) (4.13.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.3,>=0.1.125->langchain-community==0.3.11) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.3,>=0.1.125->langchain-community==0.3.11) (3.10.16)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.3,>=0.1.125->langchain-community==0.3.11) (1.0.0)
# Collecting python-dotenv>=0.21.0 (from pydantic-settings<3.0.0,>=2.4.0->langchain-community==0.3.11)
#   Downloading python_dotenv-1.1.0-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain-community==0.3.11) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain-community==0.3.11) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain-community==0.3.11) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain-community==0.3.11) (2025.1.31)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from SQLAlchemy<3,>=1.4->langchain-community==0.3.11) (3.1.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.125->langchain-community==0.3.11) (4.9.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.125->langchain-community==0.3.11) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.3,>=0.1.125->langchain-community==0.3.11) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.11/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.24->langchain-community==0.3.11) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4.0,>=0.3.11->langchain-community==0.3.11) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4.0,>=0.3.11->langchain-community==0.3.11) (2.33.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4.0,>=0.3.11->langchain-community==0.3.11) (0.4.0)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community==0.3.11)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.3,>=0.1.125->langchain-community==0.3.11) (1.3.1)
# Downloading langchain_community-0.3.11-py3-none-any.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 38.1 MB/s eta 0:00:00
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading httpx_sse-0.4.0-py3-none-any.whl (7.8 kB)
# Downloading pydantic_settings-2.8.1-py3-none-any.whl (30 kB)
# Downloading marshmallow-3.26.1-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 3.7 MB/s eta 0:00:00
# Downloading python_dotenv-1.1.0-py3-none-any.whl (20 kB)
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: python-dotenv, mypy-extensions, marshmallow, httpx-sse, typing-inspect, pydantic-settings, dataclasses-json, langchain-community
# Successfully installed dataclasses-json-0.6.7 httpx-sse-0.4.0 langchain-community-0.3.11 marshmallow-3.26.1 mypy-extensions-1.0.0 pydantic-settings-2.8.1 python-dotenv-1.1.0 typing-inspect-0.9.0
# Collecting pyngrok==7.2.2
#   Downloading pyngrok-7.2.2-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: PyYAML>=5.1 in /usr/local/lib/python3.11/dist-packages (from pyngrok==7.2.2) (6.0.2)
# Downloading pyngrok-7.2.2-py3-none-any.whl (22 kB)
# Installing collected packages: pyngrok
# Successfully installed pyngrok-7.2.2
# Collecting PyMuPDF==1.24.0
#   Downloading PyMuPDF-1.24.0-cp311-none-manylinux2014_x86_64.whl.metadata (3.4 kB)
# Collecting PyMuPDFb==1.24.0 (from PyMuPDF==1.24.0)
#   Downloading PyMuPDFb-1.24.0-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.4 kB)
# Downloading PyMuPDF-1.24.0-cp311-none-manylinux2014_x86_64.whl (3.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.9/3.9 MB 35.3 MB/s eta 0:00:00
# Downloading PyMuPDFb-1.24.0-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (30.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.8/30.8 MB 50.1 MB/s eta 0:00:00
# Installing collected packages: PyMuPDFb, PyMuPDF
# Successfully installed PyMuPDF-1.24.0 PyMuPDFb-1.24.0
# Collecting chromadb==0.6.3
#   Downloading chromadb-0.6.3-py3-none-any.whl.metadata (6.8 kB)
# Collecting build>=1.0.3 (from chromadb==0.6.3)
#   Downloading build-1.2.2.post1-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: pydantic>=1.9 in /usr/local/lib/python3.11/dist-packages (from chromadb==0.6.3) (2.11.2)
# Collecting chroma-hnswlib==0.7.6 (from chromadb==0.6.3)
#   Downloading chroma_hnswlib-0.7.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (252 bytes)
# Collecting fastapi>=0.95.2 (from chromadb==0.6.3)
#   Downloading fastapi-0.115.12-py3-none-any.whl.metadata (27 kB)
# Collecting uvicorn>=0.18.3 (from uvicorn[standard]>=0.18.3->chromadb==0.6.3)
#   Downloading uvicorn-0.34.1-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: numpy>=1.22.5 in /usr/local/lib/python3.11/dist-packages (from chromadb==0.6.3) (1.26.4)
# Collecting posthog>=2.4.0 (from chromadb==0.6.3)
#   Downloading posthog-3.24.1-py2.py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: typing_extensions>=4.5.0 in /usr/local/lib/python3.11/dist-packages (from chromadb==0.6.3) (4.13.1)
# Collecting onnxruntime>=1.14.1 (from chromadb==0.6.3)
#   Downloading onnxruntime-1.21.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (4.5 kB)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from chromadb==0.6.3) (1.31.1)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0 (from chromadb==0.6.3)
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.32.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting opentelemetry-instrumentation-fastapi>=0.41b0 (from chromadb==0.6.3)
#   Downloading opentelemetry_instrumentation_fastapi-0.53b0-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from chromadb==0.6.3) (1.31.1)
# Requirement already satisfied: tokenizers>=0.13.2 in /usr/local/lib/python3.11/dist-packages (from chromadb==0.6.3) (0.21.1)
# Collecting pypika>=0.48.9 (from chromadb==0.6.3)
#   Downloading PyPika-0.48.9.tar.gz (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 3.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: tqdm>=4.65.0 in /usr/local/lib/python3.11/dist-packages (from chromadb==0.6.3) (4.67.1)
# Collecting overrides>=7.3.1 (from chromadb==0.6.3)
#   Downloading overrides-7.7.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.11/dist-packages (from chromadb==0.6.3) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in /usr/local/lib/python3.11/dist-packages (from chromadb==0.6.3) (1.71.0)
# Collecting bcrypt>=4.0.1 (from chromadb==0.6.3)
#   Downloading bcrypt-4.3.0-cp39-abi3-manylinux_2_34_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: typer>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from chromadb==0.6.3) (0.15.2)
# Collecting kubernetes>=28.1.0 (from chromadb==0.6.3)
#   Downloading kubernetes-32.0.1-py2.py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: tenacity>=8.2.3 in /usr/local/lib/python3.11/dist-packages (from chromadb==0.6.3) (9.1.2)
# Requirement already satisfied: PyYAML>=6.0.0 in /usr/local/lib/python3.11/dist-packages (from chromadb==0.6.3) (6.0.2)
# Collecting mmh3>=4.0.1 (from chromadb==0.6.3)
#   Downloading mmh3-5.1.0-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (16 kB)
# Requirement already satisfied: orjson>=3.9.12 in /usr/local/lib/python3.11/dist-packages (from chromadb==0.6.3) (3.10.16)
# Requirement already satisfied: httpx>=0.27.0 in /usr/local/lib/python3.11/dist-packages (from chromadb==0.6.3) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.11/dist-packages (from chromadb==0.6.3) (13.9.4)
# Requirement already satisfied: packaging>=19.1 in /usr/local/lib/python3.11/dist-packages (from build>=1.0.3->chromadb==0.6.3) (24.2)
# Collecting pyproject_hooks (from build>=1.0.3->chromadb==0.6.3)
#   Downloading pyproject_hooks-1.2.0-py3-none-any.whl.metadata (1.3 kB)
# Collecting starlette<0.47.0,>=0.40.0 (from fastapi>=0.95.2->chromadb==0.6.3)
#   Downloading starlette-0.46.2-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx>=0.27.0->chromadb==0.6.3) (4.9.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx>=0.27.0->chromadb==0.6.3) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx>=0.27.0->chromadb==0.6.3) (1.0.7)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from httpx>=0.27.0->chromadb==0.6.3) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx>=0.27.0->chromadb==0.6.3) (0.14.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb==0.6.3) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb==0.6.3) (2.8.2)
# Requirement already satisfied: google-auth>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb==0.6.3) (2.38.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb==0.6.3) (1.8.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb==0.6.3) (2.32.3)
# Requirement already satisfied: requests-oauthlib in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb==0.6.3) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb==0.6.3) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb==0.6.3) (2.3.0)
# Collecting durationpy>=0.7 (from kubernetes>=28.1.0->chromadb==0.6.3)
#   Downloading durationpy-0.9-py3-none-any.whl.metadata (338 bytes)
# Collecting coloredlogs (from onnxruntime>=1.14.1->chromadb==0.6.3)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.11/dist-packages (from onnxruntime>=1.14.1->chromadb==0.6.3) (25.2.10)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.11/dist-packages (from onnxruntime>=1.14.1->chromadb==0.6.3) (5.29.4)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from onnxruntime>=1.14.1->chromadb==0.6.3) (1.13.1)
# Requirement already satisfied: deprecated>=1.2.6 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-api>=1.2.0->chromadb==0.6.3) (1.2.18)
# Requirement already satisfied: importlib-metadata<8.7.0,>=6.0 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-api>=1.2.0->chromadb==0.6.3) (8.6.1)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb==0.6.3) (1.69.2)
# Collecting opentelemetry-exporter-otlp-proto-common==1.32.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb==0.6.3)
#   Downloading opentelemetry_exporter_otlp_proto_common-1.32.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting opentelemetry-proto==1.32.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb==0.6.3)
#   Downloading opentelemetry_proto-1.32.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting opentelemetry-sdk>=1.2.0 (from chromadb==0.6.3)
#   Downloading opentelemetry_sdk-1.32.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting opentelemetry-instrumentation-asgi==0.53b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb==0.6.3)
#   Downloading opentelemetry_instrumentation_asgi-0.53b0-py3-none-any.whl.metadata (2.1 kB)
# Collecting opentelemetry-instrumentation==0.53b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb==0.6.3)
#   Downloading opentelemetry_instrumentation-0.53b0-py3-none-any.whl.metadata (6.8 kB)
# Collecting opentelemetry-semantic-conventions==0.53b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb==0.6.3)
#   Downloading opentelemetry_semantic_conventions-0.53b0-py3-none-any.whl.metadata (2.5 kB)
# Collecting opentelemetry-util-http==0.53b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb==0.6.3)
#   Downloading opentelemetry_util_http-0.53b0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-instrumentation==0.53b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb==0.6.3) (1.17.2)
# Collecting asgiref~=3.0 (from opentelemetry-instrumentation-asgi==0.53b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb==0.6.3)
#   Downloading asgiref-3.8.1-py3-none-any.whl.metadata (9.3 kB)
# Collecting opentelemetry-api>=1.2.0 (from chromadb==0.6.3)
#   Downloading opentelemetry_api-1.32.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting monotonic>=1.5 (from posthog>=2.4.0->chromadb==0.6.3)
#   Downloading monotonic-1.6-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting backoff>=1.10.0 (from posthog>=2.4.0->chromadb==0.6.3)
#   Downloading backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: distro>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from posthog>=2.4.0->chromadb==0.6.3) (1.9.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=1.9->chromadb==0.6.3) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in /usr/local/lib/python3.11/dist-packages (from pydantic>=1.9->chromadb==0.6.3) (2.33.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=1.9->chromadb==0.6.3) (0.4.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->chromadb==0.6.3) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->chromadb==0.6.3) (2.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.11/dist-packages (from tokenizers>=0.13.2->chromadb==0.6.3) (0.30.1)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from typer>=0.9.0->chromadb==0.6.3) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer>=0.9.0->chromadb==0.6.3) (1.5.4)
# Collecting httptools>=0.6.3 (from uvicorn[standard]>=0.18.3->chromadb==0.6.3)
#   Downloading httptools-0.6.4-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.6 kB)
# Requirement already satisfied: python-dotenv>=0.13 in /usr/local/lib/python3.11/dist-packages (from uvicorn[standard]>=0.18.3->chromadb==0.6.3) (1.1.0)
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0 (from uvicorn[standard]>=0.18.3->chromadb==0.6.3)
#   Downloading uvloop-0.21.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.18.3->chromadb==0.6.3)
#   Downloading watchfiles-1.0.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Requirement already satisfied: websockets>=10.4 in /usr/local/lib/python3.11/dist-packages (from uvicorn[standard]>=0.18.3->chromadb==0.6.3) (15.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb==0.6.3) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb==0.6.3) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb==0.6.3) (4.9)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb==0.6.3) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb==0.6.3) (2025.3.2)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib-metadata<8.7.0,>=6.0->opentelemetry-api>=1.2.0->chromadb==0.6.3) (3.21.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb==0.6.3) (0.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->kubernetes>=28.1.0->chromadb==0.6.3) (3.4.1)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx>=0.27.0->chromadb==0.6.3) (1.3.1)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime>=1.14.1->chromadb==0.6.3)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->onnxruntime>=1.14.1->chromadb==0.6.3) (1.3.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb==0.6.3) (0.6.1)
# Downloading chromadb-0.6.3-py3-none-any.whl (611 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 611.1/611.1 kB 20.1 MB/s eta 0:00:00
# Downloading chroma_hnswlib-0.7.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 65.1 MB/s eta 0:00:00
# Downloading bcrypt-4.3.0-cp39-abi3-manylinux_2_34_x86_64.whl (284 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 284.2/284.2 kB 20.2 MB/s eta 0:00:00
# Downloading build-1.2.2.post1-py3-none-any.whl (22 kB)
# Downloading fastapi-0.115.12-py3-none-any.whl (95 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.2/95.2 kB 6.7 MB/s eta 0:00:00
# Downloading kubernetes-32.0.1-py2.py3-none-any.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 68.7 MB/s eta 0:00:00
# Downloading mmh3-5.1.0-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (101 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.6/101.6 kB 7.8 MB/s eta 0:00:00
# Downloading onnxruntime-1.21.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 84.6 MB/s eta 0:00:00
# Downloading opentelemetry_exporter_otlp_proto_grpc-1.32.0-py3-none-any.whl (18 kB)
# Downloading opentelemetry_exporter_otlp_proto_common-1.32.0-py3-none-any.whl (18 kB)
# Downloading opentelemetry_proto-1.32.0-py3-none-any.whl (55 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.9/55.9 kB 3.7 MB/s eta 0:00:00
# Downloading opentelemetry_instrumentation_fastapi-0.53b0-py3-none-any.whl (12 kB)
# Downloading opentelemetry_instrumentation-0.53b0-py3-none-any.whl (30 kB)
# Downloading opentelemetry_instrumentation_asgi-0.53b0-py3-none-any.whl (16 kB)
# Downloading opentelemetry_semantic_conventions-0.53b0-py3-none-any.whl (188 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.4/188.4 kB 12.7 MB/s eta 0:00:00
# Downloading opentelemetry_api-1.32.0-py3-none-any.whl (65 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.3/65.3 kB 4.7 MB/s eta 0:00:00
# Downloading opentelemetry_util_http-0.53b0-py3-none-any.whl (7.3 kB)
# Downloading opentelemetry_sdk-1.32.0-py3-none-any.whl (118 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.0/119.0 kB 9.4 MB/s eta 0:00:00
# Downloading overrides-7.7.0-py3-none-any.whl (17 kB)
# Downloading posthog-3.24.1-py2.py3-none-any.whl (85 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.7/85.7 kB 6.4 MB/s eta 0:00:00
# Downloading uvicorn-0.34.1-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.4/62.4 kB 5.0 MB/s eta 0:00:00
# Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Downloading durationpy-0.9-py3-none-any.whl (3.5 kB)
# Downloading httptools-0.6.4-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (459 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 459.8/459.8 kB 25.9 MB/s eta 0:00:00
# Downloading monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Downloading starlette-0.46.2-py3-none-any.whl (72 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 6.1 MB/s eta 0:00:00
# Downloading uvloop-0.21.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 56.9 MB/s eta 0:00:00
# Downloading watchfiles-1.0.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (454 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 454.8/454.8 kB 26.7 MB/s eta 0:00:00
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 3.2 MB/s eta 0:00:00
# Downloading pyproject_hooks-1.2.0-py3-none-any.whl (10 kB)
# Downloading asgiref-3.8.1-py3-none-any.whl (23 kB)
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 6.4 MB/s eta 0:00:00
# Building wheels for collected packages: pypika
#   Building wheel for pypika (pyproject.toml) ... done
#   Created wheel for pypika: filename=pypika-0.48.9-py2.py3-none-any.whl size=53800 sha256=999eb498851103062fc2b5d4255e7b21f769c1cecd144d146378179b2686dd4b
#   Stored in directory: /root/.cache/pip/wheels/a3/01/bd/4c40ceb9d5354160cb186dcc153360f4ab7eb23e2b24daf96d
# Successfully built pypika
# Installing collected packages: pypika, monotonic, durationpy, uvloop, uvicorn, pyproject_hooks, overrides, opentelemetry-util-http, opentelemetry-proto, mmh3, humanfriendly, httptools, chroma-hnswlib, bcrypt, backoff, asgiref, watchfiles, starlette, posthog, opentelemetry-exporter-otlp-proto-common, opentelemetry-api, coloredlogs, build, opentelemetry-semantic-conventions, onnxruntime, kubernetes, fastapi, opentelemetry-sdk, opentelemetry-instrumentation, opentelemetry-instrumentation-asgi, opentelemetry-exporter-otlp-proto-grpc, opentelemetry-instrumentation-fastapi, chromadb
#   Attempting uninstall: opentelemetry-api
#     Found existing installation: opentelemetry-api 1.31.1
#     Uninstalling opentelemetry-api-1.31.1:
#       Successfully uninstalled opentelemetry-api-1.31.1
#   Attempting uninstall: opentelemetry-semantic-conventions
#     Found existing installation: opentelemetry-semantic-conventions 0.52b1
#     Uninstalling opentelemetry-semantic-conventions-0.52b1:
#       Successfully uninstalled opentelemetry-semantic-conventions-0.52b1
#   Attempting uninstall: opentelemetry-sdk
#     Found existing installation: opentelemetry-sdk 1.31.1
#     Uninstalling opentelemetry-sdk-1.31.1:
#       Successfully uninstalled opentelemetry-sdk-1.31.1
# Successfully installed asgiref-3.8.1 backoff-2.2.1 bcrypt-4.3.0 build-1.2.2.post1 chroma-hnswlib-0.7.6 chromadb-0.6.3 coloredlogs-15.0.1 durationpy-0.9 fastapi-0.115.12 httptools-0.6.4 humanfriendly-10.0 kubernetes-32.0.1 mmh3-5.1.0 monotonic-1.6 onnxruntime-1.21.0 opentelemetry-api-1.32.0 opentelemetry-exporter-otlp-proto-common-1.32.0 opentelemetry-exporter-otlp-proto-grpc-1.32.0 opentelemetry-instrumentation-0.53b0 opentelemetry-instrumentation-asgi-0.53b0 opentelemetry-instrumentation-fastapi-0.53b0 opentelemetry-proto-1.32.0 opentelemetry-sdk-1.32.0 opentelemetry-semantic-conventions-0.53b0 opentelemetry-util-http-0.53b0 overrides-7.7.0 posthog-3.24.1 pypika-0.48.9 pyproject_hooks-1.2.0 starlette-0.46.2 uvicorn-0.34.1 uvloop-0.21.0 watchfiles-1.0.5
# Collecting pydantic==2.10.1
#   Downloading pydantic-2.10.1-py3-none-any.whl.metadata (169 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 169.7/169.7 kB 5.2 MB/s eta 0:00:00
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic==2.10.1) (0.7.0)
# Collecting pydantic-core==2.27.1 (from pydantic==2.10.1)
#   Downloading pydantic_core-2.27.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.11/dist-packages (from pydantic==2.10.1) (4.13.1)
# Downloading pydantic-2.10.1-py3-none-any.whl (455 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 455.3/455.3 kB 16.7 MB/s eta 0:00:00
# Downloading pydantic_core-2.27.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 55.3 MB/s eta 0:00:00
# Installing collected packages: pydantic-core, pydantic
#   Attempting uninstall: pydantic-core
#     Found existing installation: pydantic_core 2.33.1
#     Uninstalling pydantic_core-2.33.1:
#       Successfully uninstalled pydantic_core-2.33.1
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.11.2
#     Uninstalling pydantic-2.11.2:
#       Successfully uninstalled pydantic-2.11.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# Successfully installed pydantic-2.10.1 pydantic-core-2.27.1
# Collecting langchain-chroma==0.2.2
#   Downloading langchain_chroma-0.2.2-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.2,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43 in /usr/local/lib/python3.11/dist-packages (from langchain-chroma==0.2.2) (0.3.51)
# Requirement already satisfied: numpy<2.0.0,>=1.22.4 in /usr/local/lib/python3.11/dist-packages (from langchain-chroma==0.2.2) (1.26.4)
# Requirement already satisfied: chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from langchain-chroma==0.2.2) (0.6.3)
# Requirement already satisfied: build>=1.0.3 in /usr/local/lib/python3.11/dist-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (1.2.2.post1)
# Requirement already satisfied: pydantic>=1.9 in /usr/local/lib/python3.11/dist-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (2.10.1)
# Requirement already satisfied: chroma-hnswlib==0.7.6 in /usr/local/lib/python3.11/dist-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (0.7.6)
# ...
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx>=0.27.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx>=0.27.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (1.0.7)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from httpx>=0.27.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx>=0.27.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.11/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.2,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langchain-chroma==0.2.2) (3.0.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (2.8.2)
# Requirement already satisfied: google-auth>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (2.38.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (1.8.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (2.32.3)
# Requirement already satisfied: requests-oauthlib in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (2.3.0)
# Requirement already satisfied: durationpy>=0.7 in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (0.9)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.125->langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.2,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langchain-chroma==0.2.2) (1.0.0)
# Requirement already satisfied: coloredlogs in /usr/local/lib/python3.11/dist-packages (from onnxruntime>=1.14.1->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (15.0.1)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.11/dist-packages (from onnxruntime>=1.14.1->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (25.2.10)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.11/dist-packages (from onnxruntime>=1.14.1->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (5.29.4)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from onnxruntime>=1.14.1->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (1.13.1)
# Requirement already satisfied: deprecated>=1.2.6 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-api>=1.2.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (1.2.18)
# Requirement already satisfied: importlib-metadata<8.7.0,>=6.0 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-api>=1.2.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (8.6.1)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (1.69.2)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.32.0 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (1.32.0)
# Requirement already satisfied: opentelemetry-proto==1.32.0 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (1.32.0)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.53b0 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (0.53b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.53b0 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (0.53b0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.53b0 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (0.53b0)
# Requirement already satisfied: opentelemetry-util-http==0.53b0 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (0.53b0)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-instrumentation==0.53b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (1.17.2)
# Requirement already satisfied: asgiref~=3.0 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-instrumentation-asgi==0.53b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (3.8.1)
# Requirement already satisfied: monotonic>=1.5 in /usr/local/lib/python3.11/dist-packages (from posthog>=2.4.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in /usr/local/lib/python3.11/dist-packages (from posthog>=2.4.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from posthog>=2.4.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (1.9.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=1.9->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /usr/local/lib/python3.11/dist-packages (from pydantic>=1.9->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (2.27.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (2.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.11/dist-packages (from tokenizers>=0.13.2->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (0.30.1)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from typer>=0.9.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer>=0.9.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in /usr/local/lib/python3.11/dist-packages (from uvicorn[standard]>=0.18.3->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (0.6.4)
# Requirement already satisfied: python-dotenv>=0.13 in /usr/local/lib/python3.11/dist-packages (from uvicorn[standard]>=0.18.3->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (1.1.0)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /usr/local/lib/python3.11/dist-packages (from uvicorn[standard]>=0.18.3->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (0.21.0)
# Requirement already satisfied: watchfiles>=0.13 in /usr/local/lib/python3.11/dist-packages (from uvicorn[standard]>=0.18.3->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (1.0.5)
# Requirement already satisfied: websockets>=10.4 in /usr/local/lib/python3.11/dist-packages (from uvicorn[standard]>=0.18.3->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (15.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (4.9)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (2025.3.2)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib-metadata<8.7.0,>=6.0->opentelemetry-api>=1.2.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (3.21.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (0.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (3.4.1)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx>=0.27.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (1.3.1)
# Requirement already satisfied: humanfriendly>=9.1 in /usr/local/lib/python3.11/dist-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->onnxruntime>=1.14.1->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (1.3.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma==0.2.2) (0.6.1)
# Downloading langchain_chroma-0.2.2-py3-none-any.whl (11 kB)
# Installing collected packages: langchain-chroma
# Successfully installed langchain-chroma-0.2.2
# Collecting numpy==1.24.3
#   Downloading numpy-1.24.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.6 kB)
# Downloading numpy-1.24.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 68.2 MB/s eta 0:00:00
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# blosc2 3.2.1 requires numpy>=1.26, but you have numpy 1.24.3 which is incompatible.
# jaxlib 0.5.1 requires numpy>=1.25, but you have numpy 1.24.3 which is incompatible.
# pymc 5.21.2 requires numpy>=1.25.0, but you have numpy 1.24.3 which is incompatible.
# jax 0.5.2 requires numpy>=1.25, but you have numpy 1.24.3 which is incompatible.
# treescope 0.1.9 requires numpy>=1.25.2, but you have numpy 1.24.3 which is incompatible.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.24.3 which is incompatible.
# tensorflow 2.18.0 requires numpy<2.1.0,>=1.26.0, but you have numpy 1.24.3 which is incompatible.
# albumentations 2.0.5 requires numpy>=1.24.4, but you have numpy 1.24.3 which is incompatible.
# albucore 0.0.23 requires numpy>=1.24.4, but you have numpy 1.24.3 which is incompatible.
# Successfully installed numpy-1.24.3

# %% [markdown]
# ## Install RAG Evaluation Libraries

# %%
# !pip install ragas==0.2.3
# !pip install deepeval==1.4.7
# Out:
# Collecting ragas==0.2.3
#   Downloading ragas-0.2.3-py3-none-any.whl.metadata (7.9 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from ragas==0.2.3) (1.24.3)
# Requirement already satisfied: datasets in /usr/local/lib/python3.11/dist-packages (from ragas==0.2.3) (3.5.0)
# Requirement already satisfied: tiktoken in /usr/local/lib/python3.11/dist-packages (from ragas==0.2.3) (0.9.0)
# Requirement already satisfied: langchain in /usr/local/lib/python3.11/dist-packages (from ragas==0.2.3) (0.3.11)
# Requirement already satisfied: langchain-core in /usr/local/lib/python3.11/dist-packages (from ragas==0.2.3) (0.3.51)
# Requirement already satisfied: langchain-community in /usr/local/lib/python3.11/dist-packages (from ragas==0.2.3) (0.3.11)
# Requirement already satisfied: langchain-openai in /usr/local/lib/python3.11/dist-packages (from ragas==0.2.3) (0.3.12)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.11/dist-packages (from ragas==0.2.3) (1.6.0)
# Requirement already satisfied: appdirs in /usr/local/lib/python3.11/dist-packages (from ragas==0.2.3) (1.4.4)
# Requirement already satisfied: pydantic>=2 in /usr/local/lib/python3.11/dist-packages (from ragas==0.2.3) (2.10.1)
# Requirement already satisfied: openai>1 in /usr/local/lib/python3.11/dist-packages (from ragas==0.2.3) (1.70.0)
# Collecting pysbd>=0.3.4 (from ragas==0.2.3)
#   Downloading pysbd-0.3.4-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from openai>1->ragas==0.2.3) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from openai>1->ragas==0.2.3) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from openai>1->ragas==0.2.3) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from openai>1->ragas==0.2.3) (0.9.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from openai>1->ragas==0.2.3) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.11/dist-packages (from openai>1->ragas==0.2.3) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.11/dist-packages (from openai>1->ragas==0.2.3) (4.13.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2->ragas==0.2.3) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2->ragas==0.2.3) (2.27.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from datasets->ragas==0.2.3) (3.18.0)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets->ragas==0.2.3) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from datasets->ragas==0.2.3) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets->ragas==0.2.3) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.11/dist-packages (from datasets->ragas==0.2.3) (2.32.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from datasets->ragas==0.2.3) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.11/dist-packages (from datasets->ragas==0.2.3) (0.70.16)
# Requirement already satisfied: fsspec<=2024.12.0,>=2023.1.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<=2024.12.0,>=2023.1.0->datasets->ragas==0.2.3) (2024.12.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets->ragas==0.2.3) (3.11.15)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from datasets->ragas==0.2.3) (0.30.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from datasets->ragas==0.2.3) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets->ragas==0.2.3) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.11/dist-packages (from langchain->ragas==0.2.3) (2.0.40)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from langchain->ragas==0.2.3) (0.3.8)
# Requirement already satisfied: langsmith<0.3,>=0.1.17 in /usr/local/lib/python3.11/dist-packages (from langchain->ragas==0.2.3) (0.2.11)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /usr/local/lib/python3.11/dist-packages (from langchain->ragas==0.2.3) (8.4.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.11/dist-packages (from langchain-core->ragas==0.2.3) (1.33)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /usr/local/lib/python3.11/dist-packages (from langchain-community->ragas==0.2.3) (0.6.7)
# Requirement already satisfied: httpx-sse<0.5.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from langchain-community->ragas==0.2.3) (0.4.0)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in /usr/local/lib/python3.11/dist-packages (from langchain-community->ragas==0.2.3) (2.8.1)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.11/dist-packages (from tiktoken->ragas==0.2.3) (2024.11.6)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets->ragas==0.2.3) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets->ragas==0.2.3) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets->ragas==0.2.3) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets->ragas==0.2.3) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets->ragas==0.2.3) (6.3.2)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets->ragas==0.2.3) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets->ragas==0.2.3) (1.18.3)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.5.0->openai>1->ragas==0.2.3) (3.10)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.11/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community->ragas==0.2.3) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community->ragas==0.2.3) (0.9.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai>1->ragas==0.2.3) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai>1->ragas==0.2.3) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai>1->ragas==0.2.3) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.11/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core->ragas==0.2.3) (3.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.3,>=0.1.17->langchain->ragas==0.2.3) (3.10.16)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.3,>=0.1.17->langchain->ragas==0.2.3) (1.0.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.11/dist-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community->ragas==0.2.3) (1.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets->ragas==0.2.3) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets->ragas==0.2.3) (2.3.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from SQLAlchemy<3,>=1.4->langchain->ragas==0.2.3) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets->ragas==0.2.3) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets->ragas==0.2.3) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets->ragas==0.2.3) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets->ragas==0.2.3) (1.17.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community->ragas==0.2.3) (1.0.0)
# Downloading ragas-0.2.3-py3-none-any.whl (141 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.9/141.9 kB 3.2 MB/s eta 0:00:00
# Downloading pysbd-0.3.4-py3-none-any.whl (71 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.1/71.1 kB 4.2 MB/s eta 0:00:00
# Installing collected packages: pysbd, ragas
#   Attempting uninstall: ragas
#     Found existing installation: ragas 0.2.14
#     Uninstalling ragas-0.2.14:
#       Successfully uninstalled ragas-0.2.14
# Successfully installed pysbd-0.3.4 ragas-0.2.3
# Requirement already satisfied: deepeval==1.4.7 in /usr/local/lib/python3.11/dist-packages (1.4.7)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from deepeval==1.4.7) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from deepeval==1.4.7) (4.67.1)
# Requirement already satisfied: pytest in /usr/local/lib/python3.11/dist-packages (from deepeval==1.4.7) (8.3.5)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.11/dist-packages (from deepeval==1.4.7) (0.9.0)
# Requirement already satisfied: typer in /usr/local/lib/python3.11/dist-packages (from deepeval==1.4.7) (0.15.2)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from deepeval==1.4.7) (13.9.4)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.11/dist-packages (from deepeval==1.4.7) (4.25.6)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.11/dist-packages (from deepeval==1.4.7) (2.10.1)
# Requirement already satisfied: sentry-sdk in /usr/local/lib/python3.11/dist-packages (from deepeval==1.4.7) (2.25.1)
# Requirement already satisfied: pytest-repeat in /usr/local/lib/python3.11/dist-packages (from deepeval==1.4.7) (0.9.4)
# Requirement already satisfied: pytest-xdist in /usr/local/lib/python3.11/dist-packages (from deepeval==1.4.7) (3.6.1)
# Requirement already satisfied: portalocker in /usr/local/lib/python3.11/dist-packages (from deepeval==1.4.7) (3.1.1)
# Requirement already satisfied: langchain in /usr/local/lib/python3.11/dist-packages (from deepeval==1.4.7) (0.3.11)
# Requirement already satisfied: langchain-core in /usr/local/lib/python3.11/dist-packages (from deepeval==1.4.7) (0.3.51)
# Requirement already satisfied: langchain-openai in /usr/local/lib/python3.11/dist-packages (from deepeval==1.4.7) (0.3.12)
# Requirement already satisfied: ragas in /usr/local/lib/python3.11/dist-packages (from deepeval==1.4.7) (0.2.3)
# Requirement already satisfied: docx2txt~=0.8 in /usr/local/lib/python3.11/dist-packages (from deepeval==1.4.7) (0.9)
# Requirement already satisfied: importlib-metadata>=6.0.2 in /usr/local/lib/python3.11/dist-packages (from deepeval==1.4.7) (7.0.0)
# Requirement already satisfied: tenacity~=8.4.1 in /usr/local/lib/python3.11/dist-packages (from deepeval==1.4.7) (8.4.2)
# Requirement already satisfied: opentelemetry-api~=1.24.0 in /usr/local/lib/python3.11/dist-packages (from deepeval==1.4.7) (1.24.0)
# Requirement already satisfied: opentelemetry-sdk~=1.24.0 in /usr/local/lib/python3.11/dist-packages (from deepeval==1.4.7) (1.24.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc~=1.24.0 in /usr/local/lib/python3.11/dist-packages (from deepeval==1.4.7) (1.24.0)
# Requirement already satisfied: grpcio~=1.63.0 in /usr/local/lib/python3.11/dist-packages (from deepeval==1.4.7) (1.63.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.11/dist-packages (from importlib-metadata>=6.0.2->deepeval==1.4.7) (3.21.0)
# Requirement already satisfied: deprecated>=1.2.6 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-api~=1.24.0->deepeval==1.4.7) (1.2.18)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-exporter-otlp-proto-grpc~=1.24.0->deepeval==1.4.7) (1.69.2)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.24.0 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-exporter-otlp-proto-grpc~=1.24.0->deepeval==1.4.7) (1.24.0)
# Requirement already satisfied: opentelemetry-proto==1.24.0 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-exporter-otlp-proto-grpc~=1.24.0->deepeval==1.4.7) (1.24.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.45b0 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-sdk~=1.24.0->deepeval==1.4.7) (0.45b0)
# Requirement already satisfied: typing-extensions>=3.7.4 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-sdk~=1.24.0->deepeval==1.4.7) (4.13.1)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.11/dist-packages (from langchain->deepeval==1.4.7) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.11/dist-packages (from langchain->deepeval==1.4.7) (2.0.40)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.11/dist-packages (from langchain->deepeval==1.4.7) (3.11.15)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from langchain->deepeval==1.4.7) (0.3.8)
# Requirement already satisfied: langsmith<0.3,>=0.1.17 in /usr/local/lib/python3.11/dist-packages (from langchain->deepeval==1.4.7) (0.2.11)
# Requirement already satisfied: numpy<2,>=1.22.4 in /usr/local/lib/python3.11/dist-packages (from langchain->deepeval==1.4.7) (1.24.3)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.11/dist-packages (from langchain-core->deepeval==1.4.7) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.11/dist-packages (from langchain-core->deepeval==1.4.7) (24.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic->deepeval==1.4.7) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /usr/local/lib/python3.11/dist-packages (from pydantic->deepeval==1.4.7) (2.27.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->deepeval==1.4.7) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->deepeval==1.4.7) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->deepeval==1.4.7) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->deepeval==1.4.7) (2025.1.31)
# Requirement already satisfied: openai<2.0.0,>=1.68.2 in /usr/local/lib/python3.11/dist-packages (from langchain-openai->deepeval==1.4.7) (1.70.0)
# Requirement already satisfied: tiktoken<1,>=0.7 in /usr/local/lib/python3.11/dist-packages (from langchain-openai->deepeval==1.4.7) (0.9.0)
# Requirement already satisfied: iniconfig in /usr/local/lib/python3.11/dist-packages (from pytest->deepeval==1.4.7) (2.1.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /usr/local/lib/python3.11/dist-packages (from pytest->deepeval==1.4.7) (1.5.0)
# Requirement already satisfied: execnet>=2.1 in /usr/local/lib/python3.11/dist-packages (from pytest-xdist->deepeval==1.4.7) (2.1.1)
# Requirement already satisfied: datasets in /usr/local/lib/python3.11/dist-packages (from ragas->deepeval==1.4.7) (3.5.0)
# Requirement already satisfied: langchain-community in /usr/local/lib/python3.11/dist-packages (from ragas->deepeval==1.4.7) (0.3.11)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.11/dist-packages (from ragas->deepeval==1.4.7) (1.6.0)
# Requirement already satisfied: appdirs in /usr/local/lib/python3.11/dist-packages (from ragas->deepeval==1.4.7) (1.4.4)
# Requirement already satisfied: pysbd>=0.3.4 in /usr/local/lib/python3.11/dist-packages (from ragas->deepeval==1.4.7) (0.3.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->deepeval==1.4.7) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->deepeval==1.4.7) (2.18.0)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from typer->deepeval==1.4.7) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer->deepeval==1.4.7) (1.5.4)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain->deepeval==1.4.7) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain->deepeval==1.4.7) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain->deepeval==1.4.7) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain->deepeval==1.4.7) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain->deepeval==1.4.7) (6.3.2)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain->deepeval==1.4.7) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain->deepeval==1.4.7) (1.18.3)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.11/dist-packages (from deprecated>=1.2.6->opentelemetry-api~=1.24.0->deepeval==1.4.7) (1.17.2)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.11/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core->deepeval==1.4.7) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.3,>=0.1.17->langchain->deepeval==1.4.7) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.3,>=0.1.17->langchain->deepeval==1.4.7) (3.10.16)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.3,>=0.1.17->langchain->deepeval==1.4.7) (1.0.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->deepeval==1.4.7) (0.1.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from openai<2.0.0,>=1.68.2->langchain-openai->deepeval==1.4.7) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from openai<2.0.0,>=1.68.2->langchain-openai->deepeval==1.4.7) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from openai<2.0.0,>=1.68.2->langchain-openai->deepeval==1.4.7) (0.9.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from openai<2.0.0,>=1.68.2->langchain-openai->deepeval==1.4.7) (1.3.1)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from SQLAlchemy<3,>=1.4->langchain->deepeval==1.4.7) (3.1.1)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.11/dist-packages (from tiktoken<1,>=0.7->langchain-openai->deepeval==1.4.7) (2024.11.6)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from datasets->ragas->deepeval==1.4.7) (3.18.0)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets->ragas->deepeval==1.4.7) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from datasets->ragas->deepeval==1.4.7) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets->ragas->deepeval==1.4.7) (2.2.2)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from datasets->ragas->deepeval==1.4.7) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.11/dist-packages (from datasets->ragas->deepeval==1.4.7) (0.70.16)
# Requirement already satisfied: fsspec<=2024.12.0,>=2023.1.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<=2024.12.0,>=2023.1.0->datasets->ragas->deepeval==1.4.7) (2024.12.0)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from datasets->ragas->deepeval==1.4.7) (0.30.1)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /usr/local/lib/python3.11/dist-packages (from langchain-community->ragas->deepeval==1.4.7) (0.6.7)
# Requirement already satisfied: httpx-sse<0.5.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from langchain-community->ragas->deepeval==1.4.7) (0.4.0)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in /usr/local/lib/python3.11/dist-packages (from langchain-community->ragas->deepeval==1.4.7) (2.8.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.11/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community->ragas->deepeval==1.4.7) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community->ragas->deepeval==1.4.7) (0.9.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain->deepeval==1.4.7) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain->deepeval==1.4.7) (0.14.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.11/dist-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community->ragas->deepeval==1.4.7) (1.1.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets->ragas->deepeval==1.4.7) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets->ragas->deepeval==1.4.7) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets->ragas->deepeval==1.4.7) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets->ragas->deepeval==1.4.7) (1.17.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community->ragas->deepeval==1.4.7) (1.0.0)

# %% [markdown]
# ## Load Gemini API Credentials
#
# Here we load it from a secret keys of Colab so we don't expose the credentials on the internet by mistake

# %%
import os
from google.colab import userdata

os.environ['GOOGLE_API_KEY'] = userdata.get('GEMINI_API_KEY')

# %% [markdown]
# ## Load Necessary Dependencies and Gemini LLM

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_google_genai import ChatGoogleGenerativeAI

gemini_model = ChatGoogleGenerativeAI(model="gemini-2.0-flash", convert_system_message_to_human=True)

# %% [markdown]
# ## Build a Conversational Text Chatbot App

# %%
# Import necessary components from the LangChain library.
from langchain.memory import ConversationBufferWindowMemory
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain_core.runnables import RunnableLambda, RunnablePassthrough
from operator import itemgetter

# %%
from langchain_core.callbacks.base import BaseCallbackHandler
from langchain.schema.runnable.config import RunnableConfig
from langchain_community.document_loaders import PyMuPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_google_genai import GoogleGenerativeAIEmbeddings
from langchain.schema import StrOutputParser
from langchain_community.vectorstores.chroma import Chroma
from langchain_community.document_loaders.csv_loader import CSVLoader
from operator import itemgetter
import chromadb
import tempfile
import os
import pandas as pd

# %%
docs = []
docs_path = "/content/"

if not os.path.exists(docs_path):
    os.makedirs(docs_path)

for file in os.listdir(docs_path):
    if file.endswith(".pdf"):
        # print(file)
        loader = PyMuPDFLoader(os.path.join(docs_path, file))
        #loader = CSVLoader(file_path=os.path.join(docs_path, file))
        docs.extend(loader.load())




data = loader.load()

print(data)

if docs:
    text_splitter = RecursiveCharacterTextSplitter(chunk_size=1500,
                                                 chunk_overlap=200)
    chunks = text_splitter.split_documents(docs)
    embeddings = GoogleGenerativeAIEmbeddings(model="models/text-embedding-004")
    client = chromadb.PersistentClient(path="./chroma_db")
    # Use Chroma from LangChain
    vectordb = Chroma.from_documents(
        documents=chunks,
        embedding=embeddings,
        client=client,
        collection_name="document_collection"
    )

    # Define retriever object
    retriever = vectordb.as_retriever(search_kwargs={"k": 3})
# Out:
# /usr/local/lib/python3.11/dist-packages/langchain_community/document_loaders/parsers/pdf.py:300: UserWarning: Warning: Empty content on page 7 of document /content/farmerbook-1-20.pdf
#   warnings.warn(
# [Document(metadata={'source': '/content/farmerbook-1-20.pdf', 'file_path': '/content/farmerbook-1-20.pdf', 'page': 0, 'total_pages': 20, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'creator': '', 'producer': 'iLovePDF', 'creationDate': '', 'modDate': 'D:20250408072807Z', 'trapped': ''}, page_content='A holistic  \nperspective of  \nscientific  \nagriculture\nA joint initiative to  \nimpart farmers with \ntechnical knowledge on \nbasic agriculture.\nFarmer’s Handbook on Basic Agriculture\n'), Document(metadata={'source': '/content/farmerbook-1-20.pdf', 'file_path': '/content/farmerbook-1-20.pdf', 'page': 1, 'total_pages': 20, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'creator': '', 'producer': 'iLovePDF', 'creationDate': '', 'modDate': 'D:20250408072807Z', 'trapped': ''}, page_content='Disclaimer:\nThe opinions expressed provided in this publication are those of the authors and do not necessarily reflect those of  GIZ . The \ndesignations employed and the presentation of material in this publication do not imply the expression of any opinion what-\nsoever on the part of  GIZ  concerning the legal status of any country, territory, city or area, or concerning the delimitation of \nits frontiers or boundaries.\n'), Document(metadata={'source': '/content/farmerbook-1-20.pdf', 'file_path': '/content/farmerbook-1-20.pdf', 'page': 2, 'total_pages': 20, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'creator': '', 'producer': 'iLovePDF', 'creationDate': '', 'modDate': 'D:20250408072807Z', 'trapped': ''}, page_content=' \nFarmer’s Handbook on Basic Agriculture\nFarmer’s Handbook on Basic Agriculture\nPrepared & compiled by\nDr. P. Chandra Shekara\nNational Institute of Agricultural Extension  \nManagement (MANAGE)\nMinistry of Agriculture, GoI\nHyderabad, Andhra Pradesh\nIndia\nDr. N. Balasubramani\nNational Institute of Agricultural Extension  \nManagement (MANAGE)\nMinistry of Agriculture, GoI \nHyderabad, Andhra Pradesh\nIndia\nDr. Rajeev Sharma\nDr. Chitra Shukla\nDesai Fruits & Vegetables Pvt. Ltd.\nNavsari, Gujarat\nIndia\nDr. Ajit Kumar\nDesai Fruits & Vegetables Pvt. Ltd.\nNavsari, Gujarat \nIndia\nBakul C. Chaudhary\nDesai Fruits & Vegetables Pvt. Ltd.\nNavsari, Gujarat \nIndia\nMr. Max Baumann\nPlanning Officer\nSection “Agricultural Production & Resource Use”\nDivision 45 - Rural Development and Agriculture\nDeutsche Gesellschaft für Internationale Zusam-\nmenarbeit (GIZ) GmbH\nGermany\nMax.Baumann@giz.de\nFinanced by\nDesai Fruits & Vegetables Pvt. Ltd.\nNavsari, Gujarat, India\nGerman Federal Ministry for Economic Cooperation \nand Development (BMZ)\nPublished by\nDesai Fruits & Vegetables Pvt. Ltd.\nNavsari, Gujarat\nIndia\nSecond Edition: August 2016\n'), Document(metadata={'source': '/content/farmerbook-1-20.pdf', 'file_path': '/content/farmerbook-1-20.pdf', 'page': 3, 'total_pages': 20, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'creator': '', 'producer': 'iLovePDF', 'creationDate': '', 'modDate': 'D:20250408072807Z', 'trapped': ''}, page_content='The Authors acknowledge the contribution of following experts/professionals in developing the \nHandbook. \nMr. Max Baumann, Planning Officer, GIZ, Germany\nMr. Fredrick Oberthur, Planning Officer, GIZ, Germany\nMr. Ajit Kumar Desai, Chairman, DFV, Navsari, Gujarat \nDr. Sashidhar, Professor, University of Agriculture and Horticultural Sciences, Shimoga, Karnataka\nDr. Syed Ahmed Hussain, Professor, ANGRAU, Hyderabad, Telangana\nMr. V.Gunasekaran,Agricultural Officer, Pesticide Testing Laboratory, Dharmapuri, Tamilnadu\nDr. M.V.Shantharam, Former Dean, ANGRAU, Hyderabad, Telangana\nDr. K. Kareemulla, Principal Scientist, NAARM, Hyderabad, Telangana\nDr. K.V. Jayaraghavendra Rao, Principal Scientist, NAARM, Hyderabad, Telangana\nMr. Thomas A Vivian, Assistant Professor, College of Agriculture, Dhule, Maharastra\nProf. T. M. Bahale, Professo ...

# %%
def run_agribrain_chatbot(system_prompt='You are a Agricultural Expert', history_window=30,
                        temperature=0.3, llm=gemini_model):
  # Modify the core behavior of the LLM
  if system_prompt:
    SYS_PROMPT = system_prompt
  else:
    SYS_PROMPT = """
                  Act as a helpful AI Assistant for farmers. Use the following context information to answer questions.
                 """
  def format_docs(docs):
    return "\n\n".join(doc.page_content for doc in docs)

  # Function to format retrieved documents
  #def format_docs(docs):
    # First, print the retrieved documents in a well-defined format
    #print("\n" + "="*50)
    #print("📚 RETRIEVED CONTENT:")
    #print("="*50)

    #for i, doc in enumerate(docs, 1):
      #print(f"\n📄 Document {i}:")
      #print("-"*40)
      #print(doc.page_content[:500] + "..." if len(doc.page_content) > 500 else doc.page_content)
      #if hasattr(doc, 'metadata') and doc.metadata:
        #print("\n📋 Metadata:")
        #for key, value in doc.metadata.items():
          #print(f"  • {key}: {value}")

    #print("\n" + "="*50 + "\n")

    # Then return the formatted content as before
    #return "\n\n".join(doc.page_content for doc in docs)

  # Create a prompt template to store conversation history and accept new user prompts
  # Combine system prompt and context into a single system message for Gemini
  prompt = ChatPromptTemplate.from_messages(
    [
      ("system", "{system_prompt}\n\nContext information: {context}"),
      MessagesPlaceholder(variable_name="history"),
      ("human", "{question}"),
    ]
  )

  # Create a memory object to store conversation history window
  memory = ConversationBufferWindowMemory(k=history_window,
                                          return_messages=True)

  # Create a conversation chain
  conversation_chain = (
    RunnablePassthrough.assign(
      context=lambda x: format_docs(retriever.get_relevant_documents(x["question"])),
      system_prompt=lambda x: SYS_PROMPT,
      history=lambda x: memory.load_memory_variables({})["history"],
      question=lambda x: x["question"]
    )
    |
    prompt
    |
    llm
  )

  # Print a welcome message when the chatbot starts.
  print("🌾 Hello! I'm AgriBrain, your agri-assistant. Ask me anything about crops, soil, or farming. (type 'STOP' to quit)")

  # Start an infinite loop for interactive conversation with the user.
  while True:
    # Get input from the user.
    user_prompt = input('👨‍🌾 You: >>> ')
    # Check if the user wants to end the chat.
    if user_prompt.strip().upper() == 'STOP':
      print("👋 AgriBrain: >>> Take care and happy farming!")
      break

    # Generate and print the chatbot's reply.
    user_inp = {'question': user_prompt}
    reply = conversation_chain.invoke(user_inp)
    print(f"🌱 Agribrain: >>>\n{reply.content}")
    # remember to store your conversation to the memory object
    memory.save_context({"input": user_prompt}, {"output": reply.content})

# %%
run_agribrain_chatbot()
# Out:
# <ipython-input-6-75e76f69f245>:45: LangChainDeprecationWarning: Please see the migration guide at: https://python.langchain.com/docs/versions/migrating_memory/
#   memory = ConversationBufferWindowMemory(k=history_window,
# 🌾 Hello! I'm AgriBrain, your agri-assistant. Ask me anything about crops, soil, or farming. (type 'STOP' to quit)
# 👨‍🌾 You: >>> What are the benefits of Mulching?
# <ipython-input-6-75e76f69f245>:51: LangChainDeprecationWarning: The method `BaseRetriever.get_relevant_documents` was deprecated in langchain-core 0.1.46 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   context=lambda x: format_docs(retriever.get_relevant_documents(x["question"])),
# /usr/local/lib/python3.11/dist-packages/langchain_google_genai/chat_models.py:310: UserWarning: Convert_system_message_to_human will be deprecated!
#   warnings.warn("Convert_system_message_to_human will be deprecated!")
# 🌱 Agribrain: >>>
# Based on the provided text, the benefits of crop residue mulching are:
#
# *   **Increased availability of water and organic matter:** Mulch helps retain moisture in the soil and as it decomposes, it adds organic matter, improving soil fertility.
# *   **Less erosion:** Mulch protects the soil surface from the impact of raindrops and wind, reducing soil erosion.
# *   **Environment protection:** By reducing erosion and improving soil health, mulching contributes to environmental protection.
# *   **Less drought susceptibility:** Improved water retention in the soil makes crops less vulnerable to drought.
# *   **Improved soil quality and fertilizer efficiency:** Mulch enhances soil structure, water infiltration, and nutrient availability, leading to better fertilizer utilization.
# *   **Minimizes long-term dependency on external inputs:** By improving soil health and fertility, mulching reduces the need for synthetic fertilizers and other external inputs.
# 👨‍🌾 You: >>> what kind of deficiency causes In cereals, yellowing and curling of the leaf blades, restricted ear production and poor grain set, indeterminate tillering.
# /usr/local/lib/python3.11/dist-packages/langchain_google_genai/chat_models.py:310: UserWarning: Convert_system_message_to_human will be deprecated!
#   warnings.warn("Convert_system_message_to_human will be deprecated!")
# 🌱 Agribrain: >>>
# Based on the symptoms you described (yellowing and curling of leaf blades, restricted ear production, poor grain set, and indeterminate tillering in cereals), the deficiency most likely to cause these issues is **Nitrogen (N)**.
#
# Here's why:
#
# *   **Yellowing (Chlorosis):** Nitrogen is a key component of chlorophyll, the pigment responsible for the green color in plants. A deficiency leads to reduced chlorophyll production, resulting in yellowing, particularly in older leaves first.
# *   **Restricted Ear Production and Poor Grain Set:** Nitrogen is crucial for overall plant growth and development, including reproductive processes. Insufficient nitrogen can hinder ear development and grain filling.
# *   **Indeterminate Tillering:** While other deficiencies can sometimes affect tillering, nitrogen deficiency can lead to excessive, weak tillering as the plant tries to compensate for its lack of resources.
# *   **Curling of Leaf Blades:** While not always present, leaf curling can occur in nitrogen-deficient plants due to disrupted cell growth and water balance.
#
# **Other Possible Deficiencies (Less Likely):**
#
# While nitrogen is the primary suspect, other deficiencies could contribute to similar symptoms, but usually with additional distinguishing characteristics:
#
# *   **Sulfur (S):** Sulfur deficiency can also cause yellowing, but it often starts in younger leaves, unlike nitrogen.
# *   **Molybdenum (Mo):** Molybdenum is involved in nitrogen metabolism, so a deficiency can indirectly affect nitrogen utilization. However, molybdenum deficiency is less common.
#
# **Recommendation:**
#
# To confirm the deficiency, consider the following:
#
# 1.  **Soil Testing:** Analyze the soil to determine the levels of available nutrients, including nitrogen.
# 2.  **Plant Tissue Analysis:** Send plant samples to a lab for tissue analysis to measure the nutrient content in the plant.
# 3.  **Observe the Pattern:** Note which leaves are most affected (older vs. younger) and the overall pattern of symptoms in the field.
#
# Once the deficiency is confirmed, apply the appropriate fertilizer containing the deficient nutrient(s) based on soil test recommendations.
# 👨‍🌾 You: >>> stop
# 👋 AgriBrain: >>> Take care and happy farming!

# %% [markdown]
# # RAG Evaluation

# %% [markdown]
# ## Create a vector storage and a retriver

# %%
docs = []
docs_path = "/content/"

if not os.path.exists(docs_path):
    os.makedirs(docs_path)

for file in os.listdir(docs_path):
    if file.endswith(".pdf"):
        # print(file)
        loader = PyMuPDFLoader(os.path.join(docs_path, file))
        docs.extend(loader.load())

if docs:
    text_splitter = RecursiveCharacterTextSplitter(chunk_size=1500,
                                                 chunk_overlap=200)
    chunks = text_splitter.split_documents(docs)
    embeddings = GoogleGenerativeAIEmbeddings(model="models/embedding-001")
    client = chromadb.PersistentClient(path="./chroma_db")
    # Use Chroma from LangChain
    vectordb = Chroma.from_documents(
        documents=chunks,
        embedding=embeddings,
        client=client,
        collection_name="document_collection"
    )

    # Define retriever object
    retriever = vectordb.as_retriever(search_type="similarity_score_threshold", search_kwargs={"k": 3, "score_threshold": 0.3})
# Out:
# /usr/local/lib/python3.11/dist-packages/langchain_community/document_loaders/parsers/pdf.py:300: UserWarning: Warning: Empty content on page 7 of document /content/farmerbook-1-20.pdf
#   warnings.warn(

# %% [markdown]
# ## Create the RAG pipeline

# %%
from IPython.display import display, Markdown

def display_docs(docs):
    for doc in docs:
        print('Metadata:', doc.metadata)
        print('Content Brief:')
        display(Markdown(doc.page_content))
        print()

# %%
query = "what is Agriculture?"
top_docs = retriever.invoke(query)
display_docs(top_docs)
# Out:
# Metadata: {'author': '', 'creationDate': '', 'creator': '', 'file_path': '/content/farmerbook-1-20.pdf', 'format': 'PDF 1.5', 'keywords': '', 'modDate': 'D:20250408072807Z', 'page': 5, 'producer': 'iLovePDF', 'source': '/content/farmerbook-1-20.pdf', 'subject': '', 'title': '', 'total_pages': 20, 'trapped': ''}
# Content Brief:
# Farmer’s Handbook on Basic Agriculture
# Preface
# A
# griculture is an important sector of Indian Economy as more than half of its population relies on Ag-
# riculture as principle source of income.  Research and Extension systems play major role in generation
# and dissemination of Agricultural technologies aiming at enhancing the income of farmers. The extension
# system adopts series of extension methods such as Training, demonstration, exposure visit to transfer
# the technologies from lab to land. Majority of these extension efforts mainly focus on location and crop
# specific technologies, and mostly on solution to problem basis. However, there is a need for equipping the
# farmers with Basic knowledge of Agriculture in order to create a better knowledge platform at farmer level
# for taking appropriate farm management decisions and to absorb modern technologies.
# In view of this, Desai Fruits and Vegetables Pvt. Ltd. (DFV), India, in cooperation with the Deutsche
# Gesellschaft für Internationale Zusammenarbeit (GIZ) GmbH on behalf of the German Federal Ministry
# for Economic Cooperation and Development (BMZ) in close cooperation with National Institute of Ag-
# ricultural Extension Management (MANAGE- An Organization of Ministry of Agriculture, Government
# of India) brought out Farmer’s Handbook on Basic Agriculture to impart technical knowledge on Basic
# Agriculture to farmers to provide holistic perspective of scientific Agriculture.
# Metadata: {'author': '', 'creationDate': '', 'creator': '', 'file_path': '/content/farmerbook-1-20.pdf', 'format': 'PDF 1.5', 'keywords': '', 'modDate': 'D:20250408072807Z', 'page': 4, 'producer': 'iLovePDF', 'source': '/content/farmerbook-1-20.pdf', 'subject': '', 'title': '', 'total_pages': 20, 'trapped': ''}
# Content Brief:
# Farmer’s Handbook on Basic Agriculture
# Acknowledgement
# H
# igher demand for agricultural raw material is now anticipated and agriculture is not any more about
# producing farm products and selling them exclusively at the local market. Instead farmers today have
# a world market to serve. But the new chances bring new challenges. Farmers and agricultural enterprises,
# willing to be part of the new expanding world market, not only have to take into consideration customers’
# preferences whom they want to serve, but also adhere to international trade regulations set by WTO and
# comply with high production and quality standards required by the importing countries.
# Agriculture contributes around 17% to GDP and continues to be among the most important and success-
# ful sectors in India. Around 58% of the Indian population depend on agriculture for their livelihood. Apart
# from delivering the local industries with top quality raw materials for processing, agriculture provides
# almost 10% of total export earnings. However, to support the impressive Indian economic growth in the
# coming years, agriculture will have to contribute more towards value addition, productivity enhancement,
# high quality products and trained manpower to successfully tackle these challenges.
# The states of Gujarat and Maharashtra have competitive advantages for the production of several com-
# modities. However, productivity and competitiveness remains low. Rising quality requirements of export
# Metadata: {'author': '', 'creationDate': '', 'creator': '', 'file_path': '/content/farmerbook-1-20.pdf', 'format': 'PDF 1.5', 'keywords': '', 'modDate': 'D:20250408072807Z', 'page': 5, 'producer': 'iLovePDF', 'source': '/content/farmerbook-1-20.pdf', 'subject': '', 'title': '', 'total_pages': 20, 'trapped': ''}
# Content Brief:
# soil fertility in an economically and environmentally sustainable manner. It also focuses on the need for
# soil testing, plant nutrition requirement, organic & inorganic fertilizers, and Integrated Nutrient Manage-
# ment (INM) for efficient, economic and sustainable production of crops.
# The third chapter of the book is about Pest Management, and focuses on enhancing the awareness of and
# understanding among farmers about the crop pests, diseases and weed management through Integrated
# Pest Management. It also aims at sensitizing farmers on safe handling of chemicals and plant protection
# equipments as also elaborated further in the fifth chapter on “Occupational health and safety of farmers”
# .
# It creates awareness about causes, preventive measures of health hazards, risks & fatalities in agriculture,
# and use of first aid in emergencies. It further includes safety tips and care to reduce the risk of injuries and
# fatalities while handling machineries and pesticides by farmers.
# Time and resources management is an integral part of each and every activity, be it service sector, busi-
# ness or day-to-day activities of life. Farming sector too has not remained untouched by it. Therefore, the
# fourth chapter of the book is devoted to “Farm Management”
# . It is to educate and equip the farmers to
# make proper plans, take appropriate decisions and also to take advantage of the improved technologies

# %%
from langchain_core.prompts import ChatPromptTemplate

rag_prompt = """You are an assistant who is an expert in question-answering tasks.
                Answer the following question using only the following pieces of retrieved context.
                If the answer is not in the context, do not make up answers, just say that you don't know.
                Keep the answer to the point based on the information from the context.

                Question:
                {question}

                Context:
                {context}

                Answer:
            """

rag_prompt_template = ChatPromptTemplate.from_template(rag_prompt)

# %%
from langchain_core.runnables import RunnablePassthrough
from langchain_openai import ChatOpenAI
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough
from langchain_core.runnables import RunnableLambda
from operator import itemgetter

def format_docs(docs):
    return "\n\n".join(doc.page_content for doc in docs)

src_rag_response_chain = (
    {
        "context": (itemgetter('context')
                        |
                    RunnableLambda(format_docs)),
        "question": itemgetter("question")
    }
        |
    rag_prompt_template
        |
    gemini_model
        |
    StrOutputParser()
)

rag_chain_w_sources = (
    {
        "context": retriever,
        "question": RunnablePassthrough()
    }
        |
    RunnablePassthrough.assign(response=src_rag_response_chain)
)

# %%
import pprint

query = "What is Agriculture?"
result = rag_chain_w_sources.invoke(query)
pprint.pprint(result)
# Out:
# /usr/local/lib/python3.11/dist-packages/langchain_google_genai/chat_models.py:310: UserWarning: Convert_system_message_to_human will be deprecated!
#   warnings.warn("Convert_system_message_to_human will be deprecated!")
# {'context': [Document(metadata={'author': '', 'creationDate': '', 'creator': '', 'file_path': '/content/farmerbook-1-20.pdf', 'format': 'PDF 1.5', 'keywords': '', 'modDate': 'D:20250408072807Z', 'page': 5, 'producer': 'iLovePDF', 'source': '/content/farmerbook-1-20.pdf', 'subject': '', 'title': '', 'total_pages': 20, 'trapped': ''}, page_content='Farmer’s Handbook on Basic Agriculture\nPreface\nA\ngriculture is an important sector of Indian Economy as more than half of its population relies on Ag-\nriculture as principle source of income.  Research and Extension systems play major role in generation \nand dissemination of Agricultural technologies aiming at enhancing the income of farmers. The extension \nsystem adopts series of extension methods such as Training, demonstration, exposure visit to transfer \nthe technologies from lab to land. Majority of these extension efforts mainly focus on location and crop \nspecific technologies, and mostly on solution to problem basis. However, there is a need for equipping the \nfarmers with Basic knowledge of Agriculture in order to create a better knowledge platform at farmer level \nfor taking appropriate farm management decisions and to absorb modern technologies.  \nIn view of this, Desai Fruits and Vegetables Pvt. Ltd. (DFV), India, in cooperation with the Deutsche \nGesellschaft für Internationale Zusammenarbeit (GIZ) GmbH on behalf of the German Federal Ministry \nfor Economic Cooperation and Development (BMZ) in close cooperation with National Institute of Ag-\nricultural Extension Management (MANAGE- An Organization of Ministry of Agriculture, Government \nof India) brought out Farmer’s Handbook on Basic Agriculture to impart technical knowledge on Basic \nAgriculture to farmers to provide holistic perspective of scientific Agriculture.'),
#              Document(metadata={'author': '', 'creationDate': '', 'creator': '', 'file_path': '/content/farmerbook-1-20.pdf', 'format': 'PDF 1.5', 'keywords': '', 'modDate': 'D:20250408072807Z', 'page': 6, 'producer': 'iLovePDF', 'source': '/content/farmerbook-1-20.pdf', 'subject': '', 'title': '', 'total_pages': 20, 'trapped': ''}, page_content='Farmer’s Handbook on Basic Agriculture\nContents\n1.\t\nGeneral Conditions for Cultivation of Crops\t \t\n\t\n\t\n\t\n1-32\n2.\t\nSoil and Plant Nutrition \t\n\t\n\t\n\t\n\t\n\t\n\t\n\t\n33-70\n3.\t\nPlant Protection\t \t\n\t\n\t\n\t\n\t\n\t\n\t\n\t\n71-96\n4.\t\nCategories of Pesticides and Precautions\t\t\n\t\n        97-98\n5.\t\nFarm Management\t\n\t\n\t\n\t\n\t\n\t\n\t\n\t\n99-120\n6.\t\nOccupational Health and Safety\t\n\t\n\t\n\t\n\t\n\t\n121-130\n7.\t\nFarmer’s Access to Service \t \t\n\t\n\t\n\t\n\t\n\t\n131-136'),
#              Document(metadata={'author': '', 'creationDate': '', 'creator': '', 'file_path': '/content/farmerbook-1-20.pdf', 'format': 'PDF 1.5', 'keywords': '', 'modDate': 'D:20250408072807Z', 'page': 4, 'producer': 'iLovePDF', 'source': '/content/farmerbook-1-20.pdf', 'subject': '', 'title': '', 'total_pages': 20, 'trapped': ''}, page_content='Farmer’s Handbook on Basic Agriculture\nAcknowledgement\nH\nigher demand for agricultural raw material is now anticipated and agriculture is not any more about \nproducing farm products and selling them exclusively at the local market. Instead farmers today have \na world market to serve. But the new chances bring new challenges. Farmers and agricultural enterprises, \nwilling to be part of the new expanding world market, not only have to take into consideration customers’ \npreferences whom they want to serve, but also adhere to international trade regulations set by WTO and \ncomply with high production and quality standards required by the importing countries.\nAgriculture contributes around 17% to GDP and continues to be among the most important and success-\nful sectors in India. Around 58% of the Indian population depend on agriculture for their livelihood. Apart \nfrom delivering the local industries with top quality raw materials for processing, agriculture provides \nalmost 10% of total export earnings. However, to support the impressive Indian economic growth in the \ncoming years, agriculture will have to contribute more towards value addition, productivity enhancement, \nhigh quality products and trained manpower to successfully tackle these challenges.\nThe states of Gujarat and Maharashtra have competitive advantages for the production of several com-\nmodities. However, productivity and competitiveness remains low. Rising quality requirements of export')],
#  'question': 'What is Agriculture?',
#  'response': 'Agriculture is an important sector of the Indian Economy, with '
#              'more than half of its population relying on it as their primary '
#              'source of income. It contributes around 17% to GDP, and around '
#              '58% of the Indian population depends on agriculture for their '
#              'livelihood.\n'}

# %% [markdown]
# # Create End-to-End RAG Evaluation Workflow
#
# ![](https://i.imgur.com/GUIkpjy.png)

# %% [markdown]
# ## Create a Synthetic RAG Golden Reference Dataset

# %%
from langchain.docstore.document import Document
processed_docs = []

for doc in docs:
    # metadata = {
    #     "title": doc['title'],
    #     "id": doc['id'],
    # }
    data = doc.page_content
    processed_docs.append(Document(page_content=data)) #, metadata=metadata
processed_docs[:3]
# Out:
# [Document(metadata={}, page_content='A holistic  \nperspective of  \nscientific  \nagriculture\nA joint initiative to  \nimpart farmers with \ntechnical knowledge on \nbasic agriculture.\nFarmer’s Handbook on Basic Agriculture\n'),
#  Document(metadata={}, page_content='Disclaimer:\nThe opinions expressed provided in this publication are those of the authors and do not necessarily reflect those of  GIZ . The \ndesignations employed and the presentation of material in this publication do not imply the expression of any opinion what-\nsoever on the part of  GIZ  concerning the legal status of any country, territory, city or area, or concerning the delimitation of \nits frontiers or boundaries.\n'),
#  Document(metadata={}, page_content=' \nFarmer’s Handbook on Basic Agriculture\nFarmer’s Handbook on Basic Agriculture\nPrepared & compiled by\nDr. P. Chandra Shekara\nNational Institute of Agricultural Extension  \nManagement (MANAGE)\nMinistry of Agriculture, GoI\nHyderabad, Andhra Pradesh\nIndia\nDr. N. Balasubramani\nNational Institute of Agricultural Extension  \nManagement (MANAGE)\nMinistry of Agriculture, GoI \nHyderabad, Andhra Pradesh\nIndia\nDr. Rajeev Sharma\nDr. Chitra Shukla\nDesai Fruits & Vegetables Pvt. Ltd.\nNavsari, Gujarat\nIndia\nDr. Ajit Kumar\nDesai Fruits & Vegetables Pvt. Ltd.\nNavsari, Gujarat \nIndia\nBakul C. Chaudhary\nDesai Fruits & Vegetables Pvt. Ltd.\nNavsari, Gujarat \nIndia\nMr. Max Baumann\nPlanning Officer\nSection “Agricultural Production & Resource Use”\nDivision 45 - Rural Development and Agriculture\nDeutsche Gesellschaft für Internationale Zusam-\nmenarbeit (GIZ) GmbH\nGermany\nMax.Baumann@giz.de\nFinanced by\nDesai Fruits & Vegetables Pvt. Ltd.\nNavsari, Gujarat, India\nGerman Federal Ministry for Economic Cooperation \nand Development (BMZ)\nPublished by\nDesai Fruits & Vegetables Pvt. Ltd.\nNavsari, Gujarat\nIndia\nSecond Edition: August 2016\n')]

# %%
doc_contexts = [doc.page_content for doc in processed_docs]
doc_contexts[:3]
# Out:
# ['A holistic  \nperspective of  \nscientific  \nagriculture\nA joint initiative to  \nimpart farmers with \ntechnical knowledge on \nbasic agriculture.\nFarmer’s Handbook on Basic Agriculture\n',
#  'Disclaimer:\nThe opinions expressed provided in this publication are those of the authors and do not necessarily reflect those of  GIZ . The \ndesignations employed and the presentation of material in this publication do not imply the expression of any opinion what-\nsoever on the part of  GIZ  concerning the legal status of any country, territory, city or area, or concerning the delimitation of \nits frontiers or boundaries.\n',
#  ' \nFarmer’s Handbook on Basic Agriculture\nFarmer’s Handbook on Basic Agriculture\nPrepared & compiled by\nDr. P. Chandra Shekara\nNational Institute of Agricultural Extension  \nManagement (MANAGE)\nMinistry of Agriculture, GoI\nHyderabad, Andhra Pradesh\nIndia\nDr. N. Balasubramani\nNational Institute of Agricultural Extension  \nManagement (MANAGE)\nMinistry of Agriculture, GoI \nHyderabad, Andhra Pradesh\nIndia\nDr. Rajeev Sharma\nDr. Chitra Shukla\nDesai Fruits & Vegetables Pvt. Ltd.\nNavsari, Gujarat\nIndia\nDr. Ajit Kumar\nDesai Fruits & Vegetables Pvt. Ltd.\nNavsari, Gujarat \nIndia\nBakul C. Chaudhary\nDesai Fruits & Vegetables Pvt. Ltd.\nNavsari, Gujarat \nIndia\nMr. Max Baumann\nPlanning Officer\nSection “Agricultural Production & Resource Use”\nDivision 45 - Rural Development and Agriculture\nDeutsche Gesellschaft für Internationale Zusam-\nmenarbeit (GIZ) GmbH\nGermany\nMax.Baumann@giz.de\nFinanced by\nDesai Fruits & Vegetables Pvt. Ltd.\nNavsari, Gujarat, India\nGerman Federal Ministry for Economic Cooperation \nand Development (BMZ)\nPublished by\nDesai Fruits & Vegetables Pvt. Ltd.\nNavsari, Gujarat\nIndia\nSecond Edition: August 2016\n']

# %%
from deepeval.synthesizer import Synthesizer
from deepeval.synthesizer import types
# Out:
# /usr/local/lib/python3.11/dist-packages/deepeval/__init__.py:49: UserWarning: You are using deepeval version 1.4.7, however version 2.7.0 is available. You should consider upgrading via the "pip install --upgrade deepeval" command.
#   warnings.warn(

# %%
os.environ["OPENAI_API_KEY"] = userdata.get('OPENAI_API_KEY')

# %%
print("hi")
# Out:
# hi

# %%
len(doc_contexts)
# Out:
# 20

# %%
synthesizer = Synthesizer(model='gpt-4o', embedder=embeddings) # model='gemini-2.0-flash',

eval_data = synthesizer.generate_goldens(
    # Provide a list of context for synthetic data generation
    contexts=[[doc] for doc in doc_contexts],
    include_expected_output=True,
    max_goldens_per_context=1,
    num_evolutions=1,
    scenario="Retrieval Augmented Generation",
    task="Question Answering",
    evolutions={
        types.Evolution.REASONING: 0.1,     # Evolves the input to require multi-step logical thinking.
        types.Evolution.MULTICONTEXT: 0.9,  # Ensures that all relevant information from the context is utilized.
        types.Evolution.CONCRETIZING: 0.0,  # Makes abstract ideas more concrete and detailed.
        types.Evolution.CONSTRAINED: 0.0,   # Introduces a condition or restriction, testing the model's ability to operate within specific limits.
        types.Evolution.COMPARATIVE: 0.0,   # Requires a response that involves a comparison between options or contexts.
        types.Evolution.HYPOTHETICAL: 0.0,  # Forces the model to consider and respond to a hypothetical scenario.
        types.Evolution.IN_BREADTH: 0.0,    # Broadens the input to touch on related or adjacent topics.
    }
)
# Out:
# Event loop is already running. Applying nest_asyncio patch to allow async execution...
# ✨ Generating up to 20 goldens using DeepEval (using gpt-4o, use case=QA, method=default): 100%|██████████| 20/20 [00:28<00:00,  1.43s/it]
# ✓ Generation finished 🎉! You can also run 'deepeval login' to generate and save goldens directly on Confident AI.

# %% [markdown]
# ## Save the Synthetic RAG Golden Reference Dataset

# %%
import dill

# %%
with open('golden_ref_data.bin', 'wb') as f:
    dill.dump(eval_data, f)

# %% [markdown]
# ## Create RAG Evaluation Dataset

# %%
from deepeval.dataset import EvaluationDataset

eval_dataset = EvaluationDataset()

# load golden dataset
with open('golden_ref_data.bin', 'rb') as f:
    golden_docs = dill.load(f)

eval_dataset.goldens = golden_docs

# %%
eval_dataset.goldens[0]
# Out:
# Golden(input='How do contour trenching and straw thatching help protect seedlings from frost?', actual_output=None, expected_output='Contour trenching helps in runoff collection, which indirectly aids in maintaining soil moisture and moderating temperature fluctuations, offering some protection against frost. Straw thatching provides direct protection for young seedlings against cold by covering them, thereby helping to mitigate frost impact.', context=['General Conditions for Cultivation of Crops\nFarmer’s Handbook on Basic Agriculture\n9\nCoping options for farmers continued....\n \nContour trenching for runoff  collec-\ntion\nConventional Raised Bed Planting\n• \n20-25% Saving in irrigation water\n \nShelterbelts\n• \nShelterbelts reduce wind velocity.\n• \nModerate temperature.\n• \nReduce evaporative loss and conserve soil \nmoisture.\nStraw Thatching\n• \nProtecting young seedlings against cold by cov-\nering with straw thatching.\nFrost Protection\n'], retrieval_context=None, additional_metadata={'evolutions': ['Multi-context'], 'synthetic_input_quality': 1.0, 'context_quality': None}, comments=None, tools_called=None, expected_tools=None, source_file=None)

# %%
eval_dataset.goldens[0].input
# Out:
# 'How do contour trenching and straw thatching help protect seedlings from frost?'

# %%
rag_chain_w_sources.invoke(eval_dataset.goldens[0].input)
# Out:
# /usr/local/lib/python3.11/dist-packages/langchain_google_genai/chat_models.py:310: UserWarning: Convert_system_message_to_human will be deprecated!
#   warnings.warn("Convert_system_message_to_human will be deprecated!")
# {'context': [Document(metadata={'author': '', 'creationDate': '', 'creator': '', 'file_path': '/content/farmerbook-1-20.pdf', 'format': 'PDF 1.5', 'keywords': '', 'modDate': 'D:20250408072807Z', 'page': 16, 'producer': 'iLovePDF', 'source': '/content/farmerbook-1-20.pdf', 'subject': '', 'title': '', 'total_pages': 20, 'trapped': ''}, page_content='General Conditions for Cultivation of Crops\nFarmer’s Handbook on Basic Agriculture\n9\nCoping options for farmers continued....\n \nContour trenching for runoff  collec-\ntion\nConventional Raised Bed Planting\n• \n20-25% Saving in irrigation water\n \nShelterbelts\n• \nShelterbelts reduce wind velocity.\n• \nModerate temperature.\n• \nReduce evaporative loss and conserve soil \nmoisture.\nStraw Thatching\n• \nProtecting young seedlings against cold by cov-\nering with straw thatching.\nFrost Protection'),
#   Document(metadata={'author': '', 'creationDate': '', 'creator': '', 'file_path': '/content/farmerbook-1-20.pdf', 'format': 'PDF 1.5', 'keywords': '', 'modDate': 'D:20250408072807Z', 'page': 19, 'producer': 'iLovePDF', 'source': '/content/farmerbook-1-20.pdf', 'subject': '', 'title': '', 'total_pages': 20, 'trapped': ''}, page_content='12\nGeneral Conditions for Cultivation of Crops\nFarmer’s Handbook on Basic Agriculture\nConservation farming\n• \nFarming across the slope\n• \nStrip cropping\n• \nRotations\n• \nMixed cropping and intercropping\n• \nSurface mulching\n• \nTimely farm operations\n• \nImproved water user efficiency\n• \nLand levelling\n• \nProviding safe drainage\n• \nIntermittent terraces\n• \nGrowing vegetation on the bunds\nVegetation and vegetative management\n• \nStrip cropping\n• \nStubble mulching\n• \nMulching\nWind erosion management\n• \nProtect the soil surface with a cover of vegeta-\ntion or vegetative residues.\n• \nProduce or bring to the surface soil aggregates \nor clods which are large enough to resist the \nwind force.\n• \nRoughen the land surface to reduce wind veloc-\nity and trap drifting soil.\n• \nEstablish barriers or trap strips at intervals to \nreduce wind velocity and soil drifting.\nBest practices to control soil blowing\n• \nDeep ploughing\n• \nSummer ploughing\n• \nSurface roughness\n• \nConserving moisture\n• \nWind breaks and shelterbelts\n• \nMechanical or vegetative barriers\nFor instance: Shelterbelts for moderating micro-\nclimate\n• \nShelterbelts reduce wind velocity\n• \nModerate temperature\n• \nReduce evaporative loss and conserve soil \nmoisture\nWater erosion can be managed by \n• \nIn situ water harvesting\n• \nSummer ploughing\nOverland flow management\n• \nContour bund\n• \nGraded bund\n• \nBroad based bund\n• \nBench terrace\n• \nWater harvesting and recycling \nZero tillage\n• \nSeveral practices are in use such as zero till-'),
#   Document(metadata={'author': '', 'creationDate': '', 'creator': '', 'file_path': '/content/farmerbook-1-20.pdf', 'format': 'PDF 1.5', 'keywords': '', 'modDate': 'D:20250408072807Z', 'page': 19, 'producer': 'iLovePDF', 'source': '/content/farmerbook-1-20.pdf', 'subject': '', 'title': '', 'total_pages': 20, 'trapped': ''}, page_content='Overland flow management\n• \nContour bund\n• \nGraded bund\n• \nBroad based bund\n• \nBench terrace\n• \nWater harvesting and recycling \nZero tillage\n• \nSeveral practices are in use such as zero till-\nage, minimum tillage and direct seeding.\n• \nPlanting crops in previously untilled soil by \nopening a narrow slot, trench or band only \nof sufficient width and depth to obtain seed \ncoverage. No other soil tillage is done.\nAdvantages of zero tillage farming\n• \nErosion control: Retained stubble and crop \nresidue reduces soil erosion and enhances \nsoil fertility\n• \nMoisture conservation: Stubble traps water, \nreduce runoff water, better infiltration lead-\ning to improved soil moisture condition\n• \nHigher nitrogen availability\n• \nSeedling protection: Stubbles protects young \nseedling from wind and heat\n• \nCrop yields will be on par with traditional \ntillage system. However good yield can be \nharvested during dry years\n• \nReduce labour and save time\n• \nSavings on equipment cost\n• \nSavings on oil/fuel cost\nMulching: Benefits of crop residue mulch-\ning are\n• \nIncreased availability of water and organic \nmatter \n• \nLess erosion\n• \nEnvironment protection\nAdditional benefit to farmers\n• \nLess drought susceptibility\n• \nImproved soil quality and fertilizer efficiency\n• \nMinimises long term dependency on external \ninputs')],
#  'question': 'How do contour trenching and straw thatching help protect seedlings from frost?',
#  'response': "Straw thatching protects young seedlings against the cold. I'm sorry, but the text does not specify how contour trenching helps protect seedlings from frost.\n"}

# %%
from typing import List
from deepeval.test_case import LLMTestCase
from deepeval.dataset import Golden
from tqdm import tqdm
import time
import random

def convert_goldens_to_test_cases(goldens: List[Golden]) -> List[LLMTestCase]:
    test_cases = []
    # Calculate sleep time to respect RPM limit
    # For 15 RPM, we need to wait at least 4 seconds between calls
    # Adding some jitter to avoid exact timing patterns
    base_sleep_time = 60 / 15  # 4 seconds

    for i, golden in enumerate(tqdm(goldens)):
        # Make the API call
        response_obj = rag_chain_w_sources.invoke(golden.input)

        # Create test case
        test_case = LLMTestCase(
            input=golden.input,
            actual_output=response_obj['response'],
            expected_output=golden.expected_output,
            context=golden.context,
            retrieval_context=[doc.page_content for doc in response_obj['context']]
        )
        test_cases.append(test_case)

        # Sleep to respect rate limits, but only if not the last item
        if i < len(goldens) - 1:
            # Add some jitter (±15%) to avoid predictable patterns
            jitter = random.uniform(0.85, 1.15)
            sleep_time = base_sleep_time * jitter
            time.sleep(sleep_time)

    return test_cases

# %%
eval_dataset.test_cases = convert_goldens_to_test_cases(eval_dataset.goldens)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]/usr/local/lib/python3.11/dist-packages/langchain_google_genai/chat_models.py:310: UserWarning: Convert_system_message_to_human will be deprecated!
#   warnings.warn("Convert_system_message_to_human will be deprecated!")
#   5%|▌         | 1/20 [00:05<01:37,  5.11s/it]/usr/local/lib/python3.11/dist-packages/langchain_google_genai/chat_models.py:310: UserWarning: Convert_system_message_to_human will be deprecated!
#   warnings.warn("Convert_system_message_to_human will be deprecated!")
#  10%|█         | 2/20 [00:09<01:23,  4.62s/it]/usr/local/lib/python3.11/dist-packages/langchain_google_genai/chat_models.py:310: UserWarning: Convert_system_message_to_human will be deprecated!
#   warnings.warn("Convert_system_message_to_human will be deprecated!")
#  15%|█▌        | 3/20 [00:14<01:23,  4.90s/it]/usr/local/lib/python3.11/dist-packages/langchain_google_genai/chat_models.py:310: UserWarning: Convert_system_message_to_human will be deprecated!
#   warnings.warn("Convert_system_message_to_human will be deprecated!")
#  20%|██        | 4/20 [00:20<01:22,  5.18s/it]/usr/local/lib/python3.11/dist-packages/langchain_google_genai/chat_models.py:310: UserWarning: Convert_system_message_to_human will be deprecated!
#   warnings.warn("Convert_system_message_to_human will be deprecated!")
#  25%|██▌       | 5/20 [00:25<01:16,  5.09s/it]/usr/local/lib/python3.11/dist-packages/langchain_google_genai/chat_models.py:310: UserWarning: Convert_system_message_to_human will be deprecated!
#   warnings.warn("Convert_system_message_to_human will be deprecated!")
#  30%|███       | 6/20 [00:30<01:11,  5.11s/it]/usr/local/lib/python3.11/dist-packages/langchain_google_genai/chat_models.py:310: UserWarning: Convert_system_message_to_human will be deprecated!
#   warnings.warn("Convert_system_message_to_human will be deprecated!")
#  35%|███▌      | 7/20 [00:35<01:06,  5.12s/it]/usr/local/lib/python3.11/dist-packages/langchain_google_genai/chat_models.py:310: UserWarning: Convert_system_message_to_human will be deprecated!
#   warnings.warn("Convert_system_message_to_human will be deprecated!")
#  40%|████      | 8/20 [00:40<01:01,  5.11s/it]/usr/local/lib/python3.11/dist-packages/langchain_google_genai/chat_models.py:310: UserWarning: Convert_system_message_to_human will be deprecated!
#   warnings.warn("Convert_system_message_to_human will be deprecated!")
#  45%|████▌     | 9/20 [00:45<00:56,  5.12s/it]/usr/local/lib/python3.11/dist-packages/langchain_google_genai/chat_models.py:310: UserWarning: Convert_system_message_to_human will be deprecated!
#   warnings.warn("Convert_system_message_to_human will be deprecated!")
#  50%|█████     | 10/20 [00:50<00:51,  5.14s/it]/usr/local/lib/python3.11/dist-packages/langchain_google_genai/chat_models.py:310: UserWarning: Convert_system_message_to_human will be deprecated!
#   warnings.warn("Convert_system_message_to_human will be deprecated!")
#  55%|█████▌    | 11/20 [00:55<00:44,  4.95s/it]/usr/local/lib/python3.11/dist-packages/langchain_google_genai/chat_models.py:310: UserWarning: Convert_system_message_to_human will be deprecated!
#   warnings.warn("Convert_system_message_to_human will be deprecated!")
#  60%|██████    | 12/20 [00:59<00:38,  4.82s/it]/usr/local/lib/python3.11/dist-packages/langchain_google_genai/chat_models.py:310: UserWarning: Convert_system_message_to_human will be deprecated!
#   warnings.warn("Convert_system_message_to_human will be deprecated!")
#  65%|██████▌   | 13/20 [01:04<00:32,  4.64s/it]/usr/local/lib/python3.11/dist-packages/langchain_google_genai/chat_models.py:310: UserWarning: Convert_system_message_to_human will be deprecated!
#   warnings.warn("Convert_system_message_to_human will be deprecated!")
#  70%|███████   | 14/20 [01:08<00:27,  4.59s/it]/usr/local/lib/python3.11/dist-packages/langchain_google_genai/chat_models.py:310: UserWarning: Convert_system_message_to_human will be deprecated!
#   warnings.warn("Convert_system_message_to_human will be deprecated!")
#  75%|███████▌  | 15/20 [01:12<00:22,  4.48s/it]/usr/local/lib/python3.11/dist-packages/langchain_google_genai/chat_models.py:310: UserWarning: Convert_system_message_to_human will be deprecated!
#   warnings.warn("Convert_system_message_to_human will be deprecated!")
#  80%|████████  | 16/20 [01:17<00:17,  4.48s/it]/usr/local/lib/python3.11/dist-packages/langchain_google_genai/chat_models.py:310: UserWarning: Convert_system_message_to_human will be deprecated!
#   warnings.warn("Convert_system_message_to_human will be deprecated!")
#  85%|████████▌ | 17/20 [01:21<00:13,  4.52s/it]/usr/local/lib/python3.11/dist-packages/langchain_google_genai/chat_models.py:310: UserWarning: Convert_system_message_to_human will be deprecated!
#   warnings.warn("Convert_system_message_to_human will be deprecated!")
#  90%|█████████ | 18/20 [01:26<00:09,  4.68s/it]/usr/local/lib/python3.11/dist-packages/langchain_google_genai/chat_models.py:310: UserWarning: Convert_system_message_to_human will be deprecated!
#   warnings.warn("Convert_system_message_to_human will be deprecated!")
#  95%|█████████▌| 19/20 [01:32<00:05,  5.04s/it]/usr/local/lib/python3.11/dist-packages/langchain_google_genai/chat_models.py:310: UserWarning: Convert_system_message_to_human will be deprecated!
#   warnings.warn("Convert_system_message_to_human will be deprecated!")
# 100%|██████████| 20/20 [01:33<00:00,  4.70s/it]

# %%
eval_dataset.test_cases[0]
# Out:
# LLMTestCase(input='How do contour trenching and straw thatching help protect seedlings from frost?', actual_output="Straw thatching protects young seedlings against the cold. I'm sorry, but the text does not describe how contour trenching helps protect seedlings from frost.\n", expected_output='Contour trenching helps in runoff collection, which indirectly aids in maintaining soil moisture and moderating temperature fluctuations, offering some protection against frost. Straw thatching provides direct protection for young seedlings against cold by covering them, thereby helping to mitigate frost impact.', context=['General Conditions for Cultivation of Crops\nFarmer’s Handbook on Basic Agriculture\n9\nCoping options for farmers continued....\n \nContour trenching for runoff  collec-\ntion\nConventional Raised Bed Planting\n• \n20-25% Saving in irrigation water\n \nShelterbelts\n• \nShelterbelts reduce wind velocity.\n• \nModerate temperature.\n• \nReduce evaporative loss and conserve soil \nmoisture.\nStraw Thatching\n• \nProtecting young seedlings against cold by cov-\nering with straw thatching.\nFrost Protection\n'], retrieval_context=['General Conditions for Cultivation of Crops\nFarmer’s Handbook on Basic Agriculture\n9\nCoping options for farmers continued....\n \nContour trenching for runoff  collec-\ntion\nConventional Raised Bed Planting\n• \n20-25% Saving in irrigation water\n \nShelterbelts\n• \nShelterbelts reduce wind velocity.\n• \nModerate temperature.\n• \nReduce evaporative loss and conserve soil \nmoisture.\nStraw Thatching\n• \nProtecting young seedlings against cold by cov-\nering with straw thatching.\nFrost Protection', '12\nGeneral Conditions for Cultivation of Crops\nFarmer’s Handbook on Basic Agriculture\nConservation farming\n• \nFarming across the slope\n• \nStrip cropping\n• \nRotations\n• \nMixed cropping and intercropping\n• \nSurface mulching\n• \nTimely farm operations\n• \nImproved water user efficiency\n• \nLand levelling\n• \nProviding safe drainage\n• \nIntermittent terraces\n• \nGrowing vegetation on the bunds\nVegetation and vegetative management\n• \nStrip cropping\n• \nStubble mulching\n• \nMulching\nWind erosion management\n• \nProtect the soil surface with a cover of vegeta-\ntion or vegetative residues.\n• \nProduce or bring to the surface soil aggregates \nor clods which are large enough to resist the \nwind force.\n• \nRoughen the land surface to reduce wind veloc-\nity and trap drifting soil.\n• \nEstablish barriers or trap strips at intervals to \nreduce wind velocity and soil drifting.\nBest practices to control soil blowing\n• \nDeep ploughing\n• \nSummer ploughing\n• \nSurface roughness\n• \nConserving moisture\n• \nWind breaks and shelterbelts\n• \nMechanical or vegetative barriers\nFor instance: Shelterbelts for moderating micro-\nclimate\n• \nShelterbelts reduce wind velocity\n• \nModerate temperature\n• \nReduce evaporative loss and conserve soil \nmoisture\nWater erosion can be managed by \n• \nIn situ water harvesting\n• \nSummer ploughing\nOverland flow management\n• \nContour bund\n• \nGraded bund\n• \nBroad based bund\n• \nBench terrace\n• \nWater harvesting and recycling \nZero tillage\n• \nSeveral practices are in use such as zero till-', 'Overland flow management\n• \nContour bund\n• \nGraded bund\n• \nBroad based bund\n• \nBench terrace\n• \nWater harvesting and recycling \nZero tillage\n• \nSeveral practices are in use such as zero till-\nage, minimum tillage and direct seeding.\n• \nPlanting crops in previously untilled soil by \nopening a narrow slot, trench or band only \nof sufficient width and depth to obtain seed \ncoverage. No other soil tillage is done.\nAdvantages of zero tillage farming\n• \nErosion control: Retained stubble and crop \nresidue reduces soil erosion and enhances \nsoil fertility\n• \nMoisture conservation: Stubble traps water, \nreduce runoff water, better infiltration lead-\ning to improved soil moisture condition\n• \nHigher nitrogen avai ...

# %% [markdown]
# ## Run and View RAG Evaluations on the Evaluation Dataset

# %%
from deepeval import evaluate
from deepeval.metrics import ContextualPrecisionMetric, ContextualRecallMetric, ContextualRelevancyMetric
from deepeval.metrics import AnswerRelevancyMetric, FaithfulnessMetric, HallucinationMetric
from deepeval.metrics.ragas import RAGASAnswerRelevancyMetric

contextual_precision = ContextualPrecisionMetric(threshold=0.5, include_reason=True, model="gpt-4o")
contextual_recall = ContextualRecallMetric(threshold=0.5, include_reason=True, model="gpt-4o")
contextual_relevancy = ContextualRelevancyMetric(threshold=0.5, include_reason=True, model="gpt-4o")
answer_relevancy = AnswerRelevancyMetric(threshold=0.5, include_reason=True, model="gpt-4o")
faithfulness = FaithfulnessMetric(threshold=0.5, include_reason=True, model="gpt-4o")
hallucination = HallucinationMetric(threshold=0.5, include_reason=True, model="gpt-4o")
ragas_answer_relevancy = RAGASAnswerRelevancyMetric(threshold=0.5, embeddings=embeddings, model="gpt-4o")

eval_results = evaluate(test_cases=eval_dataset.test_cases,
                        metrics=[contextual_precision, contextual_recall, contextual_relevancy,
                                 answer_relevancy, ragas_answer_relevancy, faithfulness, hallucination])
# Out:
# ✨ You're running DeepEval's latest Contextual Precision Metric! (using gpt-4o, strict=False, async_mode=True)...
# ✨ You're running DeepEval's latest Contextual Recall Metric! (using gpt-4o, strict=False, async_mode=True)...
# ✨ You're running DeepEval's latest Contextual Relevancy Metric! (using gpt-4o, strict=False, async_mode=True)...
# ✨ You're running DeepEval's latest Answer Relevancy Metric! (using gpt-4o, strict=False, async_mode=True)...
# ✨ You're running DeepEval's latest Answer Relevancy (ragas) Metric! (using gpt-4o, strict=False,
# async_mode=True)...
# ✨ You're running DeepEval's latest Faithfulness Metric! (using gpt-4o, strict=False, async_mode=True)...
# ✨ You're running DeepEval's latest Hallucination Metric! (using gpt-4o, strict=False, async_mode=True)...
# Event loop is already running. Applying nest_asyncio patch to allow async execution...
# Evaluating 20 test case(s) in parallel: |          |  0% (0/20) [Time Taken: 00:00, ?test case/s]
# Evaluating:   0%|          | 0/1 [00:00<?, ?it/s]
# None
# Evaluating:   0%|          | 0/1 [00:00<?, ?it/s]
# None
# Evaluating:   0%|          | 0/1 [00:00<?, ?it/s]
# None
# Evaluating:   0%|          | 0/1 [00:00<?, ?it/s]
# None
# Evaluating:   0%|          | 0/1 [00:00<?, ?it/s]
# None
# Evaluating:   0%|          | 0/1 [00:00<?, ?it/s]
# None
# Evaluating:   0%|          | 0/1 [00:00<?, ?it/s]
# None
# Evaluating:   0%|          | 0/1 [00:00<?, ?it/s]
# None
# Evaluating:   0%|          | 0/1 [00:00<?, ?it/s]
# None
# Evaluating:   0%|          | 0/1 [00:00<?, ?it/s]
# None
# Evaluating:   0%|          | 0/1 [00:00<?, ?it/s]
# None
# Evaluating:   0%|          | 0/1 [00:00<?, ?it/s]
# None
# Evaluating:   0%|          | 0/1 [00:00<?, ?it/s]
# None
# Evaluating:   0%|          | 0/1 [00:00<?, ?it/s]
# None
# Evaluating:   0%|          | 0/1 [00:00<?, ?it/s]
# None
# Evaluating:   0%|          | 0/1 [00:00<?, ?it/s]
# None
# Evaluating:   0%|          | 0/1 [00:00<?, ?it/s]
# None
# Evaluating:   0%|          | 0/1 [00:00<?, ?it/s]
# None
# Evaluating:   0%|          | 0/1 [00:00<?, ?it/s]
# None
# Evaluating:   0%|          | 0/1 [00:00<?, ?it/s]
# None
# Evaluating 20 test case(s) in parallel: |██████████|100% (20/20) [Time Taken: 01:23,  4.19s/test case]
# ======================================================================
#
# Metrics Summary
#
#   - ✅ Contextual Precision (score: 1.0, threshold: 0.5, strict: False, evaluation model: gpt-4o, reason: The score is 1.00 because all nodes are relevant and appropriately ranked. The nodes in the retrieval context extensively address how the Farmer's Handbook enhances farmers' decision-making abilities, highlighting aspects like 'enhancing awareness among farmers about sources of extension, information and services,' alignment with key topics such as 'Soil and Plant Nutrition,' and providing 'a holistic perspective of scientific Agriculture.' Great job!, error: None)
#   - ✅ Contextual Recall (score: 1.0, threshold: 0.5, strict: False, evaluation model: gpt-4o, reason: The score is 1.00 because all sentences in the expected output align perfectly with nodes in the retrieval context, demonstrating an excellent match. Great job!, error: None)
#   - ✅ Contextual Relevancy (score: 0.8823529411764706, threshold: 0.5, strict: False, evaluation model: gpt-4o, reason: The score is 0.88 because, although some aspects focus on 'other stakeholders', relevant statements highlight how the handbook aims to 'educate and equip the farmers to make proper plans' and enhance their 'awareness about sources of extension, information and services', which directly contributes to informed decision-making., error: None)
#   - ✅ Answer Relevancy (score: 1.0, threshold: 0.5, strict: False, evaluation model: gpt-4o, reason: The score is 1.00 because the response perfectly addresses the question about how the chapters in the Farmer's Handbook enhance farmers' decision-making abilities, with no irrelevant information present. Great job!, error: None)
#   - ✅ Answer Relevancy (ragas) (score: 0.8240658531454669, threshold: 0.5, strict: False, evaluation model: gpt-4o, reason: None, error: None)
#   - ✅ Faithfulness (score: 1.0, threshold: 0.5, strict: False, evaluation model: gpt-4o, reason: The score is 1.00 because there are no contradictions between the actual output and the retrieval context. Keep up the great work!, error: None)
#   - ✅ Hallucination (score: 0.0, threshold: 0.5, strict: False, evaluation model: gpt-4o, reason: The score is 0.00 because the actual output aligns well with the provided context, accurately reflecting the intents and content described without any contradictions., error: None)
#
# For test case:
#
#   - input: How can the chapters in the Farmer’s Handbook enhance farmers' ability to make informed agricultural decisions?
#   - actual output: The Farmer's Handbook chapters aim to educate and equip farmers to make proper plans and appropriate decisions, take advantage of improved technologies to increase production, assure food security for the family, and create market opportunities to increase income, considering available resources and anticipated risks like market fluctuations. The last chapter, “Farmer’s access to services,” enhances awareness among farmers about sources of extension, information and services, public and private extension services, agricultural credit, insurance and legal aspects through Information & Communication Technologies.
#
#   - expected output: The chapters in the Farmer’s Handbook enhance farmers' ability to make informed agricultural decisions by providing comprehensive knowledge and practical guidance on key aspects of farming. The first chapter equips farmers with foundational knowledge of Good Agricultural Practices and resource management, enabling them to select appropriate crops and cropping patterns. The second chapter on soil and plant nutrition helps farmers understand soil properties and nutrient management, encouraging sustainable and efficient crop production. The third chapter focuses on pest management, educating farmers on handling pests and diseases safely. The fourth chapter educates farmers on farm management strategies, enabling them to plan and use resources effectively. Lastly, the final chapter enhances farmers' access to information and services, including agricultural credit and insurance, through various communication technologies, helping farmers make economically and environmentally sustainable decisions.
#   - context: [' \nFarmer’s Handbook on Basic Agriculture\nPreface\nA\ngriculture is an important sector of Indian Economy as more than half of its population relies on Ag-\nriculture as principle source of income.  Research and Extension systems play major role in generation \nand dissemination of Agricultural technologies aiming at enhancing the income of farmers. The extension \nsystem adopts series of extension methods such as Training, demonstration, exposure visit to transfer \nthe technologies from lab to land. Majority of these extension efforts mainly focus on location and crop \nspecific technologies, and mostly on solution to problem basis. However, there is a need for equipping the \nfarmers with Basic knowledge of Agriculture in order to create a better knowledge platform at farmer level \nfor taking appropriate farm management decisions and to absorb modern technologies.  \nIn view of this, Desai Fruits and Vegetables Pvt. Ltd. (DFV), India, in cooperation with the Deutsche \nGesellschaft für Internationale Zusammenarbeit (GIZ) GmbH on behalf of the German Federal Ministry \nfor Economic Cooperation and Development (BMZ) in close cooperation with National Institute of Ag-\nricultural Extension Management (MANAGE- An Organization of Ministry of Agriculture, Government \nof India) brought out Farmer’s Handbook on Basic Agriculture to impart technical knowledge on Basic \nAgriculture to farmers to provide holistic perspective of scientific Agriculture.\nThis handbook is a product of series of brainstorming workshops and consultative meetings with various \nstakeholders such as Researchers, Academicians, Extension Functionaries, Agripreneurs, Master Trainers \nand Farmers. Based on the identified needs, the topics were prioritized and contents were developed with \nthe help of experts. The farmer-friendly content has been written in simple language, using more pictures \nwith practical examples for the benefit of farmers. \nThe book contains six chapters, each focusing on a particular topic. The first chapter, “General conditions \nfor cultivation of crops”\n, talks about the basic needs of farmers and farming sector, by providing basic \nknowledge on Good Agricultural Practices (GAP), enhancing the awareness of farmers on critical factors \nin selection of crops and cropping patterns, judicious use of natural resources such as soil and water, and \nemphasizing the importance of mechanization in the field of agriculture.\nThe second chapter “Soil and Plant Nutrition” is aimed at increasing the awareness and understanding of \nfarmers about soil, it’s structure, physical, chemical, biological properties, soil fertility and managing the \nsoil fertility in an economically and environmentally sustainable manner. It also focuses on the need for \nsoil testing, plant nutrition requirement, organic & inorganic fertilizers, and Integrated Nutrient Manage-\nment (INM) for efficient, economic and sustainable production of crops.\nThe third chapter of the book is about Pest Management, and focuses on enhancing the awareness of and \nunderstanding among farmers about the crop pests, diseases and weed management through Integrated \nPest Management. It also aims at sensitizing farmers on safe handling of chemicals and plant protection \nequipments as also elaborated further in the fifth chapter on “Occupational health and safety of farmers”\n. \nIt creates awareness about causes, preventive measures of health hazards, risks & fatalities in agriculture, \nand use of first aid in emergencies. It further includes safety tips and care to reduce the risk of injuries and \nfatalities while handling machineries and pesticides by farmers.\nTime and resources management is an integral part of each and every activity, be it service sector, busi-\nness or day-to-day activities of life. Farming sector too has not remained untouched by it. Therefore, the \nfourth chapter of the book is devoted to “Farm Management”\n. It is to educate and equi ...
#   - retrieval context: ['. It is to educate and equip the farmers to \nmake proper plans, take appropriate decisions and also to take advantage of the improved technologies \nto increase production, assure food security for the family and market opportunities to increase income \nconsidering available resources, anticipated risks, including market fluctuations.\n“Farmer’s access to services”\n, the last chapter of the book, aims at enhancing awareness among farmers \nabout sources of extension, information and services, public and private extension services, agricultural \ncredit, insurance and legal aspects through Information & Communication Technologies. The content is \nuseful not only for farmers but also for other stakeholders involved in farm advisory services such as Agri \ninput dealers, Agripreneurs, Kisan Call Centers and extension functionaries working at grass roots level. \nWe trust that this Handbook will benefit maximum number of farmers to make farming economically and \nenvironmentally more sustainable.\nB. Srinivas, IAS\nDirector General\nMANAGE', 'Farmer’s Handbook on Basic Agriculture\nContents\n1.\t\nGeneral Conditions for Cultivation of Crops\t \t\n\t\n\t\n\t\n1-32\n2.\t\nSoil and Plant Nutrition \t\n\t\n\t\n\t\n\t\n\t\n\t\n\t\n33-70\n3.\t\nPlant Protection\t \t\n\t\n\t\n\t\n\t\n\t\n\t\n\t\n71-96\n4.\t\nCategories of Pesticides and Precautions\t\t\n\t\n        97-98\n5.\t\nFarm Management\t\n\t\n\t\n\t\n\t\n\t\n\t\n\t\n99-120\n6.\t\nOccupational Health and Safety\t\n\t\n\t\n\t\n\t\n\t\n121-130\n7.\t\nFarmer’s Access to Service \t \t\n\t\n\t\n\t\n\t\n\t\n131-136', 'of India) brought out Farmer’s Handbook on Basic Agriculture to impart technical knowledge on Basic \nAgriculture to farmers to provide holistic perspective of scientific Agriculture.\nThis handbook is a product of series of brainstorming workshops and consultative meetings with various \nstakeholders such as Researchers, Academicians, Extension Functionaries, Agripreneurs, Master Trainers \nand Farmers. Based on the identified needs, the topics were prioritized and contents were developed with \nthe help of experts. The farmer-friendly content has been written in simple language, using more pictures \nwith practical examples for the benefit of farmers. \nThe book contains six chapters, each focusing on a particular topic. The first chapter, “General conditions \nfor cultivation of crops”\n, talks about the basic needs of farmers and farming sector, by providing basic \nknowledge on Good Agricultural Practices (GAP), enhancing the awareness of farmers on critical factors \nin selection of crops and cropping patterns, judicious use of natural resources such as soil and water, and \nemphasizing the importance of mechanization in the field of agriculture.\nThe second chapter “Soil and Plant Nutrition” is aimed at increasing the awareness and understanding of \nfarmers about soil, it’s structure, physical, chemical, biological properties, soil fertility and managing the \nsoil fertility in an economically and environmentally sustainable manner. It also focuses on the need for']
#
# ======================================================================
#
# Metrics Summary
#
#   - ✅ Contextual Precision (score: 1.0, threshold: 0.5, strict: False, evaluation model: gpt-4o, reason: The score is 1.00 because all nodes in the retrieval context are relevant and appropriately ranked, splendidly capturing the detailed range of topics and support related to the 'Farmer’s Handbook' by Shekara et al. Amazing job staying on target!, error: None)
#   - ✅ Contextual Recall (score: 0.75, threshold: 0.5, strict: False, evaluation model: gpt-4o, reason: The score is 0.75 because while the nodes in retrieval context confirm the involvement of Dr. P. Chandra Shekara, MANAGE, and Desai Fruits & Vegetables (1st node) and their role in assisting farmers (2nd node), as well as the associations with the Ministry of Agriculture (3rd node), they do not explicitly cover the specific topics like agricultural production, resource use, rural development, and practical farming techniques mentioned in the expected output., error: None)
#   - ✅ Contextual Relevancy (score: 0.5217391304347826, threshold: 0.5, strict: False, evaluation model: gpt-4o, reason: The score is 0.52 because although the relevant statements highlight the handbook's focus on educating farmers and increasing production, the reasons for irrelevancy emphasize that much of the context is about authorship and not directly about the handbook's topics., error: None)
#   - ✅ Answer Relevancy (score: 1.0, threshold: 0.5, strict: False, evaluation model: gpt-4o, reason: The score is 1.00 because the output is fully relevant, directly addressing the topics covered in the 'Farmer's Handbook' without any irrelevant information. Great job!, error: None)
#   - ✅ Answer Relevancy (ragas) (score: 0.803967557912352, threshold: 0.5, strict: False, evaluation model: gpt-4o, reason: None, error: None)
#   - ✅ Faithfulness (score: 1.0, threshold: 0.5, strict: False, evaluation model: gpt-4o, reason: The score is 1.00 because there are no contradictions. Great job maintaining perfect alignment with the retrieval context!, error: None)
#   - ✅ Hallucination (score: 0.0, threshold: 0.5, strict: False, evaluation model: gpt-4o, reason: The score is 0.00 because the actual output fully aligns with the context, with no contradictions present., error: None)
#
# For test case:
#
#   - input: What topics are addressed in the 'Farmer’s Handbook' by Shekara et al., with support from Desai and MANAGE?
#   - actual output: The 'Farmer’s Handbook on Basic Agriculture' by Shekara et al., with support from Desai and MANAGE, addresses the need to equip farmers with basic knowledge of agriculture to create a better knowledge platform for farm management decisions and to absorb modern technologies. It aims to educate farmers to make proper plans, take appropriate decisions, and take advantage of improved technologies to increase production, assure food security, and increase income. It also enhances awareness among farmers about sources of extension, information and services, public and private extension services, agricultural credit, insurance and legal aspects through Information & Communication Technologies.
#
#   - expected output: The 'Farmer’s Handbook on Basic Agriculture' by Shekara et al., with support from Desai and MANAGE, addresses a range of topics relevant to basic agricultural practices. This includes agricultural production, resource use, rural development, and practical farming techniques. The handbook is designed to assist farmers with fundamental agricultural knowledge and improve productivity and resource management, supported by entities like Desai Fruits & Vegetables and MANAGE under the Ministry of Agriculture, Government of India.
#   - context: [' \nFarmer’s Handbook on Basic Agriculture\nFarmer’s Handbook on Basic Agriculture\nPrepared & compiled by\nDr. P. Chandra Shekara\nNational Institute of Agricultural Extension  \nManagement (MANAGE)\nMinistry of Agriculture, GoI\nHyderabad, Andhra Pradesh\nIndia\nDr. N. Balasubramani\nNational Institute of Agricultural Extension  \nManagement (MANAGE)\nMinistry of Agriculture, GoI \nHyderabad, Andhra Pradesh\nIndia\nDr. Rajeev Sharma\nDr. Chitra Shukla\nDesai Fruits & Vegetables Pvt. Ltd.\nNavsari, Gujarat\nIndia\nDr. Ajit Kumar\nDesai Fruits & Vegetables Pvt. Ltd.\nNavsari, Gujarat \nIndia\nBakul C. Chaudhary\nDesai Fruits & Vegetables Pvt. Ltd.\nNavsari, Gujarat \nIndia\nMr. Max Baumann\nPlanning Officer\nSection “Agricultural Production & Resource Use”\nDivision 45 - Rural Development and Agriculture\nDeutsche Gesellschaft für Internationale Zusam-\nmenarbeit (GIZ) GmbH\nGermany\nMax.Baumann@giz.de\nFinanced by\nDesai Fruits & Vegetables Pvt. Ltd.\nNavsari, Gujarat, India\nGerman Federal Ministry for Economic Cooperation \nand Development (BMZ)\nPublished by\nDesai Fruits & Vegetables Pvt. Ltd.\nNavsari, Gujarat\nIndia\nSecond Edition: August 2016\n']
#   - retrieval context: ['Farmer’s Handbook on Basic Agriculture\nFarmer’s Handbook on Basic Agriculture\nPrepared & compiled by\nDr. P. Chandra Shekara\nNational Institute of Agricultural Extension  \nManagement (MANAGE)\nMinistry of Agriculture, GoI\nHyderabad, Andhra Pradesh\nIndia\nDr. N. Balasubramani\nNational Institute of Agricultural Extension  \nManagement (MANAGE)\nMinistry of Agriculture, GoI \nHyderabad, Andhra Pradesh\nIndia\nDr. Rajeev Sharma\nDr. Chitra Shukla\nDesai Fruits & Vegetables Pvt. Ltd.\nNavsari, Gujarat\nIndia\nDr. Ajit Kumar\nDesai Fruits & Vegetables Pvt. Ltd.\nNavsari, Gujarat \nIndia\nBakul C. Chaudhary\nDesai Fruits & Vegetables Pvt. Ltd.\nNavsari, Gujarat \nIndia\nMr. Max Baumann\nPlanning Officer\nSection “Agricultural Production & Resource Use”\nDivision 45 - Rural Development and Agriculture\nDeutsche Gesellschaft für Internationale Zusam-\nmenarbeit (GIZ) GmbH\nGermany\nMax.Baumann@giz.de\nFinanced by\nDesai Fruits & Vegetables Pvt. Ltd.\nNavsari, Gujarat, India\nGerman Federal Ministry for Economic Cooperation \nand Development (BMZ)\nPublished by\nDesai Fruits & Vegetables Pvt. Ltd.\nNavsari, Gujarat\nIndia\nSecond Edition: August 2016', '. It is to educate and equip the farmers to \nmake proper plans, take appropriate decisions and also to take advantage of the improved technologies \nto increase production, assure food security for the family and market opportunities to increase income \nconsidering available resources, anticipated risks, including market fluctuations.\n“Farmer’s access to services”\n, the last chapter of the book, aims at enhancing awareness among farmers \nabout sources of extension, information and services, public and private extension services, agricultural \ncredit, insurance and legal aspects through Information & Communication Technologies. The content is \nuseful not only for farmers but also for other stakeholders involved in farm advisory services such as Agri \ninput dealers, Agripreneurs, Kisan Call Centers and extension functionaries working at grass roots level. \nWe trust that this Handbook will benefit maximum number of farmers to make farming economically and \nenvironmentally more sustainable.\nB. Srinivas, IAS\nDirector General\nMANAGE', 'Farmer’s Handbook on Basic Agriculture\nPreface\nA\ngriculture is an important sector of Indian Economy as more than half of its population relies on Ag-\nriculture as principle source of income.  Research and Extension systems play major role in generation \nand dissemination of Agricultural technologies aiming at enhancing the income of farmers. The extension \nsystem adopts series of extension methods such as Training, demonstration, exposure visit to transfer \nthe technologies from lab to land. Majority of these extension efforts mainly focus on location and crop \nspecific technologies, and mostly on solution to problem basis. However, there is a need for equipping the \nfarmers with Basic knowledge of Agriculture in order to create a better knowledge platform at farmer level \nfor taking appropriate farm management decisions and to absorb modern technologies.  \nIn view of this, Desai Fruits and Vegetables Pvt. Ltd. (DFV), India, in cooperation with the Deutsche \nGesellschaft für Internationale Zusammenarbeit (GIZ) GmbH on behalf of the German Federal Ministry \nfor Economic Cooperation and Development (BMZ) in close cooperation with National Institute of Ag-\nricultural Extension Management (MANAGE- An Organization of Ministry of Agriculture, Government \nof India) brought out Farmer’s Handbook on Basic Agriculture to impart technical knowledge on Basic \nAgriculture to farmers to provide holistic perspective of scientific Agriculture.']
#
# ======================================================================
#
# Metrics Summary
#
#   - ✅ Contextual Precision (score: 1.0, threshold: 0.5, strict: False, evaluation model: gpt-4o, reason: The score is 1.00 because the relevant nodes in the retrieval context are appropriately ranked higher. The first and second nodes relate directly to vital guidelines for effective crop cultivation, focusing on crop selection and soil preparation. The third node pertains to 'market considerations, policies, schemes, and post-harvest storage', which are not directly related to cultivation guidelines, thus correctly placed last., error: None)
#   - ✅ Contextual Recall (score: 0.8, threshold: 0.5, strict: False, evaluation model: gpt-4o, reason: The score is 0.80 because the majority of the expected output's guidelines on crop cultivation relate well to the nodes in retrieval context, covering aspects like crop selection, soil preparation, irrigation, fertilizers, and pest management. However, the concluding sentence about optimizing growth conditions is a general statement not directly linked to the contents of the nodes in the retrieval context., error: None)
#   - ✅ Contextual Relevancy (score: 0.6666666666666666, threshold: 0.5, strict: False, evaluation model: gpt-4o, reason: The score is 0.67 because the relevant statements, like 'Climatic factors,' focus on core cultivation guidelines that align with the question, but many retrieved contexts discuss unrelated topics such as 'health and safety' and 'market information,' detracting from the main focus on cultivation guidelines., error: None)
#   - ✅ Answer Relevancy (score: 1.0, threshold: 0.5, strict: False, evaluation model: gpt-4o, reason: The score is 1.00 because the response perfectly addresses the input without any irrelevant statements. Well done!, error: None)
#   - ✅ Answer Relevancy (ragas) (score: 0.9015597023082268, threshold: 0.5, strict: False, evaluation model: gpt-4o, reason: None, error: None)
#   - ✅ Faithfulness (score: 1.0, threshold: 0.5, strict: False, evaluation model: gpt-4o, reason: The score is 1.00 because there are no contradictions. Everything aligns perfectly! Great job!, error: None)
#   - ✅ Hallucination (score: 0.0, threshold: 0.5, strict: False, evaluation model: gpt-4o, reason: The score is 0.00 because the actual output is fully aligned with the context, with no contradictions present, indicating no hallucination., error: None)
#
# For test case:
#
#   - input: What vital guidelines from the Farmer's Handbook should be followed for effective crop cultivation?
#   - actual output: Based on the Farmer's Handbook, vital guidelines for effective crop cultivation include considering climatic factors (temperature, rainfall, humidity, etc.), soil conditions (type, pH, fertility), and water availability and quality. Other guidelines include cropping system options, past experiences, expected profit and risk, market information, government policies, access to extension services, availability of agricultural inputs and credit, and post-harvest storage and processing technologies.
#
#   - expected output: For effective crop cultivation, key guidelines from the Farmer's Handbook include selecting suitable crop varieties for the local climate, ensuring proper soil preparation, implementing efficient irrigation systems, applying appropriate fertilizers at recommended dosages, and managing pests and diseases through integrated pest management practices. These steps help optimize growth conditions and yield successful harvests.
#   - context: ['2\nGeneral Conditions for Cultivation of Crops\nFarmer’s Handbook on Basic Agriculture\n']
#   - retrieval context: ['General Conditions for Cultivation of Crops\nFarmer’s Handbook on Basic Agriculture\n3\n1.3. Factors influencing decisions on \nthe selection of crops and cropping \nsystem\nClimatic factors \nIs the crop/cropping system suitable for local weath-\ner parameters such as temperature, rainfall, sun \nshine hours, relative humidity, wind velocity, wind \ndirection, seasons and agro-ecological situations?\nSoil conditions \nIs the crop/cropping system suitable for local soil \ntype, pH and soil fertility?  \nWater \n• \nDo you have adequate water source like a tanks, \nwells, dams, etc.? \n• \nDo you receive adequate rainfall?\n• \nIs the distribution of rainfall suitable to grow \nidentified crops?\n• \nIs the water quality suitable?\n• \nIs electricity available for lifting the water?\n• \nDo you have pump sets, micro irrigation sys-\ntems?\nCropping system options \n• \nDo you have the opportunity to go for inter-\ncropping, mixed cropping, multi-storeyed \ncropping, relay cropping, crop rotation, etc.?\n• \nDo you have the knowledge on cropping sys-\ntems management?\nPast and present experiences of  \nfarmers \n• \nWhat were your previous experiences with re-\ngard to the crop/cropping systems that you are \nplanning to choose?\n• \nWhat is the opinion of your friends, relatives \nand neighbours on proposed crop/cropping \nsystems?\nExpected profit and risk \n• \nHow much profit are you expecting from the \nproposed crop/cropping system?\n• \nWhether this profit is better than the existing \ncrop/cropping system?\n•', 'Farmer’s Handbook on Basic Agriculture\nContents\n1.\t\nGeneral Conditions for Cultivation of Crops\t \t\n\t\n\t\n\t\n1-32\n2.\t\nSoil and Plant Nutrition \t\n\t\n\t\n\t\n\t\n\t\n\t\n\t\n33-70\n3.\t\nPlant Protection\t \t\n\t\n\t\n\t\n\t\n\t\n\t\n\t\n71-96\n4.\t\nCategories of Pesticides and Precautions\t\t\n\t\n        97-98\n5.\t\nFarm Management\t\n\t\n\t\n\t\n\t\n\t\n\t\n\t\n99-120\n6.\t\nOccupational Health and Safety\t\n\t\n\t\n\t\n\t\n\t\n121-130\n7.\t\nFarmer’s Access to Service \t \t\n\t\n\t\n\t\n\t\n\t\n131-136', '4\nGeneral Conditions for Cultivation of Crops\nFarmer’s Handbook on Basic Agriculture\nwhere to sell? When to sell? Whom to sell to? \nWhat form to sell in? What price to sell for?\n• \nDo you get real time market information and \nmarket intelligence on proposed crops?\nPolicies and schemes\n• \nDo Government policies favour your crops?\n• \nIs there any existing scheme which incentivises \nyour crop?\n• \nAre you eligible to avail those benefits?\nPublic and private extension influence\nDo you have access to Agricultural Technology \nManagement Agency (ATMA)/ Departmental \nextension functionaries to get advisory?\n• \nDo you know Kissan Call Center?\n• \nDo you have access to KVKs, Agricultural Uni-\nversities and ICAR organizations?\n• \nDo you subscribe agricultural magazines?\n• \nDo you read agricultural articles in newspa-\npers?\n• \nDo you get any support from input dealers, Ag-\nribusiness Companies, NGOs, Agriclinics and \nAgribusiness Centers?\nAvailability of required agricultural \ninputs including agricultural credit \n• \nDo you get adequate agricultural inputs such as \nseeds, fertilizers, pesticides, and implements in \ntime?\n• \nDo you have access to institutional credit?\nPost harvest storage and processing \ntechnologies\n• \nDo you have your own storage facility? \n• \nIf not, do you have access to such facility?\n• \nDo you have access to primary processing facil-\nity?\n• \nDo you know technologies for value addition of \nyour crop?\n• \nDo you have market linkage for value added \nproducts?\n•']
#
# ======================================================================
#
# Metrics Summary
#
#   - ✅ Contextual Precision (score: 1.0, threshold: 0.5, strict: False, evaluation model: gpt-4o, reason: The score is 1.00 because relevant nodes in the retrieval context were suitably ranked higher. The first node detailed 'Contour trenching for runoff collection', closely aligned with the input query about frost protection methods. In contrast, less relevant nodes discussing general agricultural techniques, such as zero tillage and mulching, without focus on frost protection, were rightly ranked lower. Great job maintaining precision!, error: None)
#   - ❌ Contextual Recall (score: 0.4, threshold: 0.5, strict: False, evaluation model: gpt-4o, reason: The score is 0.40 because while some aspects like contour trenching for runoff collection and straw thatching providing protection are supported by nodes in the retrieval context, there are key details such as soil moisture maintenance, temperature moderation, and frost protection that are not sufficiently detailed or linked to the correct methods in the provided nodes., error: None)
#   - ❌ Contextual Relevancy (score: 0.03508771929824561, threshold: 0.5, strict: False, evaluation model: gpt-4o, reason: The score is 0.04 because the retrieval context included a relevant statement: 'Straw Thatching: Protecting young seedlings against cold by covering with straw thatching.' However, most of the context was unrelated to frost protection methods, focusing instead on other agricultural practices., error: None)
#   - ✅ Answer Relevancy (score: 1.0, threshold: 0.5, strict: False, evaluation model: gpt-4o, reason: The score is 1.00 because the output directly addresses the input without any irrelevant information, focusing solely on how contour trenching and straw thatching protect seedlings from frost. Great job on providing a precise and relevant answer!, error: None)
#   - ✅ Answer Relevancy (ragas) (score: 0.8145278773141604, threshold: 0.5, strict: False, evaluation model: gpt-4o, reason: None, error: None)
#   - ✅ Faithfulness (score: 1.0, threshold: 0.5, strict: False, evaluation model: gpt-4o, reason: The score is 1.00 because the actual output is perfectly aligned with the retrieval context, with no contradictions present. Great job maintaining consistency!, error: None)
#   - ✅ Hallucination (score: 0.0, threshold: 0.5, strict: False, evaluation model: gpt-4o, reason: The score is 0.00 because the actual output is fully aligned with the context, with no contradictions or unsupported information present., error: None)
#
# For test case:
#
#   - input: How do contour trenching and straw thatching help protect seedlings from frost?
#   - actual output: Straw thatching protects young seedlings against the cold. I'm sorry, but the text does not describe how contour trenching helps protect seedlings from frost.
#
#   - expected output: Contour trenching helps in runoff collection, which indirectly aids in maintaining soil moisture and moderating temperature fluctuations, offering some protection against frost. Straw thatching provides direct protection for young seedlings against cold by covering them, thereby helping to mitigate frost impact.
#   - context: ['General Conditions for Cultivation of Crops\nFarmer’s Handbook on Basic Agriculture\n9\nCoping options for farmers continued....\n \nContour trenching for runoff  collec-\ntion\nConventional Raised Bed Planting\n• \n20-25% Saving in irrigation water\n \nShelterbelts\n• \nShelterbelts reduce wind velocity.\n• \nModerate temperature.\n• \nReduce evaporative loss and conserve soil \nmoisture.\nStraw Thatching\n• \nProtecting young seedlings against cold by cov-\nering with straw thatching.\nFrost Protection\n']
#   - retrieval context: ['General Conditions for Cultivation of Crops\nFarmer’s Handbook on Basic Agriculture\n9\nCoping options for farmers continued....\n \nContour trenching for runoff  collec-\ntion\nConventional Raised Bed Planting\n• \n20-25% Saving in irrigation water\n \nShelterbelts\n• \nShelterbelts reduce wind velocity.\n• \nModerate temperature.\n• \nReduce evaporative loss and conserve soil \nmoisture.\nStraw Thatching\n• \nProtecting young seedlings against cold by cov-\nering with straw thatching.\nFrost Protection', '12\nGeneral Conditions for Cultivation of Crops\nFarmer’s Handbook on Basic Agriculture\nConservation farming\n• \nFarming across the slope\n• \nStrip cropping\n• \nRotations\n• \nMixed cropping and intercropping\n• \nSurface mulching\n• \nTimely farm operations\n• \nImproved water user efficiency\n• \nLand levelling\n• \nProviding safe drainage\n• \nIntermittent terraces\n• \nGrowing vegetation on the bunds\nVegetation and vegetative management\n• \nStrip cropping\n• \nStubble mulching\n• \nMulching\nWind erosion management\n• \nProtect the soil surface with a cover of vegeta-\ntion or vegetative residues.\n• \nProduce or bring to the surface soil aggregates \nor clods which are large enough to resist the \nwind force.\n• \nRoughen the land surface to reduce wind veloc-\nity and trap drifting soil.\n• \nEstablish barriers or trap strips at intervals to \nreduce wind velocity and soil drifting.\nBest practices to control soil blowing\n• \nDeep ploughing\n• \nSummer ploughing\n• \nSurface roughness\n• \nConserving moisture\n• \nWind breaks and shelterbelts\n• \nMechanical or vegetative barriers\nFor instance: Shelterbelts for moderating micro-\nclimate\n• \nShelterbelts reduce wind velocity\n• \nModerate temperature\n• \nReduce evaporative loss and conserve soil \nmoisture\nWater erosion can be managed by \n• \nIn situ water harvesting\n• \nSummer ploughing\nOverland flow management\n• \nContour bund\n• \nGraded bund\n• \nBroad based bund\n• \nBench terrace\n• \nWater harvesting and recycling \nZero tillage\n• \nSeveral practices are in use such as zero till-', 'Overland flow management\n• \nContour bund\n• \nGraded bund\n• \nBroad based bund\n• \nBench terrace\n• \nWater harvesting and recycling \nZero tillage\n• \nSeveral practices are in use such as zero till-\nage, minimum tillage and direct seeding.\n• \nPlanting crops in previously untilled soil by \nopening a narrow slot, trench or band only \nof sufficient width and depth to obtain seed \ncoverage. No other soil tillage is done.\nAdvantages of zero tillage farming\n• \nErosion control: Retained stubble and crop \nresidue reduces soil erosion and enhances \nsoil fertility\n• \nMoisture conservation: Stubble traps water, \nreduce runoff water, better infiltration lead-\ning to improved soil moisture condition\n• \nHigher nitrogen availability\n• \nSeedling protection: Stubbles protects young \nseedling from wind and heat\n• \nCrop yields will be on par with traditional \ntillage system. However good yield can be \nharvested during dry years\n• \nReduce labour and save time\n• \nSavings on equipment cost\n• \nSavings on oil/fuel cost\nMulching: Benefits of crop residue mulch-\ning are\n• \nIncreased availability of water and organic \nmatter \n• \nLess erosion\n• \nEnvironment protection\nAdditional benefit to farmers\n• \nLess drought susceptibility\n• \nImproved soil quality and fertilizer efficiency\n• \nMinimises long term dependency on external \ninputs']
#
# ======================================================================
#
# Metrics Summary
#
#   - ✅ Contextual Precision (score: 1.0, threshold: 0.5, strict: False, evaluation model: gpt-4o, reason: The score is 1.00 because the relevant nodes in the retrieval context are perfectly ranked higher than the irrelevant node. The first node discusses Partnership Farming India (PFI) in enabling farmers and aligns with the expected output, while the second node details technical agricultural knowledge benefits. The third node, ranked last, does not specifically relate to PFI's role, thereby having an irrelevant node correctly placed lower., error: None)
#   - ✅ Contextual Recall (score: 1.0, threshold: 0.5, strict: False, evaluation model: gpt-4o, reason: The score is 1.00 because every aspect of the expected output is strongly supported by relevant details in the nodes in the retrieval context, demonstrating complete alignment., error: None)
#   - ✅ Contextual Relevancy (score: 0.7586206896551724, threshold: 0.5, strict: False, evaluation model: gpt-4o, reason: The score is 0.76 because while the input asks about how PFI enhances decision-making and competitive production capabilities of Indian farmers, the relevant statement mentions that 'PFI strengthens farmers’ and farm workers’ management skills to adopt modern agricultural practices and concepts,' which is somewhat aligned. However, the reasons for irrelevancy highlight that the retrieval context focuses on 'cooperation between DFV and GIZ,' which does not directly address the specifics of PFI's impact on farmers' decision-making abilities., error: None)
#   - ✅ Answer Relevancy (score: 1.0, threshold: 0.5, strict: False, evaluation model: gpt-4o, reason: The score is 1.00 because the output is perfectly relevant and directly addresses how PFI enhances the decision-making and competitive production capabilities of Indian farmers without any irrelevant information. Great job!, error: None)
#   - ✅ Answer Relevancy (ragas) (score: 0.8411011526894399, threshold: 0.5, strict: False, evaluation model: gpt-4o, reason: None, error: None)
#   - ✅ Faithfulness (score: 1.0, threshold: 0.5, strict: False, evaluation model: gpt-4o, reason: The score is 1.00 because there are no contradictions, indicating perfect alignment between the actual output and the retrieval context. Great job maintaining accuracy!, error: None)
#   - ✅ Hallucination (score: 0.0, threshold: 0.5, strict: False, evaluation model: gpt-4o, reason: The score is 0.00 because the actual output fully aligns with the provided context, with no contradictions present., error: None)
#
# For test case:
#
#   - input: In what ways does PFI enhance the decision-making and competitive production capabilities of Indian farmers?
#   - actual output: PFI enables farmers to be self-sufficient decision-makers and strengthens their management skills to adopt modern agricultural practices. It also enhances the international competitiveness of smallholders’ agricultural produce by giving farmers and workers in Gujarat and Maharashtra access to practical agricultural education.
#
#   - expected output: PFI enhances the decision-making and competitive production capabilities of Indian farmers by providing practical agricultural education aimed at making them self-sufficient "agripreneurs." This education emphasizes flexible production systems, modern agricultural practices, and management skills. Additionally, PFI strengthens competitiveness in international markets by improving the quality of produce from smallholders in Gujarat and Maharashtra through upscaling production and offering access to advanced agricultural techniques.
#   - context: ['Farmer’s Handbook on Basic Agriculture\nAcknowledgement\nH\nigher demand for agricultural raw material is now anticipated and agriculture is not any more about \nproducing farm products and selling them exclusively at the local market. Instead farmers today have \na world market to serve. But the new chances bring new challenges. Farmers and agricultural enterprises, \nwilling to be part of the new expanding world market, not only have to take into consideration customers’ \npreferences whom they want to serve, but also adhere to international trade regulations set by WTO and \ncomply with high production and quality standards required by the importing countries.\nAgriculture contributes around 17% to GDP and continues to be among the most important and success-\nful sectors in India. Around 58% of the Indian population depend on agriculture for their livelihood. Apart \nfrom delivering the local industries with top quality raw materials for processing, agriculture provides \nalmost 10% of total export earnings. However, to support the impressive Indian economic growth in the \ncoming years, agriculture will have to contribute more towards value addition, productivity enhancement, \nhigh quality products and trained manpower to successfully tackle these challenges.\nThe states of Gujarat and Maharashtra have competitive advantages for the production of several com-\nmodities. However, productivity and competitiveness remains low. Rising quality requirements of export \nand domestic markets require an up-scaling of the production which is only feasible with educated farmers \nand skilled workers.\nDesai Fruits and Vegetables (DFV)in cooperation with the Deutsche Gesellschaft für Internationale \nZusammenarbeit(GIZ) GmbH on behalf of the German Federal Ministry for Economic Cooperation and \nDevelopment (BMZ) takes up the existing education gap by implementing a development partnership \ncalled “Partnership Farming India”\n.\nThe goal of Partnership Farming India (PFI) is to enable farmers to be self-sufficient decision-makers, \n“agripreneurs”\n, which allows for a more flexible production system and highlights farming as profession by \nchoice and not by inheritance. \nFurthermore, PFI strengthens farmers’ and farm workers’ management skills to adopt modern agricul-\ntural practices and concepts and enhance the international competitiveness of smallholders’ agricultural \nproduce by giving farmers and workers in Gujarat and Maharashtra access to practical agricultural educa-\ntion. Therefore, DFV and GIZ in close cooperation with the National Institute of Agricultural Extension \nManagement (MANAGE, an organization of Ministry of Agriculture, Government of India) developed the \ntraining material on basic agricultural knowledge and skills.\nThe states of Gujarat and Maharashtra will serve as an example on how to establish long term successful \nand trustful business relationships by combining small scale production in the field with large scale pro-\ncessing and marketing. I am confident that this effort will serve the Indian agriculture as a replicable model \nmake lasting contributions towards sustainable agriculture and prosperous farmers.\nI would like to express my sincere gratitude to the people and institutions namely MANAGE, DFV and \nGIZ,which supported this project and enabled making information available. This is a useful source of in-\nformation for farmers, trainers, and other interested persons to improve not only the agriculture but also \nthe livelihood of the farming community.\nMrs. Sabine Preuss \nGIZ-India Programme Director \n \nNatural Resource Management\n']
#   - retrieval context: ['modities. However, productivity and competitiveness remains low. Rising quality requirements of export \nand domestic markets require an up-scaling of the production which is only feasible with educated farmers \nand skilled workers.\nDesai Fruits and Vegetables (DFV)in cooperation with the Deutsche Gesellschaft für Internationale \nZusammenarbeit(GIZ) GmbH on behalf of the German Federal Ministry for Economic Cooperation and \nDevelopment (BMZ) takes up the existing education gap by implementing a development partnership \ncalled “Partnership Farming India”\n.\nThe goal of Partnership Farming India (PFI) is to enable farmers to be self-sufficient decision-makers, \n“agripreneurs”\n, which allows for a more flexible production system and highlights farming as profession by \nchoice and not by inheritance. \nFurthermore, PFI strengthens farmers’ and farm workers’ management skills to adopt modern agricul-\ntural practices and concepts and enhance the international competitiveness of smallholders’ agricultural \nproduce by giving farmers and workers in Gujarat and Maharashtra access to practical agricultural educa-\ntion. Therefore, DFV and GIZ in close cooperation with the National Institute of Agricultural Extension \nManagement (MANAGE, an organization of Ministry of Agriculture, Government of India) developed the \ntraining material on basic agricultural knowledge and skills.\nThe states of Gujarat and Maharashtra will serve as an example on how to establish long term successful', 'General Conditions for Cultivation of Crops\nFarmer’s Handbook on Basic Agriculture\n1\nA\ngricultural Universities, Research Institutes, \nKrishi Vigyan Kendras have been generat-\ning ample technologies to improve the productiv-\nity and profitability of the farmers. How many of \nthese technologies are reaching the farmers? Base-\nline Situation Assessment conducted by Partner-\nship farming in India, in Gujarat and Maharashtra, \nclearly indicated that farmers with access to techni-\ncal knowledge on agriculture realized better income \ncompared to others. Fifty one percent of sample \nfarmers who were part of partnership farming In-\ndia had knowledge of soil testing compared to only \n28% of control group. Mulching and intercropping \nas a practice were not widely adopted by control \ngroup of farmers. They were less aware about other \norganic fertilizers. Fertigation as a method of appli-\ncation of fertilizers was not widely practiced by con-\ntrol group. Farmers who accessed information from \nagricultural universities and magazines were less in \nnumber in the control group. The treatment farmers \nhad an average yield of 35.65 tons and control farm-\ners had yield of 22.36 tons of banana per acre. The \naverage net income of the treatment farmers was Rs \n93,822 and for the control farmers Rs.81,659. More \nthan 85% of the farmers wanted basic education on \nagriculture and crop production and ready to pay \nfor undergoing such basic education and training.', 'systems?\nExpected profit and risk \n• \nHow much profit are you expecting from the \nproposed crop/cropping system?\n• \nWhether this profit is better than the existing \ncrop/cropping system?\n• \nWhat are the risks you are anticipating in the \nproposed crop/cropping system?\n• \nDo you have the solution? Can you manage the \nrisks?\n• \nIs it worth to take the risks for anticipated prof-\nits?\nEconomic conditions of farmers  \nincluding land holding\n• \nAre the proposed crop/cropping systems suit-\nable for your size of land holding?\n• \nAre your financial resources adequate to man-\nage the proposed crop/cropping system?\n• \nIf not, can you mobilize financial resources \nthrough alternative routes?\nLabour availability and mechanization \npotential\n• \nCan you manage the proposed crop/cropping \nsystem through your family labour?\n• \nIf not, do you have adequate labours to manage \nthe same?\n• \nIs family/hired labour equipped to handle the \n ...
#
# ...
#
# ======================================================================
#
# Metrics Summary
#
#   - ✅ Contextual Precision (score: 1.0, threshold: 0.5, strict: False, evaluation model: gpt-4o, reason: The score is 1.00 because all relevant nodes in the retrieval context are ranked correctly and align perfectly with the input. Each node provides precise coverage on aspects such as 'The main cause of water erosion is unmanaged runoff,' types of erosion like 'rills develop' and 'stream channel erosion,' and how vegetation contributes through 'Interception of rainfall' and 'Root structure.' Great job!, error: None)
#   - ✅ Contextual Recall (score: 0.875, threshold: 0.5, strict: False, evaluation model: gpt-4o, reason: The score is 0.88 because the majority of the expected content regarding the role of runoff, erosion, and vegetation in soil conservation is supported by nodes in the retrieval context. However, node details do not explicitly address how sheet erosion uniformly removes topsoil, which impacted the overall score., error: None)
#   - ✅ Contextual Relevancy (score: 0.6590909090909091, threshold: 0.5, strict: False, evaluation model: gpt-4o, reason: The score is 0.66 because, while there are relevant statements discussing 'the main cause of water erosion is unmanaged runoff' and 'how vegetation reduces runoff', many statements in the context do not directly address the roles of runoff, erosion, or vegetation in soil and water conservation, as indicated by reasons such as 'general conditions for cultivation of crops does not directly address the roles'., error: None)
#   - ✅ Answer Relevancy (score: 1.0, threshold: 0.5, strict: False, evaluation model: gpt-4o, reason: The score is 1.00 because the response perfectly addresses every aspect of the question without any irrelevant information. It's concise and directly related to the roles of runoff, different types of erosion, and vegetation in soil and water conservation within agriculture. Great job!, error: None)
#   - ✅ Answer Relevancy (ragas) (score: 0.8557421359118883, threshold: 0.5, strict: False, evaluation model: gpt-4o, reason: None, error: None)
#   - ✅ Faithfulness (score: 1.0, threshold: 0.5, strict: False, evaluation model: gpt-4o, reason: The score is 1.00 because there are no contradictions! Keep up the great work!, error: None)
#   - ✅ Hallucination (score: 0.0, threshold: 0.5, strict: False, evaluation model: gpt-4o, reason: The score is 0.00 because the actual output accurately summarizes the roles of runoff, erosion, and vegetation in soil and water conservation as discussed in the context, with no contradictions., error: None)
#
# For test case:
#
#   - input: What are the roles of runoff, different types of erosion, and vegetation in soil and water conservation within agriculture?
#   - actual output: Here's what the provided text says about the roles of runoff, erosion, and vegetation in soil and water conservation:
#
# *   **Runoff:** Unmanaged runoff is a main cause of water erosion.
#
# *   **Types of Erosion:**
#     *   **Water erosion:** Removes soil from the land's surface through water in motion. Unmanaged runoff is the main cause of water erosion.
#     *   **Wind erosion:** Destroys valuable topsoil.
#
# *   **Vegetation:** Vegetation reduces runoff through interception of rainfall, root structure, biological influences, and transpiration effects. It intercepts raindrops, hinders runoff, aggregates soil, increases pore space and water holding capacity, and increases soil storage capacity by transpiration.
#
#   - expected output: Runoff, erosion, and vegetation play crucial roles in soil and water conservation in agriculture. Runoff, caused by unmanaged rainfall or irrigation, contributes to water erosion by transporting soil particles away, exacerbating soil degradation. Different types of erosion include water erosion, sheet erosion, and rill erosion. Water erosion removes soil from the land's surface, while sheet erosion uniformly removes topsoil, often going unnoticed but severely impacting soil fertility. Rill erosion, characterized by shallow channels, is more visible and can be addressed through cultivation. Vegetation helps reduce runoff and erosion by intercepting rainfall, binding soil with root structures, and enhancing soil's water-holding capacity through biological processes. Implementing effective vegetation cover can significantly improve soil stability and water retention, essential for sustainable agriculture.
#   - context: ['10\nGeneral Conditions for Cultivation of Crops\nFarmer’s Handbook on Basic Agriculture\n1.5. Soil and Water Conservation\nS\noil and water are our precious heritage. Hence, \nit is obligatory on our part to protect and hand \nover these resources to further generations. It is \nestimated that about 50% of the cultivated area in \nIndia suffers from severe soil erosion and requires \nremedial measures. \n• \nWater resources are essential for increasing and \nstabilizing crop production.\n• \nWind erosion has been responsible for destroy-\ning the valuable top soil.\n1.5.1. Degradation of soil and water \ntakes place with water and wind ero-\nsion\n• \nThe main cause of water erosion is unmanaged \nrunoff.\n• \nRunoff is the portion of the rainfall or irriga-\ntion water applied which leaves a field either as \nsurface or as subsurface flow.\nSeveral factors are responsible for runoff \n• \nClimatic factors: Precipitation characteristics - \nduration, intensity, distribution, direction, tem-\nperature, humidity, wind velocity.\n• \nWatershed characteristics: Geological shape of \nthe catchments, size and shape of the catch-\nments, topography, drainage pattern.\n• \nBarren land without vegetation\n• \nSoil types: \n• \nSandy soil: Average rain – no problem of \nerosion. High intensity – More serious of \nless binding material i.e. fine soil particle.\n• \nClay soil: Ordinary rain – more runoff in \nmoderate and steep slopes but high water \nholding capacity. \n• \nSilt loam, loamy and fine sandy loam: More \ndesirable soils from the point of view of \nminimizing soil erosion.\nHow vegetation reduces runoff\n• \nInterception of rainfall\n• \nRoot structure \n• \nBiological influences\n• \nTranspiration effects\n• \nIntercept, absorb the impact of raindrop\n• \nHindrance to runoff water slows down the rate \nat which travels down the slope\n• \nKnitting and binding effect aggregates the soil \ninto granules \n• \nDie and decay increase pore space and water \nholding capacity\n• \nOne cubic meter of soil has several kilometres \nof root fibre\n• \nMore vegetative cover, most active soil fauna, \nchannels of earth worm, beetles and other life\n• \nVegetation increases the storage capacity of \nthe soil for rainfall by the transpiration of large \nquantities of moistures from the soil\nSoil erosion \nSoil erosion is the detachment and transportation \nof soil material from one place to another through \nthe action of wind, water in motion or by the hitting \naction of the rain drops.\n• \nWhen the vegetation is removed and land is \nput under cultivation the natural equilibrium \nbetween soil building and soil removal is dis-\nturbed.\n• \nThe removal of surface soil takes place at a \nmuch faster rate than it can be built up by the \nsoil forming process.\nErosion by water: Known as water erosion, is \nthe removal of soil from the lands surface by water \nin motion.\nSheet erosion: The removal of a thin relatively \nuniform layer of soil particles by the action of rain-\nfall and runoff.\n• \nExtremely harmful\n• \nUsually so slow that the farmer is not conscious \nof its existence\n• \nCommon on lands having a gentle uniform \nslope\n• \nResults in the uniform removal of the cream of \nthe top soil with every heavy rain\n• \nShallow top soil overlies a tight sub soil are most \nsusceptible to sheet erosion\n• \nMovement of soil by rain drop splash is the pri-\nmary cause of sheet erosion\n• \nSheet erosion has damaged millions of hectares \nof slopping land throughout the India\nRill erosion is the removal of soil by running wa-\nter with the formation of shallow channels that can \nbe smoothed out completely by normal cultivation.\n• \nThere is no sharp lines of demarcation where \nsheet erosion and rill erosion begins but rill \nerosion is more readily apparent than sheet ero-\nsion.\n']
#   - retrieval context: ['10\nGeneral Conditions for Cultivation of Crops\nFarmer’s Handbook on Basic Agriculture\n1.5. Soil and Water Conservation\nS\noil and water are our precious heritage. Hence, \nit is obligatory on our part to protect and hand \nover these resources to further generations. It is \nestimated that about 50% of the cultivated area in \nIndia suffers from severe soil erosion and requires \nremedial measures. \n• \nWater resources are essential for increasing and \nstabilizing crop production.\n• \nWind erosion has been responsible for destroy-\ning the valuable top soil.\n1.5.1. Degradation of soil and water \ntakes place with water and wind ero-\nsion\n• \nThe main cause of water erosion is unmanaged \nrunoff.\n• \nRunoff is the portion of the rainfall or irriga-\ntion water applied which leaves a field either as \nsurface or as subsurface flow.\nSeveral factors are responsible for runoff \n• \nClimatic factors: Precipitation characteristics - \nduration, intensity, distribution, direction, tem-\nperature, humidity, wind velocity.\n• \nWatershed characteristics: Geological shape of \nthe catchments, size and shape of the catch-\nments, topography, drainage pattern.\n• \nBarren land without vegetation\n• \nSoil types: \n• \nSandy soil: Average rain – no problem of \nerosion. High intensity – More serious of \nless binding material i.e. fine soil particle.\n• \nClay soil: Ordinary rain – more runoff in \nmoderate and steep slopes but high water \nholding capacity. \n• \nSilt loam, loamy and fine sandy loam: More', 'General Conditions for Cultivation of Crops\nFarmer’s Handbook on Basic Agriculture\n11\n• \nRills develop when there is a concentration \nof runoff water which, if neglected, grow into \nlarge gullies.\n• \nMore serious in soils having a loose shallow top \nsoil.\n• \nTransition stage between sheet erosion and gul-\nlying.\nGully erosion: Removal of soil by running wa-\nter with the formation of channels that cannot be \nsmoothed out completely by cultivation.\n• \nAdvance stage of rill erosion.\n• \nAny concentration of surface runoff is a poten-\ntial source of gullying.\n• \nCattle paths, cart tracks, dead furrows, tillage \nfurrows or other small depression down a slope \nfavour concentration of flow.\n• \nUnattended rills deepen and widen every year \nand begin to attain the form of gullies.\n• \nUnattended gullies may result over a few years \nfor an entire landscape to be filled with a net-\nwork of gullies.\n• \nMore spectacular than other type of erosions.\nStream channel erosion: Erosion caused by \nstream flow.\n• \nClosely resembles rill erosion.\n• \nIntensive channel erosion areas are on the \noutside of lands where flow shear stresses are \nhigh.\t\nMass movement: Enmass movement of soil.\n• \nLandslides, land slips, soil and mudflows are \nvarious forms of mass movement.\nWind erosion: Movement of soil particles is \ncaused by wind force exerted against or parallel to \nsurface of the ground.  \n1.5.2. Conservation\nConservation is the utilization without wastage of', '• \nClay soil: Ordinary rain – more runoff in \nmoderate and steep slopes but high water \nholding capacity. \n• \nSilt loam, loamy and fine sandy loam: More \ndesirable soils from the point of view of \nminimizing soil erosion.\nHow vegetation reduces runoff\n• \nInterception of rainfall\n• \nRoot structure \n• \nBiological influences\n• \nTranspiration effects\n• \nIntercept, absorb the impact of raindrop\n• \nHindrance to runoff water slows down the rate \nat which travels down the slope\n• \nKnitting and binding effect aggregates the soil \ninto granules \n• \nDie and decay increase pore space and water \nholding capacity\n• \nOne cubic meter of soil has several kilometres \nof root fibre\n• \nMore vegetative cover, most active soil fauna, \nchannels of earth worm, beetles and other life\n• \nVegetation increases the storage capacity of \nthe soil for rainfall by the transpiration of large \nquantities of moistur ...
#
# ======================================================================
#
# Overall Metric Pass Rates
#
# Contextual Precision: 95.00% pass rate
# Contextual Recall: 90.00% pass rate
# Contextual Relevancy: 55.00% pass rate
# Answer Relevancy: 95.00% pass rate
# Answer Relevancy (ragas): 95.00% pass rate
# Faithfulness: 95.00% pass rate
# Hallucination: 95.00% pass rate
#
# ======================================================================
# ✓ Tests finished 🎉! Run 'deepeval login' to save and analyze evaluation results on Confident AI.
# ‼️  Friendly reminder 😇: You can also run evaluations with ALL of deepeval's metrics directly on Confident AI
# instead.

# %%
eval_results.test_results[0]
# Out:
# TestResult(success=True, metrics_data=[MetricData(name='Contextual Precision', threshold=0.5, success=True, score=1.0, reason="The score is 1.00 because all nodes are relevant and appropriately ranked. The nodes in the retrieval context extensively address how the Farmer's Handbook enhances farmers' decision-making abilities, highlighting aspects like 'enhancing awareness among farmers about sources of extension, information and services,' alignment with key topics such as 'Soil and Plant Nutrition,' and providing 'a holistic perspective of scientific Agriculture.' Great job!", strict_mode=False, evaluation_model='gpt-4o', error=None, evaluation_cost=0.00764, verbose_logs='Verdicts:\n[\n    {\n        "verdict": "yes",\n        "reason": "The text provides insights about enhancing farmers\' decision-making capabilities, mentioning \'educate and equip the farmers to make proper plans, take appropriate decisions\' and the last chapter focusing on \'enhancing awareness among farmers about sources of extension, information and services.\'"\n    },\n    {\n        "verdict": "yes",\n        "reason": "The content list of the Farmer\\u2019s Handbook aligns well with the key aspects mentioned in the expected output, such as \'Soil and Plant Nutrition,\' \'Plant Protection,\' and \'Farm Management,\' indicating comprehensive topic coverage."\n    },\n    {\n        "verdict": "yes",\n        "reason": "The context explains the intention behind the Farmer\'s Handbook and describes its development process, stating that it provides \'a holistic perspective of scientific Agriculture\' with chapters focusing on useful topics, such as \'Good Agricultural Practices,\' and \'Soil and Plant Nutrition,\' directly supporting the enhancement of informed agricultural decisions."\n    }\n]'), MetricData(name='Contextual Recall', threshold=0.5, success=True, score=1.0, reason='The score is 1.00 because all sentences in the expected output align perfectly with nodes in the retrieval context, demonstrating an excellent match. Great job!', strict_mode=False, evaluation_model='gpt-4o', error=None, evaluation_cost=0.00943, verbose_logs='Verdicts:\n[\n    {\n        "verdict": "yes",\n        "reason": "The sentence can be attributed to the 3rd node. It mentions \'enhance farmers\' ability to make informed agricultural decisions\' and \'comprehensive knowledge and practical guidance,\' which align with educating farmers on \'proper plans,\' \'appropriate decisions,\' and \'improved technologies...\' as mentioned in the retrieval context."\n    },\n    {\n        "verdict": "yes",\n        "reason": "The sentence is supported by the 3rd node, which states the first chapter provides \'basic knowledge on Good Agricultural Practices\' and \'selection of crops and cropping patterns,\' matching the description of the first chapter in the expected output."\n    },\n    {\n        "verdict": "yes",\n        "reason": "The sentence aligns with content from the 3rd node, which details the \'soil and plant nutrition\' chapter focusing on \'awareness and understanding of farmers about soil...\' and \'soil fertility,\' paralleling the second chapter description in the expected output."\n    },\n    {\n        "verdict": "yes",\n        "reason": "The 3rd node describes the \'Plant Protection\' chapter, which corresponds with the expected output\'s third chapter focusing on \'pest management...\' This matches the sentence\'s focus on educating \'farmers on handling pests and diseases safely.\'"\n    },\n    {\n        "verdict": "yes",\n        "reason": "The sentence matches content in the 3rd node under \'Farm Management,\' which \'equips farmers to make farming economically and environmentally sustainable...\' aligning with the fourth chapter\'s focus on \'farm management strategies.\'"\n    },\n    {\n        "verdict": "yes",\n        "reason": "The sentence is attributed to the 1st node, as it mentions the last chapter \'enhances awareness among farmers about sou ...

# %%
eval_metrics = []
for result in eval_results.test_results:
    eval_dict = {}
    eval_dict['Input'] = result.input
    eval_dict['Expected Output'] = result.expected_output
    eval_dict['Actual Output'] = result.actual_output
    eval_dict['Context'] = result.context
    eval_dict['Retrieval Context'] = result.retrieval_context
    eval_dict['Success'] = result.success
    metrics = result.metrics_data
    for metric in metrics:
        eval_dict[metric.name+'_Score'] = metric.score
    for metric in metrics:
        eval_dict[metric.name+'_Success'] = metric.success
    for metric in metrics:
        eval_dict[metric.name+'_Reason'] = metric.reason
    eval_metrics.append(eval_dict)

# %%
eval_metrics[0]
# Out:
# {'Input': "How can the chapters in the Farmer’s Handbook enhance farmers' ability to make informed agricultural decisions?",
#  'Expected Output': "The chapters in the Farmer’s Handbook enhance farmers' ability to make informed agricultural decisions by providing comprehensive knowledge and practical guidance on key aspects of farming. The first chapter equips farmers with foundational knowledge of Good Agricultural Practices and resource management, enabling them to select appropriate crops and cropping patterns. The second chapter on soil and plant nutrition helps farmers understand soil properties and nutrient management, encouraging sustainable and efficient crop production. The third chapter focuses on pest management, educating farmers on handling pests and diseases safely. The fourth chapter educates farmers on farm management strategies, enabling them to plan and use resources effectively. Lastly, the final chapter enhances farmers' access to information and services, including agricultural credit and insurance, through various communication technologies, helping farmers make economically and environmentally sustainable decisions.",
#  'Actual Output': "The Farmer's Handbook chapters aim to educate and equip farmers to make proper plans and appropriate decisions, take advantage of improved technologies to increase production, assure food security for the family, and create market opportunities to increase income, considering available resources and anticipated risks like market fluctuations. The last chapter, “Farmer’s access to services,” enhances awareness among farmers about sources of extension, information and services, public and private extension services, agricultural credit, insurance and legal aspects through Information & Communication Technologies.\n",
#  'Context': [' \nFarmer’s Handbook on Basic Agriculture\nPreface\nA\ngriculture is an important sector of Indian Economy as more than half of its population relies on Ag-\nriculture as principle source of income.  Research and Extension systems play major role in generation \nand dissemination of Agricultural technologies aiming at enhancing the income of farmers. The extension \nsystem adopts series of extension methods such as Training, demonstration, exposure visit to transfer \nthe technologies from lab to land. Majority of these extension efforts mainly focus on location and crop \nspecific technologies, and mostly on solution to problem basis. However, there is a need for equipping the \nfarmers with Basic knowledge of Agriculture in order to create a better knowledge platform at farmer level \nfor taking appropriate farm management decisions and to absorb modern technologies.  \nIn view of this, Desai Fruits and Vegetables Pvt. Ltd. (DFV), India, in cooperation with the Deutsche \nGesellschaft für Internationale Zusammenarbeit (GIZ) GmbH on behalf of the German Federal Ministry \nfor Economic Cooperation and Development (BMZ) in close cooperation with National Institute of Ag-\nricultural Extension Management (MANAGE- An Organization of Ministry of Agriculture, Government \nof India) brought out Farmer’s Handbook on Basic Agriculture to impart technical knowledge on Basic \nAgriculture to farmers to provide holistic perspective of scientific Agriculture.\nThis handbook is a product of series of brainstorming workshops and consultative meetings with various \nstakeholders such as Researchers, Academicians, Extension Functionaries, Agripreneurs, Master Trainers \nand Farmers. Based on the identified needs, the topics were prioritized and contents were developed with \nthe help of experts. The farmer-friendly content has been written in simple language, using more pictures \nwith practical examples for the benefit of farmers. \nThe book contains six chapters, each focusing on a particular topic. The first chapter, “General conditions \nfor cultivation of crops”\n, talks about the basic needs of farmers and farming sector, by providing basic \nknowledge on Good Agricultural Practices (GAP), enhancing the awareness of farmers on critical factors \nin selection of crops and cropping patterns, judicious use of natural resources such as soil and water, and \nemphasizing the importance of mechanization in the field of agriculture.\nThe second chapter “Soil and Plant Nutrition” is aimed at increasing the awareness and understanding of \nfarmers about soil, it’s structure, physical, chemical, biological properties, soil fertility and managing the \nsoil fertility in an economically and environmentally sustainable manner. It also focuses on the need for \nsoil testing, plant nutrition requirement, organic & inorganic fertilizers, and Integrated Nutrient Manage-\nment (INM) for efficient, economic and sustainable production of crops.\nThe third chapter of the book is about Pest Management, and focuses on enhancing the awareness of and \nunderstanding among farmers about the crop pests, diseases and weed management through Integrated \nPest Management. It also aims at sensitizing farmers on safe handling of chemicals and plant protection \nequipments as also elaborated further in the fifth chapter on “Occupational health and safety of farmers”\n. \nIt creates awareness about causes, preventive measures of health hazards, risks & fatalities in agriculture, \nand use of first aid in emergencies. It further includes safety tips and care to reduce the risk of injuries and \nfatalities while handling machineries and pesticides by farmers.\nTime and resources management is an integral part of each and every activity, be it service sector, busi-\nness or day-to-day activities of life. Farming sector too has not remained untouched by it. Therefore, the \nfourth chapter of the book is devoted to “Farm Management”\n. It is to educate and equip ...
#  'Retrieval Context': ['. It is to educate and equip the farmers to \nmake proper plans, take appropriate decisions and also to take advantage of the improved technologies \nto increase production, assure food security for the family and market opportunities to increase income \nconsidering available resources, anticipated risks, including market fluctuations.\n“Farmer’s access to services”\n, the last chapter of the book, aims at enhancing awareness among farmers \nabout sources of extension, information and services, public and private extension services, agricultural \ncredit, insurance and legal aspects through Information & Communication Technologies. The content is \nuseful not only for farmers but also for other stakeholders involved in farm advisory services such as Agri \ninput dealers, Agripreneurs, Kisan Call Centers and extension functionaries working at grass roots level. \nWe trust that this Handbook will benefit maximum number of farmers to make farming economically and \nenvironmentally more sustainable.\nB. Srinivas, IAS\nDirector General\nMANAGE',
#   'Farmer’s Handbook on Basic Agriculture\nContents\n1.\t\nGeneral Conditions for Cultivation of Crops\t \t\n\t\n\t\n\t\n1-32\n2.\t\nSoil and Plant Nutrition \t\n\t\n\t\n\t\n\t\n\t\n\t\n\t\n33-70\n3.\t\nPlant Protection\t \t\n\t\n\t\n\t\n\t\n\t\n\t\n\t\n71-96\n4.\t\nCategories of Pesticides and Precautions\t\t\n\t\n        97-98\n5.\t\nFarm Management\t\n\t\n\t\n\t\n\t\n\t\n\t\n\t\n99-120\n6.\t\nOccupational Health and Safety\t\n\t\n\t\n\t\n\t\n\t\n121-130\n7.\t\nFarmer’s Access to Service \t \t\n\t\n\t\n\t\n\t\n\t\n131-136',
#   'of India) brought out Farmer’s Handbook on Basic Agriculture to impart technical knowledge on Basic \nAgriculture to farmers to provide holistic perspective of scientific Agriculture.\nThis handbook is a product of series of brainstorming workshops and consultative meetings with various \nstakeholders such as Researchers, Academicians, Extension Functionaries, Agripreneurs, Master Trainers \nand Farmers. Based on the identified needs, the topics were prioritized and contents were developed with \nthe help of experts. The farmer-friendly content has been written in simple language, using more pictures \nwith practical examples for the benefit of farmers. \nThe book contains six chapters, each focusing on a particular topic. The first chapter, “General conditions \nfor cultivation of crops”\n, talks about the basic needs of farmers and farming sector, by providing basic \nknowledge on Good Agricultural Practices (GAP), enhancing the awareness of farmers on critical factors \nin selection of crops and cropping patterns, judicious use of natural resources such as soil and water, and \nemphasizing the importance of mechanization in the field of agriculture.\nThe second chapter “Soil and Plant Nutrition” is aimed at increasing the awareness and understanding of \nfarmers about soil, it’s structure, physical, chemical, biological properties, soil fertility and managing the \nsoil fertility in an economically and environmentally sustainable manner. It also focuses on the need for'],
#  'Success': True,
#  'Contextual Precision_Score': 1.0,
#  'Contextual Recall_Score': 1.0,
#  'Contextual Relevancy_Score': 0.8823529411764706,
#  'Answer Relevancy_Score': 1.0,
#  'Answer Relevancy (ragas)_Score': 0.8240658531454669,
#  'Faithfulness_Score': 1.0,
#  'Hallucination_Score': 0.0,
#  'Contextual Precision_Success': True,
#  'Contextual Recall_Success': True,
#  'Contextual Relevancy_Success': True,
#  'Answer Relevancy_Success': True,
#  'Answer Relevancy (ragas)_Success': True,
#  'Faithfulness_Success': True,
#  'Hallucination_Success': True,
#  'Contextual Precision_Reason': "The score is 1.00 because all nodes are relevant and appropriately ranked. The nodes in the retrieval context extensively address how the Farmer's Handbook enhances farmers' decision-making abilities, highlighting aspects like 'enhancing awareness among farmers about sources of extension, information and services,' alignment with key topics such as 'Soil and Plant Nutrition,' and providing 'a holistic perspective of scientific Agriculture.' Great job!",
#  'Contextual Recall_Reason': 'The score is 1.00 because all sentences in the expected output align perfectly with nodes in the retrieval context, demonstrating an excellent match. Great job!',
#  'Contextual Relevancy_Reason': "The score is 0.88 because, although some aspects focus on 'other stakeholders', relevant statements highlight how the handbook aims to 'educate and equip the farmers to make proper plans' and enhance their 'awareness about sources of extension, information and services', which directly contributes to informed decision-making.",
#  'Answer Relevancy_Reason': "The score is 1.00 because the response perfectly addresses the question about how the chapters in the Farmer's Handbook enhance farmers' decision-making abilities, with no irrelevant information present. Great job!",
#  'Answer Relevancy (ragas)_Reason': None,
#  'Faithfulness_Reason': 'The score is 1.00 because there are no contradictions between the actual output and the retrieval context. Keep up the great work!',
#  'Hallucination_Reason': 'The score is 0.00 because the actual output aligns well with the provided context, accurately reflecting the intents and content described without any contradictions.'}

# %%
import pandas as pd

eval_results_df = pd.DataFrame(eval_metrics)
eval_results_df.T
# Out:
#                                                                                  0   \
# Input                             How can the chapters in the Farmer’s Handbook ...
# Expected Output                   The chapters in the Farmer’s Handbook enhance ...
# Actual Output                     The Farmer's Handbook chapters aim to educate ...
# Context                           [ \nFarmer’s Handbook on Basic Agriculture\nPr...
# Retrieval Context                 [. It is to educate and equip the farmers to \...
# Success                                                                        True
# Contextual Precision_Score                                                      1.0
# Contextual Recall_Score                                                         1.0
# Contextual Relevancy_Score                                                 0.882353
# Answer Relevancy_Score                                                          1.0
# Answer Relevancy (ragas)_Score                                             0.824066
# Faithfulness_Score                                                              1.0
# Hallucination_Score                                                             0.0
# Contextual Precision_Success                                                   True
# Contextual Recall_Success                                                      True
# Contextual Relevancy_Success                                                   True
# Answer Relevancy_Success                                                       True
# Answer Relevancy (ragas)_Success                                               True
# Faithfulness_Success                                                           True
# Hallucination_Success                                                          True
# Contextual Precision_Reason       The score is 1.00 because all nodes are releva...
# Contextual Recall_Reason          The score is 1.00 because all sentences in the...
# Contextual Relevancy_Reason       The score is 0.88 because, although some aspec...
# Answer Relevancy_Reason           The score is 1.00 because the response perfect...
# Answer Relevancy (ragas)_Reason                                                None
# Faithfulness_Reason               The score is 1.00 because there are no contrad...
# Hallucination_Reason              The score is 0.00 because the actual output al...
#
#                                                                                  1   \
# Input                             What topics are addressed in the 'Farmer’s Han...
# Expected Output                   The 'Farmer’s Handbook on Basic Agriculture' b...
# Actual Output                     The 'Farmer’s Handbook on Basic Agriculture' b...
# Context                           [ \nFarmer’s Handbook on Basic Agriculture\nFa...
# Retrieval Context                 [Farmer’s Handbook on Basic Agriculture\nFarme...
# Success                                                                        True
# Contextual Precision_Score                                                      1.0
# Contextual Recall_Score                                                        0.75
# Contextual Relevancy_Score                                                 0.521739
# Answer Relevancy_Score                                                          1.0
# Answer Relevancy (ragas)_Score                                             0.803968
# Faithfulness_Score                                                              1.0
# Hallucination_Score                                                             0.0
# Contextual Precision_Success                                                   True
# Contextual Recall_Success                                                      True
# Contextual Relevancy_Success                                                   True
# Answer Relevancy_Success                                                       True
# Answer Relevancy (ragas)_Success                                               True
# Faithfulness_Success                                                           True
# Hallucination_Success                                                          True
# Contextual Precision_Reason       The score is 1.00 because all nodes in the ret...
# Contextual Recall_Reason          The score is 0.75 because while the nodes in r...
# Contextual Relevancy_Reason       The score is 0.52 because although the relevan...
# Answer Relevancy_Reason           The score is 1.00 because the output is fully ...
# Answer Relevancy (ragas)_Reason                                                None
# Faithfulness_Reason               The score is 1.00 because there are no contrad...
# Hallucination_Reason              The score is 0.00 because the actual output fu...
#
#                                                                                  2   \
# Input                             What vital guidelines from the Farmer's Handbo...
# Expected Output                   For effective crop cultivation, key guidelines...
# Actual Output                     Based on the Farmer's Handbook, vital guidelin...
# Context                           [2\nGeneral Conditions for Cultivation of Crop...
# Retrieval Context                 [General Conditions for Cultivation of Crops\n...
# Success                                                                        True
# Contextual Precision_Score                                                      1.0
# Contextual Recall_Score                                                         0.8
# Contextual Relevancy_Score                                                 0.666667
# Answer Relevancy_Score                                                          1.0
# Answer Relevancy (ragas)_Score                                              0.90156
# Faithfulness_Score                                                              1.0
# Hallucination_Score                                                             0.0
# Contextual Precision_Success                                                   True
# Contextual Recall_Success                                                      True
# Contextual Relevancy_Success                                                   True
# Answer Relevancy_Success                                                       True
# Answer Relevancy (ragas)_Success                                               True
# Faithfulness_Success                                                           True
# Hallucination_Success                                                          True
# Contextual Precision_Reason       The score is 1.00 because the relevant nodes i...
# Contextual Recall_Reason          The score is 0.80 because the majority of the ...
# Contextual Relevancy_Reason       The score is 0.67 because the relevant stateme...
# Answer Relevancy_Reason           The score is 1.00 because the response perfect...
# Answer Relevancy (ragas)_Reason                                                None
# Faithfulness_Reason               The score is 1.00 because there are no contrad...
# Hallucination_Reason              The score is 0.00 because the actual output is...
#
#                                                                                  3   \
# Input                             How do contour trenching and straw thatching h...
# Expected Output                   Contour trenching helps in runoff collection, ...
# Actual Output                     Straw thatching protects young seedlings again...
# Context                           [General Conditions for Cultivation of Crops\n...
# Retrieval Context                 [General Conditions for Cultivation of Crops\n...
# Success                                                                       False
# Contextual Precision_Score                                                      1.0
# Contextual Recall_Score                                                         0.4
# Contextual Relevancy_Score                                                 0.035088
# Answer Relevancy_Score                                                          1.0
# Answer Relevancy (ragas)_Score                                             0.814528
# Faithfulness_Score                                                              1.0
# Hallucination_Score                                                             0.0
# Contextual Precision_Success                                                   True
# Contextual Recall_Success                                                     False
# Contextual Relevancy_Success                                                  False
# Answer Relevancy_Success                                                       True
# Answer Relevancy (ragas)_Success                                               True
# Faithfulness_Success                                                           True
# Hallucination_Success                                                          True
# Contextual Precision_Reason       The score is 1.00 because relevant nodes in th...
# Contextual Recall_Reason          The score is 0.40 because while some aspects l...
# Contextual Relevancy_Reason       The score is 0.04 because the retrieval contex...
# Answer Relevancy_Reason           The score is 1.00 because the output directly ...
# Answer Relevancy (ragas)_Reason                                                None
# Faithfulness_Reason               The score is 1.00 because the actual output is...
# Hallucination_Reason              The score is 0.00 because the actual output is...
#
#                                                                                  4   \
# Input                             In what ways does PFI enhance the decision-mak...
# Expected Output                   PFI enhances the decision-making and competiti...
# Actual Output                     PFI enables farmers to be self-sufficient deci...
# Context                           [Farmer’s Handbook on Basic Agriculture\nAckno...
# Retrieval Context                 [modities. However, productivity and competiti...
# Success                                                                        True
# Contextual Precision_Score                                                      1.0
# Contextual Recall_Score                                                         1.0
# Contextual Relevancy_Score                                                 0.758621
# Answer Relevancy_Score                                                          1.0
# Answer Relevancy (ragas)_Score                                             0.841101
# Faithfulness_Score                                                              1.0
# Hallucination_Score                                                             0.0
# Contextual Precision_Success                                                   True
# Contextual Recall_Success                                                      True
# Contextual Relevancy_Success                                                   True
# Answer Relevancy_Success                                                       True
# Answer Relevancy (ragas)_Success                                               True
# Faithfulness_Success                                                           True
# Hallucination_Success                                                          True
# Contextual Precision_Reason       The score is 1.00 because the relevant nodes i...
# Contextual Recall_Reason          The score is 1.00 because every aspect of the ...
# Contextual Relevancy_Reason       The score is 0.76 because while the input asks...
# Answer Relevancy_Reason           The score is 1.00 because the output is perfec...
# Answer Relevancy (ragas)_Reason                                                None
# Faithfulness_Reason               The score is 1.00 because there are no contrad...
# Hallucination_Reason              The score is 0.00 because the actual output fu...
#
#                                                                                  5   \
# Input                             In what ways do climatic shifts, such as tempe...
# Expected Output                   Climatic shifts like temperature spikes and ra...
# Actual Output                     Climatic shifts, such as temperature spikes an...
# Context                           [General Conditions for Cultivation of Crops\n...
# Retrieval Context                 [General Conditions for Cultivation of Crops\n...
# Success                                                                        True
# Contextual Precision_Score                                                      1.0
# Contextual Recall_Score                                                         1.0
# Contextual Relevancy_Score                                                 0.833333
# Answer Relevancy_Score                                                          1.0
# Answer Relevancy (ragas)_Score                                             0.853776
# Faithfulness_Score                                                              1.0
# Hallucination_Score                                                             0.0
# Contextual Precision_Success                                                   True
# Contextual Recall_Success                                                      True
# Contextual Relevancy_Success                                                   True
# Answer Relevancy_Success                                                       True
# Answer Relevancy (ragas)_Success                                               True
# Faithfulness_Success                                                           True
# Hallucination_Success                                                          True
# Contextual Precision_Reason       The score is 1.00 because all nodes in the ret...
# Contextual Recall_Reason          The score is 1.00 because every aspect of the ...
# Contextual Relevancy_Reason       The score is 0.83 because the relevant stateme...
# Answer Relevancy_Reason           The score is 1.00 because the response complet...
# Answer Relevancy (ragas)_Reason                                                None
# Faithfulness_Reason               The score is 1.00 because there are no contrad...
# Hallucination_Reason              The score is 0.00 because the actual output fu...
#
#                                                                                  6   \
# Input                             How do climatic, soil, water, economic, and te...
# Expected Output                   Climatic, soil, water, economic, and technolog...
# Actual Output                     Climatic factors such as temperature, rainfall...
# Context                           [General Conditions for Cultivation of Crops\n...
# Retrieval Context                 [General Conditions for Cultivation of Crops\n...
# Success                                                                        True
# Contextual Precision_Score                                                      1.0
# Contextual Recall_Score                                                    0.857143
# Contextual Relevancy_Score                                                      0.8
# Answer Relevancy_Score                                                          1.0
# Answer Relevancy (ragas)_Score                                             0.857671
# Faithfulness_Score                                                              0.8
# Hallucination_Score                                                             0.0
# Contextual Precision_Success                                                   True
# Contextual Recall_Success                                                      True
# Contextual Relevancy_Success                                                   True
# Answer Relevancy_Success                                                       True
# Answer Relevancy (ragas)_Success                                               True
# Faithfulness_Success                                                           True
# Hallucination_Success                                                          True
# Contextual Precision_Reason       The score is 1.00 because all nodes in the ret...
# Contextual Recall_Reason          The score is 0.86 because the expected output ...
# Contextual Relevancy_Reason       The score is 0.80 because while several releva...
# Answer Relevancy_Reason           The score is 1.00 because every part of the ou...
# Answer Relevancy (ragas)_Reason                                                None
# Faithfulness_Reason               The score is 0.80 because the actual output in...
# Hallucination_Reason              The score is 0.00 because there are no contrad...
#
#                                                                                  7   \
# Input                             What insights does the Farmer's Handbook provi...
# Expected Output                   The Farmer's Handbook on Basic Agriculture pro...
# Actual Output                     The Farmer's Handbook on Basic Agriculture imp...
# Context                           [A holistic  \nperspective of  \nscientific  \...
# Retrieval Context                 [of India) brought out Farmer’s Handbook on Ba...
# Success                                                                        True
# Contextual Precision_Score                                                 0.833333
# Contextual Recall_Score                                                         1.0
# Contextual Relevancy_Score                                                      0.5
# Answer Relevancy_Score                                                          1.0
# Answer Relevancy (ragas)_Score                                              0.78429
# Faithfulness_Score                                                              1.0
# Hallucination_Score                                                             0.0
# Contextual Precision_Success                                                   True
# Contextual Recall_Success                                                      True
# Contextual Relevancy_Success                                                   True
# Answer Relevancy_Success                                                       True
# Answer Relevancy (ragas)_Success                                               True
# Faithfulness_Success                                                           True
# Hallucination_Success                                                          True
# Contextual Precision_Reason       The score is 0.83 because the first and third ...
# Contextual Recall_Reason          The score is 1.00 because the expected output ...
# Contextual Relevancy_Reason       The score is 0.50 because while the handbook p...
# Answer Relevancy_Reason           The score is 1.00 because the response perfect...
# Answer Relevancy (ragas)_Reason                                                None
# Faithfulness_Reason               The score is 1.00 because the actual output pe...
# Hallucination_Reason              The score is 0.00 because the actual output pe...
#
#                                                                                  8   \
# Input                             What is the impact of rills and unattended gul...
# Expected Output                   Rills can develop into larger gullies if left ...
# Actual Output                     Rills, if neglected, can grow into large gulli...
# Context                           [General Conditions for Cultivation of Crops\n...
# Retrieval Context                 [General Conditions for Cultivation of Crops\n...
# Success                                                                        True
# Contextual Precision_Score                                                      1.0
# Contextual Recall_Score                                                         1.0
# Contextual Relevancy_Score                                                 0.678571
# Answer Relevancy_Score                                                          1.0
# Answer Relevancy (ragas)_Score                                             0.713767
# Faithfulness_Score                                                              1.0
# Hallucination_Score                                                             0.0
# Contextual Precision_Success                                                   True
# Contextual Recall_Success                                                      True
# Contextual Relevancy_Success                                                   True
# Answer Relevancy_Success                                                       True
# Answer Relevancy (ragas)_Success                                               True
# Faithfulness_Success                                                           True
# Hallucination_Success                                                          True
# Contextual Precision_Reason       The score is 1.00 because all nodes in the ret...
# Contextual Recall_Reason          The score is 1.00 because every sentence in th...
# Contextual Relevancy_Reason       The score is 0.68 because some relevant statem...
# Answer Relevancy_Reason           The score is 1.00 because the actual output di...
# Answer Relevancy (ragas)_Reason                                                None
# Faithfulness_Reason               The score is 1.00 because there are no contrad...
# Hallucination_Reason              The score is 0.00 because there are no contrad...
#
#                                                                                  9   \
# Input                             What are the effects of increased temperatures...
# Expected Output                   Increased temperatures and altered rainfall in...
# Actual Output                     Increased temperatures may lead to an increase...
# Context                           [6\nGeneral Conditions for Cultivation of Crop...
# Retrieval Context                 [6\nGeneral Conditions for Cultivation of Crop...
# Success                                                                       False
# Contextual Precision_Score                                                      1.0
# Contextual Recall_Score                                                         0.8
# Contextual Relevancy_Score                                                 0.333333
# Answer Relevancy_Score                                                          1.0
# Answer Relevancy (ragas)_Score                                             0.762563
# Faithfulness_Score                                                              1.0
# Hallucination_Score                                                             0.0
# Contextual Precision_Success                                                   True
# Contextual Recall_Success                                                      True
# Contextual Relevancy_Success                                                  False
# Answer Relevancy_Success                                                       True
# Answer Relevancy (ragas)_Success                                               True
# Faithfulness_Success                                                           True
# Hallucination_Success                                                          True
# Contextual Precision_Reason       The score is 1.00 because the relevant node ad...
# Contextual Recall_Reason          The score is 0.80 because while the 1st node i...
# Contextual Relevancy_Reason       The score is 0.33 because while some relevant ...
# Answer Relevancy_Reason           The score is 1.00 because the response perfect...
# Answer Relevancy (ragas)_Reason                                                None
# Faithfulness_Reason               The score is 1.00 because there are no contrad...
# Hallucination_Reason              The score is 0.00 because there are no contrad...
#
#                                                                                  10  \
# Input                             In what ways do Farm Ponds and Conservation Fu...
# Expected Output                   Farm Ponds and Conservation Furrows contribute...
# Actual Output                     Farm Ponds and Conservation Furrows contribute...
# Context                           [8\nGeneral Conditions for Cultivation of Crop...
# Retrieval Context                 [8\nGeneral Conditions for Cultivation of Crop...
# Success                                                                       False
# Contextual Precision_Score                                                      1.0
# Contextual Recall_Score                                                         1.0
# Contextual Relevancy_Score                                                 0.019231
# Answer Relevancy_Score                                                          1.0
# Answer Relevancy (ragas)_Score                                             0.811679
# Faithfulness_Score                                                              1.0
# Hallucination_Score                                                             0.0
# Contextual Precision_Success                                                   True
# Contextual Recall_Success                                                      True
# Contextual Relevancy_Success                                                  False
# Answer Relevancy_Success                                                       True
# Answer Relevancy (ragas)_Success                                               True
# Faithfulness_Success                                                           True
# Hallucination_Success                                                          True
# Contextual Precision_Reason       The score is 1.00 because the first node in re...
# Contextual Recall_Reason          The score is 1.00 because each sentence in the...
# Contextual Relevancy_Reason       The score is 0.02 because, despite one relevan...
# Answer Relevancy_Reason           The score is 1.00 because the response perfect...
# Answer Relevancy (ragas)_Reason                                                None
# Faithfulness_Reason               The score is 1.00 because the actual output pe...
# Hallucination_Reason              The score is 0.00 because the actual output fu...
#
#                                                                                  11  \
# Input                             How does farmers' access to agri-tech knowledg...
# Expected Output                   Farmers' access to agri-tech knowledge and pra...
# Actual Output                     Farmers with access to technical knowledge on ...
# Context                           [General Conditions for Cultivation of Crops\n...
# Retrieval Context                 [General Conditions for Cultivation of Crops\n...
# Success                                                                        True
# Contextual Precision_Score                                                 0.833333
# Contextual Recall_Score                                                         1.0
# Contextual Relevancy_Score                                                 0.761905
# Answer Relevancy_Score                                                          1.0
# Answer Relevancy (ragas)_Score                                             0.806468
# Faithfulness_Score                                                              1.0
# Hallucination_Score                                                             0.0
# Contextual Precision_Success                                                   True
# Contextual Recall_Success                                                      True
# Contextual Relevancy_Success                                                   True
# Answer Relevancy_Success                                                       True
# Answer Relevancy (ragas)_Success                                               True
# Faithfulness_Success                                                           True
# Hallucination_Success                                                          True
# Contextual Precision_Reason       The score is 0.83 because the first and third ...
# Contextual Recall_Reason          The score is 1.00 because every sentence in th...
# Contextual Relevancy_Reason       The score is 0.76 because although there is a ...
# Answer Relevancy_Reason           The score is 1.00 because the response perfect...
# Answer Relevancy (ragas)_Reason                                                None
# Faithfulness_Reason               The score is 1.00 because there are no contrad...
# Hallucination_Reason              The score is 0.00 because the actual output ac...
#
#                                                                                  12  \
# Input                             What role do monsoons, temperature, and market...
# Expected Output                   Monsoons, temperature, and market influences s...
# Actual Output                     Monsoons are a key source of water in agricult...
# Context                           [4\nGeneral Conditions for Cultivation of Crop...
# Retrieval Context                 [• \nDo you have access to primary processing ...
# Success                                                                       False
# Contextual Precision_Score                                                      1.0
# Contextual Recall_Score                                                         1.0
# Contextual Relevancy_Score                                                 0.361111
# Answer Relevancy_Score                                                          1.0
# Answer Relevancy (ragas)_Score                                               0.7191
# Faithfulness_Score                                                              1.0
# Hallucination_Score                                                             0.0
# Contextual Precision_Success                                                   True
# Contextual Recall_Success                                                      True
# Contextual Relevancy_Success                                                  False
# Answer Relevancy_Success                                                       True
# Answer Relevancy (ragas)_Success                                               True
# Faithfulness_Success                                                           True
# Hallucination_Success                                                          True
# Contextual Precision_Reason       The score is 1.00 because all nodes in the ret...
# Contextual Recall_Reason          The score is 1.00 because every aspect of the ...
# Contextual Relevancy_Reason       The score is 0.36 because while relevant state...
# Answer Relevancy_Reason           The score is 1.00 because the response perfect...
# Answer Relevancy (ragas)_Reason                                                None
# Faithfulness_Reason               The score is 1.00 because there are no contrad...
# Hallucination_Reason              The score is 0.00 because there are no contrad...
#
#                                                                                  13  \
# Input                             What is GIZ's stance on authors' opinions and ...
# Expected Output                   GIZ does not necessarily reflect the opinions ...
# Actual Output                     According to the disclaimer, the opinions expr...
# Context                           [Disclaimer:\nThe opinions expressed provided ...
# Retrieval Context                 [Disclaimer:\nThe opinions expressed provided ...
# Success                                                                       False
# Contextual Precision_Score                                                      1.0
# Contextual Recall_Score                                                         1.0
# Contextual Relevancy_Score                                                      0.2
# Answer Relevancy_Score                                                          1.0
# Answer Relevancy (ragas)_Score                                             0.757213
# Faithfulness_Score                                                              1.0
# Hallucination_Score                                                             0.0
# Contextual Precision_Success                                                   True
# Contextual Recall_Success                                                      True
# Contextual Relevancy_Success                                                  False
# Answer Relevancy_Success                                                       True
# Answer Relevancy (ragas)_Success                                               True
# Faithfulness_Success                                                           True
# Hallucination_Success                                                          True
# Contextual Precision_Reason       The score is 1.00 because the node in the firs...
# Contextual Recall_Reason          The score is 1.00 because the sentence is full...
# Contextual Relevancy_Reason       The score is 0.20 because the relevant stateme...
# Answer Relevancy_Reason           The score is 1.00 because the output is perfec...
# Answer Relevancy (ragas)_Reason                                                None
# Faithfulness_Reason               The score is 1.00 because there are no contrad...
# Hallucination_Reason              The score is 0.00 because the actual output ac...
#
#                                                                                  14  \
# Input                             What topics are covered in the 'Soil and Plant...
# Expected Output                   The 'Soil and Plant Nutrition' section of the ...
# Actual Output                     The 'Soil and Plant Nutrition' section (pp. 33...
# Context                           [ \nFarmer’s Handbook on Basic Agriculture\nCo...
# Retrieval Context                 [Farmer’s Handbook on Basic Agriculture\nConte...
# Success                                                                       False
# Contextual Precision_Score                                                      1.0
# Contextual Recall_Score                                                         1.0
# Contextual Relevancy_Score                                                 0.214286
# Answer Relevancy_Score                                                          1.0
# Answer Relevancy (ragas)_Score                                             0.774277
# Faithfulness_Score                                                              1.0
# Hallucination_Score                                                             0.0
# Contextual Precision_Success                                                   True
# Contextual Recall_Success                                                      True
# Contextual Relevancy_Success                                                  False
# Answer Relevancy_Success                                                       True
# Answer Relevancy (ragas)_Success                                               True
# Faithfulness_Success                                                           True
# Hallucination_Success                                                          True
# Contextual Precision_Reason       The score is 1.00 because all the relevant nod...
# Contextual Recall_Reason          The score is 1.00 because the expected output ...
# Contextual Relevancy_Reason       The score is 0.21 because only a small portion...
# Answer Relevancy_Reason           The score is 1.00 because the output perfectly...
# Answer Relevancy (ragas)_Reason                                                None
# Faithfulness_Reason               The score is 1.00 because there are no contrad...
# Hallucination_Reason              The score is 0.00 because the actual output pe...
#
#                                                                                  15  \
# Input                             In what ways can altering cropping, employing ...
# Expected Output                   Altering cropping patterns, employing mixed fa...
# Actual Output                     Changing cropping patterns and mixed cropping ...
# Context                           [General Conditions for Cultivation of Crops\n...
# Retrieval Context                 [General Conditions for Cultivation of Crops\n...
# Success                                                                       False
# Contextual Precision_Score                                                      1.0
# Contextual Recall_Score                                                         1.0
# Contextual Relevancy_Score                                                 0.106383
# Answer Relevancy_Score                                                          1.0
# Answer Relevancy (ragas)_Score                                             0.801546
# Faithfulness_Score                                                              1.0
# Hallucination_Score                                                             0.0
# Contextual Precision_Success                                                   True
# Contextual Recall_Success                                                      True
# Contextual Relevancy_Success                                                  False
# Answer Relevancy_Success                                                       True
# Answer Relevancy (ragas)_Success                                               True
# Faithfulness_Success                                                           True
# Hallucination_Success                                                          True
# Contextual Precision_Reason       The score is 1.00 because the first node in th...
# Contextual Recall_Reason          The score is 1.00 because every part of the ex...
# Contextual Relevancy_Reason       The score is 0.11 because most of the context ...
# Answer Relevancy_Reason           The score is 1.00 because the response perfect...
# Answer Relevancy (ragas)_Reason                                                None
# Faithfulness_Reason               The score is 1.00 because there are no contrad...
# Hallucination_Reason              The score is 0.00 because there are no factual...
#
#                                                                                  16  \
# Input                             Who are the contributors from GIZ, universitie...
# Expected Output                   The contributors from GIZ are Mr. Max Baumann,...
# Actual Output                     The contributors from GIZ are Max Baumann, Fre...
# Context                           [The Authors acknowledge the contribution of f...
# Retrieval Context                 [The Authors acknowledge the contribution of f...
# Success                                                                       False
# Contextual Precision_Score                                                 0.833333
# Contextual Recall_Score                                                         1.0
# Contextual Relevancy_Score                                                 0.653846
# Answer Relevancy_Score                                                          1.0
# Answer Relevancy (ragas)_Score                                              0.82284
# Faithfulness_Score                                                              1.0
# Hallucination_Score                                                             1.0
# Contextual Precision_Success                                                   True
# Contextual Recall_Success                                                      True
# Contextual Relevancy_Success                                                   True
# Answer Relevancy_Success                                                       True
# Answer Relevancy (ragas)_Success                                               True
# Faithfulness_Success                                                           True
# Hallucination_Success                                                         False
# Contextual Precision_Reason       The score is 0.83 because the first node in th...
# Contextual Recall_Reason          The score is 1.00 because every sentence in th...
# Contextual Relevancy_Reason       The score is 0.65 because while there are rele...
# Answer Relevancy_Reason           The score is 1.00 because the answer perfectly...
# Answer Relevancy (ragas)_Reason                                                None
# Faithfulness_Reason               The score is 1.00 because there are no contrad...
# Hallucination_Reason              The score is 1.00 because the actual output li...
#
#                                                                                  17  \
# Input                             How does Retrieval Augmented Generation effect...
# Expected Output                   Retrieval Augmented Generation (RAG) enhances ...
# Actual Output                     I am sorry, but this document does not contain...
# Context                                                                          []
# Retrieval Context                 [crop/cropping system?\n• \nDo you have extens...
# Success                                                                       False
# Contextual Precision_Score                                                      0.0
# Contextual Recall_Score                                                         0.0
# Contextual Relevancy_Score                                                      0.0
# Answer Relevancy_Score                                                          0.0
# Answer Relevancy (ragas)_Score                                                  0.0
# Faithfulness_Score                                                              1.0
# Hallucination_Score                                                             0.0
# Contextual Precision_Success                                                  False
# Contextual Recall_Success                                                     False
# Contextual Relevancy_Success                                                  False
# Answer Relevancy_Success                                                      False
# Answer Relevancy (ragas)_Success                                              False
# Faithfulness_Success                                                           True
# Hallucination_Success                                                          True
# Contextual Precision_Reason       The score is 0.00 because all nodes in retriev...
# Contextual Recall_Reason          The score is 0.00 because none of the sentence...
# Contextual Relevancy_Reason       The score is 0.00 because no statements from t...
# Answer Relevancy_Reason           The score is 0.00 because the statement was an...
# Answer Relevancy (ragas)_Reason                                                None
# Faithfulness_Reason               The score is 1.00 because there are no contrad...
# Hallucination_Reason              The score is 0.00 because there are no contrad...
#
#                                                                                  18  \
# Input                             What are the benefits of zero tillage farming ...
# Expected Output                   Zero tillage farming offers several benefits f...
# Actual Output                     Zero tillage farming has several benefits:\n\n...
# Context                           [12\nGeneral Conditions for Cultivation of Cro...
# Retrieval Context                 [Overland flow management\n• \nContour bund\n•...
# Success                                                                       False
# Contextual Precision_Score                                                      1.0
# Contextual Recall_Score                                                         1.0
# Contextual Relevancy_Score                                                 0.333333
# Answer Relevancy_Score                                                          1.0
# Answer Relevancy (ragas)_Score                                             0.829046
# Faithfulness_Score                                                         0.333333
# Hallucination_Score                                                             0.0
# Contextual Precision_Success                                                   True
# Contextual Recall_Success                                                      True
# Contextual Relevancy_Success                                                  False
# Answer Relevancy_Success                                                       True
# Answer Relevancy (ragas)_Success                                               True
# Faithfulness_Success                                                          False
# Hallucination_Success                                                          True
# Contextual Precision_Reason       The score is 1.00 because all relevant nodes a...
# Contextual Recall_Reason          The score is 1.00 because every sentence in th...
# Contextual Relevancy_Reason       The score is 0.33 because the relevant stateme...
# Answer Relevancy_Reason           The score is 1.00 because the answer provided ...
# Answer Relevancy (ragas)_Reason                                                None
# Faithfulness_Reason               The score is 0.33 because the actual output cl...
# Hallucination_Reason              The score is 0.00 because the actual output pe...
#
#                                                                                  19
# Input                             What are the roles of runoff, different types ...
# Expected Output                   Runoff, erosion, and vegetation play crucial r...
# Actual Output                     Here's what the provided text says about the r...
# Context                           [10\nGeneral Conditions for Cultivation of Cro...
# Retrieval Context                 [10\nGeneral Conditions for Cultivation of Cro...
# Success                                                                        True
# Contextual Precision_Score                                                      1.0
# Contextual Recall_Score                                                       0.875
# Contextual Relevancy_Score                                                 0.659091
# Answer Relevancy_Score                                                          1.0
# Answer Relevancy (ragas)_Score                                             0.855742
# Faithfulness_Score                                                              1.0
# Hallucination_Score                                                             0.0
# Contextual Precision_Success                                                   True
# Contextual Recall_Success                                                      True
# Contextual Relevancy_Success                                                   True
# Answer Relevancy_Success                                                       True
# Answer Relevancy (ragas)_Success                                               True
# Faithfulness_Success                                                           True
# Hallucination_Success                                                          True
# Contextual Precision_Reason       The score is 1.00 because all relevant nodes i...
# Contextual Recall_Reason          The score is 0.88 because the majority of the ...
# Contextual Relevancy_Reason       The score is 0.66 because, while there are rel...
# Answer Relevancy_Reason           The score is 1.00 because the response perfect...
# Answer Relevancy (ragas)_Reason                                                None
# Faithfulness_Reason               The score is 1.00 because there are no contrad...
# Hallucination_Reason              The score is 0.00 because the actual output ac...

# %%
eval_results_df[['Contextual Precision_Score', 'Contextual Recall_Score', 'Contextual Relevancy_Score',
                 'Answer Relevancy_Score', 'Answer Relevancy (ragas)_Score',
                 'Faithfulness_Score', 'Hallucination_Score']].describe()
# Out:
#        Contextual Precision_Score  Contextual Recall_Score  \
# count                   20.000000                20.000000
# mean                     0.925000                 0.874107
# std                      0.226045                 0.253559
# min                      0.000000                 0.000000
# 25%                      1.000000                 0.842857
# 50%                      1.000000                 1.000000
# 75%                      1.000000                 1.000000
# max                      1.000000                 1.000000
#
#        Contextual Relevancy_Score  Answer Relevancy_Score  \
# count                   20.000000               20.000000
# mean                     0.465945                0.950000
# std                      0.296240                0.223607
# min                      0.000000                0.000000
# 25%                      0.210714                1.000000
# 50%                      0.510870                1.000000
# 75%                      0.698584                1.000000
# max                      0.882353                1.000000
#
#        Answer Relevancy (ragas)_Score  Faithfulness_Score  Hallucination_Score
# count                       20.000000           20.000000            20.000000
# mean                         0.766760            0.956667             0.050000
# std                          0.186336            0.153364             0.223607
# min                          0.000000            0.333333             0.000000
# 25%                          0.771348            1.000000             0.000000
# 50%                          0.809074            1.000000             0.000000
# 75%                          0.832060            1.000000             0.000000
# max                          0.901560            1.000000             1.000000
